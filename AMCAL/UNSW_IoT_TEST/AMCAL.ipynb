# %% [markdown]
# ## ------------------------------------ Final method --------------------------------------

# %% [markdown]
# ## intial train nash equillibriam

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import random
from collections import deque
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define 1D-CNN model
class CNN1D(nn.Module):
    def __init__(self, input_length, num_classes):
        super(CNN1D, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.25)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.25)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv1d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.3)
        )
        self.flatten = nn.Flatten()
        output_length = input_length // 8
        self.dense_layers = nn.Sequential(
            nn.Linear(256 * output_length, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, num_classes)
        )
    
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.flatten(x)
        x = self.dense_layers(x)
        return x

# Define ContextAwareNetwork
class ContextAwareNetwork(nn.Module):
    def __init__(self, input_size, num_layers=4, dim_feedforward=1024):
        super(ContextAwareNetwork, self).__init__()
        self.input_size = input_size
        
        # محاسبه خودکار تعداد heads بر اساس input_size
        possible_heads = [8, 4, 2, 1]
        num_heads = 1
        for h in possible_heads:
            if input_size % h == 0:
                num_heads = h
                break
        
        if input_size % num_heads != 0:
            num_heads = 1
            print(f"Warning: Using num_heads=1 for input_size={input_size}")
        
        print(f"Selected num_heads={num_heads} for input_size={input_size}")
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=input_size,
            nhead=num_heads,
            dim_feedforward=dim_feedforward,
            dropout=0.3,
            activation='relu',
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels=2, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Flatten(),
            nn.Linear(128 * input_size, 512),
            nn.ReLU(),
            nn.LayerNorm(512),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, input_size),
            nn.ReLU(),
            nn.LayerNorm(input_size)
        )
    
    def forward(self, x):
        x_flat = x.squeeze(1)
        x_transformed = self.transformer(x_flat.unsqueeze(1)).squeeze(1)
        weights = torch.sigmoid(x_transformed)
        combined = torch.stack([x_flat, weights], dim=1)
        encoded = self.encoder(combined)
        return encoded.unsqueeze(1)

# Define DQNSelector
class DQNSelector(nn.Module):
    def __init__(self, input_size):
        super(DQNSelector, self).__init__()
        hidden_size1 = min(512, max(128, input_size * 2))
        hidden_size2 = min(256, hidden_size1 // 2)
        
        self.network = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size2, 2)
        )
    
    def forward(self, x):
        return self.network(x)

# Replay Buffer for DQN
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        state = state.squeeze().cpu()
        next_state = next_state.squeeze().cpu()
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        states = torch.stack([torch.FloatTensor(s) for s in state])
        next_states = torch.stack([torch.FloatTensor(s) for s in next_state])
        return (
            states,
            torch.tensor(action, dtype=torch.long),
            torch.tensor(reward, dtype=torch.float32),
            next_states,
            torch.tensor(done, dtype=torch.float32)
        )
    
    def __len__(self):
        return len(self.buffer)

# DQN Agent
class DQNSelectorAgent:
    def __init__(self, input_size, device, lr=1e-4, gamma=0.5, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995, buffer_capacity=50000, batch_size=256):
        self.device = device
        self.policy_net = DQNSelector(input_size).to(device)
        self.target_net = DQNSelector(input_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.replay_buffer = ReplayBuffer(buffer_capacity)
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.steps_done = 0
    
    def select_action(self, state):
        """Select action for given state. Always returns a tensor."""
        self.steps_done += 1
        
        if len(state.shape) == 1:
            state = state.unsqueeze(0)
        
        state = state.to(self.device)
        
        if random.random() < self.epsilon:
            return torch.randint(0, 2, (state.size(0),), device=self.device)
        else:
            with torch.no_grad():
                q_values = self.policy_net(state)
                return q_values.argmax(dim=1)
    
    def update_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)
    
    def optimize(self):
        if len(self.replay_buffer) < self.batch_size:
            return None
        
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
        states = states.to(self.device)
        actions = actions.to(self.device)
        rewards = rewards.to(self.device)
        next_states = next_states.to(self.device)
        dones = dones.to(self.device)
        
        current_q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        
        with torch.no_grad():
            next_actions = self.policy_net(next_states).argmax(1)
            next_q_values = self.target_net(next_states).gather(1, next_actions.unsqueeze(1)).squeeze(1)
            target_q_values = rewards + (1 - dones) * self.gamma * next_q_values
        
        loss = nn.MSELoss()(current_q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), max_norm=1.0)
        self.optimizer.step()
        return loss.item()
    
    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# Load and preprocess data - GENERALIZED version
def load_data(dataset_path='Dataset', csv_filename='UNSW_IoT_original.csv'):
    try:
        original_df = pd.read_csv(f'{dataset_path}/{csv_filename}')
        
        # تقسیم داده به train (60%)، validation (20%)، test (20%)
        train_df, temp_df = train_test_split(original_df, test_size=0.4, random_state=42)
        val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)
        
        X_train = train_df.iloc[:, :-1].values
        y_train = train_df.iloc[:, -1].values
        X_val = val_df.iloc[:, :-1].values
        y_val = val_df.iloc[:, -1].values
        X_test = test_df.iloc[:, :-1].values
        y_test = test_df.iloc[:, -1].values
        
    except FileNotFoundError as e:
        print(f"Error: Dataset file not found: {e}")
        return None, None, None, None, None, None, None
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None, None, None, None, None, None, None
    
    # Encode labels
    label_encoder = LabelEncoder()
    y_train = label_encoder.fit_transform(y_train)
    y_val = label_encoder.transform(y_val)
    y_test = label_encoder.transform(y_test)
    num_classes = len(label_encoder.classes_)
    
    print(f"Detected {num_classes} classes in the dataset")
    print(f"Classes: {label_encoder.classes_}")
    
    # Scale features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)
    
    # Convert to tensors
    X_train_tensor = torch.FloatTensor(X_train).unsqueeze(1).to(device)
    y_train_tensor = torch.LongTensor(y_train).to(device)
    X_val_tensor = torch.FloatTensor(X_val).unsqueeze(1).to(device)
    y_val_tensor = torch.LongTensor(y_val).to(device)
    X_test_tensor = torch.FloatTensor(X_test).unsqueeze(1).to(device)
    y_test_tensor = torch.LongTensor(y_test).to(device)
    
    # Create datasets
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    
    # Handle class imbalance
    class_counts = np.bincount(y_train)
    if len(class_counts) < num_classes:
        class_counts = np.append(class_counts, [0] * (num_classes - len(class_counts)))
    
    weights = 1.0 / class_counts[y_train]
    train_sampler = WeightedRandomSampler(weights, len(weights))
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler) 
    full_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)  
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False) 
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)  
    
    print("Class distribution in training data:", np.bincount(y_train))
    print("Class distribution in validation data:", np.bincount(y_val))
    print("Class distribution in test data:", np.bincount(y_test))
    print(f"Total training samples: {X_train.shape[0]}, validation samples: {X_val.shape[0]}, test samples: {X_test.shape[0]}")
    print(f"Input length: {X_train.shape[1]}")
    print(f"Full dataset size for adversarial training: {len(train_dataset)}")
    
    return train_loader, val_loader, test_loader, full_loader, num_classes, X_train.shape[1], class_counts

# Compute combined loss
def compute_combined_loss(outputs, labels, class_weights):
    criterion = nn.CrossEntropyLoss(weight=class_weights, reduction='none')
    per_sample_loss = criterion(outputs, labels)
    mean_loss = per_sample_loss.mean()
    return mean_loss, per_sample_loss

# Train initial CNN model
def train_initial_cnn(cnn_model, train_loader, val_loader, class_counts, epochs=500, patience=50):
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(cnn_model.parameters(), lr=0.0005, weight_decay=1e-4)  
    scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=1e-6)
    
    best_val_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None
    
    for epoch in range(epochs):
        cnn_model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = cnn_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        
        cnn_model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = cnn_model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss = val_loss / len(val_loader.dataset)
        val_accuracy = correct / total
        print(f"Initial CNN Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = cnn_model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs.")
                if best_model_state is not None:
                    cnn_model.load_state_dict(best_model_state)
                break
        
        scheduler.step()
    
    return cnn_model

# Evaluate model
def evaluate_model(model, test_loader, class_weights, context_model=None, dqn_agent=None, threshold=None):
    model.eval()
    y_true = []
    y_pred = []
    running_loss = 0.0
    total_samples = 0
    softmax = nn.Softmax(dim=1)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            batch_size = inputs.size(0)
            total_samples += batch_size
            
            if context_model and dqn_agent and threshold is not None:
                cnn_outputs = model(inputs)
                probs = softmax(cnn_outputs)
                
                encoded_inputs = context_model(inputs)
                outputs = model(encoded_inputs)
                
                _, predicted = torch.max(outputs, 1)
                final_loss = criterion(outputs, labels)
                running_loss += final_loss.item() * batch_size
            else:
                outputs = model(inputs)
                final_loss = criterion(outputs, labels)
                running_loss += final_loss.item() * batch_size
                _, predicted = torch.max(outputs, 1)
            
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(labels.cpu().numpy())
    
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    test_loss = running_loss / total_samples
    
    return {
        'Test Loss': test_loss,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }

def compute_reward(action, cnn_pred, weighted_pred, label):
    if action == 1:
        if weighted_pred != label and cnn_pred != label:
            reward = 3.0
        elif weighted_pred == label and cnn_pred != label:
            reward = 2.0
        elif weighted_pred != label and cnn_pred == label:
            reward = -2.0
        else:
            reward = 0.0
    else:
        reward = 1.5 if cnn_pred == label else -1.0
    return reward

def train_adversarial_system(cnn_model, dqn_agent, context_model, full_loader, val_loader, class_counts, input_length, num_classes, fine_tune_epochs=500, patience=50):
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    cnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
    context_optimizer = optim.Adam(context_model.parameters(), lr=5e-4, weight_decay=1e-4)
    context_scheduler = lr_scheduler.CosineAnnealingLR(context_optimizer, T_max=100)
    
    best_val_accuracy = 0.0
    epochs_no_improve = 0
    softmax = nn.Softmax(dim=1)
    best_context_state = None
    best_dqn_state = None
    
    # Pre-train ContextAwareNetwork
    print("Pre-training ContextAwareNetwork...")
    for pretrain_epoch in range(20):
        context_model.train()
        total_context_loss = 0.0
        num_batches = 0
        for inputs, labels in full_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            context_optimizer.zero_grad()
            encoded_inputs = context_model(inputs)
            cnn_outputs_weighted = cnn_model(encoded_inputs)
            context_loss = cnn_criterion(cnn_outputs_weighted, labels)
            context_loss.backward()
            context_optimizer.step()
            total_context_loss += context_loss.item()
            num_batches += 1
        context_scheduler.step()
        print(f"Pretrain Epoch {pretrain_epoch+1}/20, Loss: {total_context_loss/num_batches:.4f}")
    
    print("Starting adversarial training on full dataset...")
    target_update_counter = 0
    TARGET_UPDATE_FREQ = 100
    
    for epoch in range(fine_tune_epochs):
        cnn_model.eval()
        context_model.train()
        dqn_agent.policy_net.train()
        
        running_context_loss = 0.0
        running_dqn_loss = 0.0
        dqn_loss_count = 0
        total_samples = 0
        context_updated_samples = 0
        rewards = []
        actions = []
        context_updated = False
        
        for inputs, labels in full_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            batch_size = inputs.size(0)
            total_samples += batch_size
            
            # Compute CNN outputs and state for DQN
            with torch.no_grad():
                cnn_outputs = cnn_model(inputs).detach()
                probs = softmax(cnn_outputs)
                _, cnn_pred = torch.max(cnn_outputs, 1)
                max_prob, _ = torch.max(probs, dim=1, keepdim=True)
                uncertainty = 1 - max_prob
            
            features = inputs.squeeze(1).detach()
            state = torch.cat([features, uncertainty], dim=1).detach()
            
            # Select actions for all samples in batch
            actions_batch = dqn_agent.select_action(state)
            actions.extend(actions_batch.cpu().tolist())
            
            # Find indices where action=1
            action_mask = (actions_batch == 1).cpu()
            action_indices = action_mask.nonzero(as_tuple=True)[0]
            
            # Update ContextAwareNetwork only for samples with action=1
            if len(action_indices) > 0:
                context_updated = True
                context_updated_samples += len(action_indices)
                
                selected_inputs = inputs[action_indices]
                selected_labels = labels[action_indices]
                
                # Handle batch size 1
                if selected_inputs.size(0) == 1:
                    selected_inputs = torch.cat([selected_inputs, selected_inputs], dim=0)
                    selected_labels = torch.cat([selected_labels, selected_labels], dim=0)
                
                context_optimizer.zero_grad()
                encoded_inputs = context_model(selected_inputs)
                cnn_outputs_weighted = cnn_model(encoded_inputs)
                context_loss = cnn_criterion(cnn_outputs_weighted, selected_labels)
                orig_cnn_loss = cnn_criterion(cnn_model(selected_inputs), selected_labels)
                epsilon = 1e-8
                loss_ratio = orig_cnn_loss / (context_loss + epsilon)
                total_context_loss = 0.8 * context_loss + 0.2 / (1 + loss_ratio)
                total_context_loss = torch.clamp(total_context_loss, max=1.0)
                total_context_loss.backward()
                context_optimizer.step()
                running_context_loss += total_context_loss.item() * len(action_indices)
            
            # Compute rewards and next states
            with torch.no_grad():
                encoded_inputs = context_model(inputs).detach()
                cnn_outputs_weighted = cnn_model(encoded_inputs).detach()
                _, weighted_pred = torch.max(cnn_outputs_weighted, 1)
            
            # Compute rewards for all samples
            batch_rewards = []
            for i in range(batch_size):
                r = compute_reward(actions_batch[i].item(), cnn_pred[i].item(), weighted_pred[i].item(), labels[i].item())
                batch_rewards.append(r)
            rewards.extend(batch_rewards)
            
            # Compute next states based on action
            with torch.no_grad():
                if len(action_indices) > 0:
                    cnn_outputs_new = cnn_model(context_model(inputs)).detach()
                    probs_new = softmax(cnn_outputs_new)
                    max_prob_new, _ = torch.max(probs_new, dim=1, keepdim=True)
                    uncertainty_new = 1 - max_prob_new
                    features_new = inputs.squeeze(1).detach()
                    next_state_new = torch.cat([features_new, uncertainty_new], dim=1).detach()
                else:
                    next_state_new = state
            
            # Push to replay buffer for ALL actions
            for i in range(batch_size):
                if actions_batch[i] == 1 and len(action_indices) > 0:
                    next_state = next_state_new[i:i+1]
                else:
                    next_state = state[i:i+1]
                
                dqn_agent.replay_buffer.push(
                    state[i:i+1],
                    actions_batch[i].item(),
                    batch_rewards[i],
                    next_state,
                    1.0
                )
                target_update_counter += 1
            
            # Update target network every N steps
            if target_update_counter >= TARGET_UPDATE_FREQ:
                dqn_agent.update_target_network()
                target_update_counter = 0
            
            # Optimize DQN
            dqn_loss = dqn_agent.optimize()
            if dqn_loss is not None:
                running_dqn_loss += dqn_loss
                dqn_loss_count += 1
        
        if context_updated:
            context_scheduler.step()
        
        dqn_agent.update_epsilon()
        
        if epoch % 5 == 0:
            dqn_agent.update_target_network()
        
        avg_reward = np.mean(rewards) if rewards else 0.0
        action_dist = np.bincount(actions, minlength=2) if actions else [0, 0]
        
        print(f"Adversarial Epoch {epoch+1}/{fine_tune_epochs}:")
        print(f"  Context Loss: {running_context_loss / max(context_updated_samples, 1):.4f}")
        print(f"  DQN Loss: {running_dqn_loss / max(dqn_loss_count, 1):.4f}")
        print(f"  Context Updated Samples: {context_updated_samples}")
        print(f"  Average Reward: {avg_reward:.4f}")
        print(f"  Action Distribution (skip/apply): {action_dist}")
        
        # Validation
        val_results = evaluate_model(cnn_model, val_loader, class_weights, context_model, dqn_agent, threshold=0.5)
        print(f"Validation Results at Epoch {epoch+1}:")
        print(f"  Val Loss: {val_results['Test Loss']:.4f}")
        print(f"  Val Accuracy: {val_results['Accuracy']:.4f}")
        print(f"  Val Precision: {val_results['Precision']:.4f}")
        print(f"  Val Recall: {val_results['Recall']:.4f}")
        print(f"  Val F1 Score: {val_results['F1 Score']:.4f}")
        
        if val_results['Accuracy'] > best_val_accuracy:
            best_val_accuracy = val_results['Accuracy']
            epochs_no_improve = 0
            best_context_state = context_model.state_dict().copy()
            best_dqn_state = dqn_agent.policy_net.state_dict().copy()
            print(f"✓ Updated best adversarial model states (Accuracy: {best_val_accuracy:.4f})")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs.")
                break
    
    # Load best models
    if best_context_state is not None:
        context_model.load_state_dict(best_context_state)
        print("Loaded best context model")
    
    if best_dqn_state is not None:
        dqn_agent.policy_net.load_state_dict(best_dqn_state)
        print("Loaded best DQN model")
    
    # Save best models
    os.makedirs('Models', exist_ok=True)
    
    torch.save({
        'context_model_state_dict': context_model.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes
    }, 'Models/adversarial_best_context.pth')
    print("Saved best adversarial Context model")
    
    torch.save({
        'dqn_policy_net_state_dict': dqn_agent.policy_net.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes,
        'replay_buffer': list(dqn_agent.replay_buffer.buffer)
    }, 'Models/adversarial_best_dqn.pth')
    print("Saved best adversarial DQN model with replay buffer")
    
    return cnn_model, dqn_agent, context_model

# Main execution
def main():
    base_epoch = 200
    base_patience = 50
    adver_epoch = 200
    adver_patience = 20
    
    print("=" * 60)
    print("Starting Adversarial Training System for Network Traffic Classification")
    print("=" * 60)
    
    # Load data
    train_loader, val_loader, test_loader, full_loader, num_classes, input_length, class_counts = load_data()
    if train_loader is None or full_loader is None:
        print("Failed to load data. Exiting.")
        return
    
    print(f"\nDataset Statistics:")
    print(f"  - Number of classes: {num_classes}")
    print(f"  - Input feature length: {input_length}")
    print(f"  - Class distribution (train): {class_counts}")
    
    # Train and evaluate initial CNN
    print("\n" + "=" * 60)
    print("Training Initial CNN Model")
    print("=" * 60)
    
    cnn_model = CNN1D(input_length, num_classes).to(device)
    cnn_model = train_initial_cnn(cnn_model, train_loader, val_loader, class_counts, base_epoch, base_patience)
    
    os.makedirs('Models', exist_ok=True)
    
    torch.save({
        'model_state_dict': cnn_model.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes
    }, 'Models/initial_cnn_model.pth')
    print("Saved initial CNN model")
    
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    initial_results = evaluate_model(cnn_model, test_loader, class_weights)
    print("\n" + "=" * 60)
    print("Initial CNN Test Results:")
    print("=" * 60)
    print(f"  Test Loss: {initial_results['Test Loss']:.4f}")
    print(f"  Accuracy: {initial_results['Accuracy']:.4f}")
    print(f"  Precision: {initial_results['Precision']:.4f}")
    print(f"  Recall: {initial_results['Recall']:.4f}")
    print(f"  F1 Score: {initial_results['F1 Score']:.4f}")
    
    # Initialize DQN and Context models
    print("\n" + "=" * 60)
    print("Initializing Adversarial Components")
    print("=" * 60)
    
    dqn_agent = DQNSelectorAgent(input_length + 1, device)
    context_model = ContextAwareNetwork(input_length).to(device)
    
    print(f"DQN Agent initialized with input size: {input_length + 1}")
    print(f"Context Model initialized with input size: {input_length}")
    
    # Train adversarial system
    print("\n" + "=" * 60)
    print("Starting Adversarial Training")
    print("=" * 60)
    
    cnn_model, dqn_agent, context_model = train_adversarial_system(
        cnn_model, dqn_agent, context_model, full_loader, val_loader, class_counts, 
        input_length, num_classes, adver_epoch, adver_patience
    )
    
    # Evaluate adversarial system
    print("\n" + "=" * 60)
    print("Final Evaluation - Adversarial System")
    print("=" * 60)
    
    adversarial_results = evaluate_model(cnn_model, test_loader, class_weights, context_model, dqn_agent, threshold=0.5)
    print("Adversarial System Test Results:")
    print(f"  Test Loss: {adversarial_results['Test Loss']:.4f}")
    print(f"  Accuracy: {adversarial_results['Accuracy']:.4f}")
    print(f"  Precision: {adversarial_results['Precision']:.4f}")
    print(f"  Recall: {adversarial_results['Recall']:.4f}")
    print(f"  F1 Score: {adversarial_results['F1 Score']:.4f}")
    
    # Comparison
    print("\n" + "=" * 60)
    print("Performance Improvement Summary")
    print("=" * 60)
    print(f"Accuracy Improvement: {(adversarial_results['Accuracy'] - initial_results['Accuracy']) * 100:+.2f}%")
    print(f"F1 Score Improvement: {(adversarial_results['F1 Score'] - initial_results['F1 Score']) * 100:+.2f}%")
    print(f"Precision Improvement: {(adversarial_results['Precision'] - initial_results['Precision']) * 100:+.2f}%")
    print(f"Recall Improvement: {(adversarial_results['Recall'] - initial_results['Recall']) * 100:+.2f}%")
    
    print("\nTraining completed successfully!")
# Out:
# Using device: cuda

# %% [markdown]
# ## RUN

# %%
if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Starting Adversarial Training System for Network Traffic Classification
# ============================================================
# Detected 5 classes in the dataset
# Classes: ['AmazonEcho' 'BelkinCamera' 'NetatmoWeatherStation' 'PhilipsHue' 'iHome']
# Class distribution in training data: [591 582 598 612 617]
# Class distribution in validation data: [194 215 204 199 188]
# Class distribution in test data: [215 203 198 189 195]
# Total training samples: 3000, validation samples: 1000, test samples: 1000
# Input length: 18
# Full dataset size for adversarial training: 3000
#
# Dataset Statistics:
#   - Number of classes: 5
#   - Input feature length: 18
#   - Class distribution (train): [591 582 598 612 617]
#
# ============================================================
# Training Initial CNN Model
# ============================================================
# Initial CNN Epoch 1/200, Train Loss: 1.4786, Val Loss: 1.2457, Val Accuracy: 0.5730
# Initial CNN Epoch 2/200, Train Loss: 0.9905, Val Loss: 0.7764, Val Accuracy: 0.7240
# Initial CNN Epoch 3/200, Train Loss: 0.7960, Val Loss: 0.6163, Val Accuracy: 0.7610
# Initial CNN Epoch 4/200, Train Loss: 0.6559, Val Loss: 0.6483, Val Accuracy: 0.8060
# Initial CNN Epoch 5/200, Train Loss: 0.5347, Val Loss: 0.4565, Val Accuracy: 0.8470
# Initial CNN Epoch 6/200, Train Loss: 0.4994, Val Loss: 0.3200, Val Accuracy: 0.8920
# Initial CNN Epoch 7/200, Train Loss: 0.4386, Val Loss: 0.2934, Val Accuracy: 0.8760
# Initial CNN Epoch 8/200, Train Loss: 0.3673, Val Loss: 0.2736, Val Accuracy: 0.9090
# Initial CNN Epoch 9/200, Train Loss: 0.3704, Val Loss: 0.4003, Val Accuracy: 0.8660
# Initial CNN Epoch 10/200, Train Loss: 0.3714, Val Loss: 0.2500, Val Accuracy: 0.8940
# Initial CNN Epoch 11/200, Train Loss: 0.3315, Val Loss: 0.2422, Val Accuracy: 0.9060
# Initial CNN Epoch 12/200, Train Loss: 0.3164, Val Loss: 0.2333, Val Accuracy: 0.8910
# Initial CNN Epoch 13/200, Train Loss: 0.2955, Val Loss: 0.4172, Val Accuracy: 0.8850
# Initial CNN Epoch 14/200, Train Loss: 0.2837, Val Loss: 0.2079, Val Accuracy: 0.9030
# Initial CNN Epoch 15/200, Train Loss: 0.2763, Val Loss: 0.1874, Val Accuracy: 0.9280
# Initial CNN Epoch 16/200, Train Loss: 0.2639, Val Loss: 0.2379, Val Accuracy: 0.8960
# Initial CNN Epoch 17/200, Train Loss: 0.2367, Val Loss: 0.1816, Val Accuracy: 0.9240
# Initial CNN Epoch 18/200, Train Loss: 0.2764, Val Loss: 0.2027, Val Accuracy: 0.9110
# Initial CNN Epoch 19/200, Train Loss: 0.2603, Val Loss: 0.2324, Val Accuracy: 0.9080
# Initial CNN Epoch 20/200, Train Loss: 0.2386, Val Loss: 0.2235, Val Accuracy: 0.9110
# Initial CNN Epoch 21/200, Train Loss: 0.2501, Val Loss: 0.2000, Val Accuracy: 0.8910
# Initial CNN Epoch 22/200, Train Loss: 0.2648, Val Loss: 0.3298, Val Accuracy: 0.8500
# Initial CNN Epoch 23/200, Train Loss: 0.2159, Val Loss: 0.1855, Val Accuracy: 0.9190
# Initial CNN Epoch 24/200, Train Loss: 0.2025, Val Loss: 0.2045, Val Accuracy: 0.9270
# Initial CNN Epoch 25/200, Train Loss: 0.2305, Val Loss: 0.4218, Val Accuracy: 0.8880
# Initial CNN Epoch 26/200, Train Loss: 0.2124, Val Loss: 0.3667, Val Accuracy: 0.8580
# Initial CNN Epoch 27/200, Train Loss: 0.2039, Val Loss: 0.1850, Val Accuracy: 0.9210
# Initial CNN Epoch 28/200, Train Loss: 0.1847, Val Loss: 0.1814, Val Accuracy: 0.9280
# Initial CNN Epoch 29/200, Train Loss: 0.1923, Val Loss: 0.4980, Val Accuracy: 0.8390
# Initial CNN Epoch 30/200, Train Loss: 0.2123, Val Loss: 0.1794, Val Accuracy: 0.9250
# Initial CNN Epoch 31/200, Train Loss: 0.2028, Val Loss: 0.1655, Val Accuracy: 0.9190
# Initial CNN Epoch 32/200, Train Loss: 0.1913, Val Loss: 0.1558, Val Accuracy: 0.9270
# Initial CNN Epoch 33/200, Train Loss: 0.1844, Val Loss: 0.4384, Val Accuracy: 0.8750
# Initial CNN Epoch 34/200, Train Loss: 0.1864, Val Loss: 0.1675, Val Accuracy: 0.9190
# Initial CNN Epoch 35/200, Train Loss: 0.1838, Val Loss: 0.1628, Val Accuracy: 0.9230
# Initial CNN Epoch 36/200, Train Loss: 0.1891, Val Loss: 0.1433, Val Accuracy: 0.9310
# Initial CNN Epoch 37/200, Train Loss: 0.1843, Val Loss: 0.1539, Val Accuracy: 0.9300
# Initial CNN Epoch 38/200, Train Loss: 0.1831, Val Loss: 0.1800, Val Accuracy: 0.9150
# Initial CNN Epoch 39/200, Train Loss: 0.1833, Val Loss: 0.1534, Val Accuracy: 0.9310
# Initial CNN Epoch 40/200, Train Loss: 0.1685, Val Loss: 0.2194, Val Accuracy: 0.9170
# Initial CNN Epoch 41/200, Train Loss: 0.1717, Val Loss: 0.2094, Val Accuracy: 0.9080
# Initial CNN Epoch 42/200, Train Loss: 0.1801, Val Loss: 0.1591, Val Accuracy: 0.9300
# Initial CNN Epoch 43/200, Train Loss: 0.1717, Val Loss: 0.1428, Val Accuracy: 0.9460
# Initial CNN Epoch 44/200, Train Loss: 0.1751, Val Loss: 0.1479, Val Accuracy: 0.9500
# Initial CNN Epoch 45/200, Train Loss: 0.1510, Val Loss: 0.1612, Val Accuracy: 0.9200
# Initial CNN Epoch 46/200, Train Loss: 0.1627, Val Loss: 0.1448, Val Accuracy: 0.9360
# Initial CNN Epoch 47/200, Train Loss: 0.1665, Val Loss: 0.2166, Val Accuracy: 0.9130
# Initial CNN Epoch 48/200, Train Loss: 0.1680, Val Loss: 0.1674, Val Accuracy: 0.9310
# Initial CNN Epoch 49/200, Train Loss: 0.1396, Val Loss: 0.1285, Val Accuracy: 0.9460
# Initial CNN Epoch 50/200, Train Loss: 0.1375, Val Loss: 0.1779, Val Accuracy: 0.9330
# Initial CNN Epoch 51/200, Train Loss: 0.1554, Val Loss: 0.1653, Val Accuracy: 0.9300
# Initial CNN Epoch 52/200, Train Loss: 0.1335, Val Loss: 0.1280, Val Accuracy: 0.9420
# Initial CNN Epoch 53/200, Train Loss: 0.1344, Val Loss: 0.1166, Val Accuracy: 0.9480
# Initial CNN Epoch 54/200, Train Loss: 0.1335, Val Loss: 0.1696, Val Accuracy: 0.9320
# Initial CNN Epoch 55/200, Train Loss: 0.1631, Val Loss: 0.1423, Val Accuracy: 0.9410
# Initial CNN Epoch 56/200, Train Loss: 0.1221, Val Loss: 0.1314, Val Accuracy: 0.9450
# Initial CNN Epoch 57/200, Train Loss: 0.1473, Val Loss: 0.1428, Val Accuracy: 0.9470
# Initial CNN Epoch 58/200, Train Loss: 0.1566, Val Loss: 0.1496, Val Accuracy: 0.9430
# Initial CNN Epoch 59/200, Train Loss: 0.1148, Val Loss: 0.1418, Val Accuracy: 0.9440
# Initial CNN Epoch 60/200, Train Loss: 0.1242, Val Loss: 0.1474, Val Accuracy: 0.9310
# Initial CNN Epoch 61/200, Train Loss: 0.1373, Val Loss: 0.1348, Val Accuracy: 0.9320
# Initial CNN Epoch 62/200, Train Loss: 0.1395, Val Loss: 0.1281, Val Accuracy: 0.9520
# Initial CNN Epoch 63/200, Train Loss: 0.1454, Val Loss: 0.1373, Val Accuracy: 0.9550
# Initial CNN Epoch 64/200, Train Loss: 0.1389, Val Loss: 0.1294, Val Accuracy: 0.9510
# Initial CNN Epoch 65/200, Train Loss: 0.1063, Val Loss: 0.1351, Val Accuracy: 0.9510
# Initial CNN Epoch 66/200, Train Loss: 0.1091, Val Loss: 0.1275, Val Accuracy: 0.9560
# Initial CNN Epoch 67/200, Train Loss: 0.1184, Val Loss: 0.1218, Val Accuracy: 0.9470
# Initial CNN Epoch 68/200, Train Loss: 0.1166, Val Loss: 0.1220, Val Accuracy: 0.9480
# Initial CNN Epoch 69/200, Train Loss: 0.1120, Val Loss: 0.1302, Val Accuracy: 0.9480
# Initial CNN Epoch 70/200, Train Loss: 0.1371, Val Loss: 0.1459, Val Accuracy: 0.9290
# Initial CNN Epoch 71/200, Train Loss: 0.1164, Val Loss: 0.1084, Val Accuracy: 0.9470
# Initial CNN Epoch 72/200, Train Loss: 0.1165, Val Loss: 0.1761, Val Accuracy: 0.9360
# Initial CNN Epoch 73/200, Train Loss: 0.1146, Val Loss: 0.1066, Val Accuracy: 0.9620
# Initial CNN Epoch 74/200, Train Loss: 0.1032, Val Loss: 0.1052, Val Accuracy: 0.9520
# Initial CNN Epoch 75/200, Train Loss: 0.0966, Val Loss: 0.1176, Val Accuracy: 0.9600
# Initial CNN Epoch 76/200, Train Loss: 0.1241, Val Loss: 0.2082, Val Accuracy: 0.9130
# Initial CNN Epoch 77/200, Train Loss: 0.1488, Val Loss: 0.1397, Val Accuracy: 0.9430
# Initial CNN Epoch 78/200, Train Loss: 0.1137, Val Loss: 0.1121, Val Accuracy: 0.9520
# Initial CNN Epoch 79/200, Train Loss: 0.1080, Val Loss: 0.1447, Val Accuracy: 0.9310
# Initial CNN Epoch 80/200, Train Loss: 0.1036, Val Loss: 0.1094, Val Accuracy: 0.9530
# Initial CNN Epoch 81/200, Train Loss: 0.1138, Val Loss: 0.1143, Val Accuracy: 0.9490
# Initial CNN Epoch 82/200, Train Loss: 0.1079, Val Loss: 0.1196, Val Accuracy: 0.9520
# Initial CNN Epoch 83/200, Train Loss: 0.0932, Val Loss: 0.1244, Val Accuracy: 0.9500
# Initial CNN Epoch 84/200, Train Loss: 0.1087, Val Loss: 0.1241, Val Accuracy: 0.9550
# Initial CNN Epoch 85/200, Train Loss: 0.1098, Val Loss: 0.1023, Val Accuracy: 0.9580
# Initial CNN Epoch 86/200, Train Loss: 0.1219, Val Loss: 0.1183, Val Accuracy: 0.9540
# Initial CNN Epoch 87/200, Train Loss: 0.0970, Val Loss: 0.1192, Val Accuracy: 0.9550
# Initial CNN Epoch 88/200, Train Loss: 0.0967, Val Loss: 0.1147, Val Accuracy: 0.9640
# Initial CNN Epoch 89/200, Train Loss: 0.0878, Val Loss: 0.1109, Val Accuracy: 0.9530
# Initial CNN Epoch 90/200, Train Loss: 0.0833, Val Loss: 0.1092, Val Accuracy: 0.9540
# Initial CNN Epoch 91/200, Train Loss: 0.0797, Val Loss: 0.1159, Val Accuracy: 0.9570
# Initial CNN Epoch 92/200, Train Loss: 0.1023, Val Loss: 0.1119, Val Accuracy: 0.9590
# Initial CNN Epoch 93/200, Train Loss: 0.0812, Val Loss: 0.1016, Val Accuracy: 0.9600
# Initial CNN Epoch 94/200, Train Loss: 0.0807, Val Loss: 0.1102, Val Accuracy: 0.9600
# Initial CNN Epoch 95/200, Train Loss: 0.1086, Val Loss: 0.1862, Val Accuracy: 0.9280
# Initial CNN Epoch 96/200, Train Loss: 0.0956, Val Loss: 0.1144, Val Accuracy: 0.9590
# Initial CNN Epoch 97/200, Train Loss: 0.0910, Val Loss: 0.1167, Val Accuracy: 0.9530
# Initial CNN Epoch 98/200, Train Loss: 0.0861, Val Loss: 0.1102, Val Accuracy: 0.9600
# Initial CNN Epoch 99/200, Train Loss: 0.1044, Val Loss: 0.2089, Val Accuracy: 0.9250
# Initial CNN Epoch 100/200, Train Loss: 0.0775, Val Loss: 0.1254, Val Accuracy: 0.9540
# Initial CNN Epoch 101/200, Train Loss: 0.0752, Val Loss: 0.1272, Val Accuracy: 0.9500
# Initial CNN Epoch 102/200, Train Loss: 0.0763, Val Loss: 0.1115, Val Accuracy: 0.9620
# Initial CNN Epoch 103/200, Train Loss: 0.0797, Val Loss: 0.0986, Val Accuracy: 0.9570
# Initial CNN Epoch 104/200, Train Loss: 0.0894, Val Loss: 0.1126, Val Accuracy: 0.9620
# Initial CNN Epoch 105/200, Train Loss: 0.0988, Val Loss: 0.1013, Val Accuracy: 0.9570
# Initial CNN Epoch 106/200, Train Loss: 0.0942, Val Loss: 0.1015, Val Accuracy: 0.9620
# Initial CNN Epoch 107/200, Train Loss: 0.0907, Val Loss: 0.1099, Val Accuracy: 0.9590
# Initial CNN Epoch 108/200, Train Loss: 0.0856, Val Loss: 0.0985, Val Accuracy: 0.9580
# Initial CNN Epoch 109/200, Train Loss: 0.0805, Val Loss: 0.1133, Val Accuracy: 0.9520
# Initial CNN Epoch 110/200, Train Loss: 0.0655, Val Loss: 0.1089, Val Accuracy: 0.9570
# Initial CNN Epoch 111/200, Train Loss: 0.0883, Val Loss: 0.1045, Val Accuracy: 0.9620
# Initial CNN Epoch 112/200, Train Loss: 0.0711, Val Loss: 0.1099, Val Accuracy: 0.9640
# Initial CNN Epoch 113/200, Train Loss: 0.0776, Val Loss: 0.1108, Val Accuracy: 0.9560
# Initial CNN Epoch 114/200, Train Loss: 0.0792, Val Loss: 0.0999, Val Accuracy: 0.9590
# Initial CNN Epoch 115/200, Train Loss: 0.0703, Val Loss: 0.1074, Val Accuracy: 0.9650
# Initial CNN Epoch 116/200, Train Loss: 0.0837, Val Loss: 0.1278, Val Accuracy: 0.9540
# Initial CNN Epoch 117/200, Train Loss: 0.0851, Val Loss: 0.1210, Val Accuracy: 0.9650
# Initial CNN Epoch 118/200, Train Loss: 0.0663, Val Loss: 0.1001, Val Accuracy: 0.9580
# Initial CNN Epoch 119/200, Train Loss: 0.0863, Val Loss: 0.1015, Val Accuracy: 0.9580
# Initial CNN Epoch 120/200, Train Loss: 0.0894, Val Loss: 0.0968, Val Accuracy: 0.9630
# Initial CNN Epoch 121/200, Train Loss: 0.0783, Val Loss: 0.1069, Val Accuracy: 0.9540
# Initial CNN Epoch 122/200, Train Loss: 0.0838, Val Loss: 0.0947, Val Accuracy: 0.9630
# Initial CNN Epoch 123/200, Train Loss: 0.0792, Val Loss: 0.0890, Val Accuracy: 0.9640
# Initial CNN Epoch 124/200, Train Loss: 0.0688, Val Loss: 0.0990, Val Accuracy: 0.9680
# Initial CNN Epoch 125/200, Train Loss: 0.0731, Val Loss: 0.1017, Val Accuracy: 0.9570
# Initial CNN Epoch 126/200, Train Loss: 0.0775, Val Loss: 0.1045, Val Accuracy: 0.9610
# Initial CNN Epoch 127/200, Train Loss: 0.0779, Val Loss: 0.1024, Val Accuracy: 0.9580
# Initial CNN Epoch 128/200, Train Loss: 0.0708, Val Loss: 0.1050, Val Accuracy: 0.9690
# Initial CNN Epoch 129/200, Train Loss: 0.0721, Val Loss: 0.1018, Val Accuracy: 0.9660
# Initial CNN Epoch 130/200, Train Loss: 0.0677, Val Loss: 0.0949, Val Accuracy: 0.9660
# Initial CNN Epoch 131/200, Train Loss: 0.0650, Val Loss: 0.1041, Val Accuracy: 0.9660
# Initial CNN Epoch 132/200, Train Loss: 0.0712, Val Loss: 0.0982, Val Accuracy: 0.9610
# Initial CNN Epoch 133/200, Train Loss: 0.0678, Val Loss: 0.1001, Val Accuracy: 0.9610
# Initial CNN Epoch 134/200, Train Loss: 0.0883, Val Loss: 0.1552, Val Accuracy: 0.9160
# Initial CNN Epoch 135/200, Train Loss: 0.0645, Val Loss: 0.1043, Val Accuracy: 0.9650
# Initial CNN Epoch 136/200, Train Loss: 0.0729, Val Loss: 0.0997, Val Accuracy: 0.9610
# Initial CNN Epoch 137/200, Train Loss: 0.0626, Val Loss: 0.1076, Val Accuracy: 0.9560
# Initial CNN Epoch 138/200, Train Loss: 0.0675, Val Loss: 0.0976, Val Accuracy: 0.9640
# Initial CNN Epoch 139/200, Train Loss: 0.0684, Val Loss: 0.1030, Val Accuracy: 0.9610
# Initial CNN Epoch 140/200, Train Loss: 0.0556, Val Loss: 0.1071, Val Accuracy: 0.9590
# Initial CNN Epoch 141/200, Train Loss: 0.0748, Val Loss: 0.0963, Val Accuracy: 0.9630
# Initial CNN Epoch 142/200, Train Loss: 0.0669, Val Loss: 0.1044, Val Accuracy: 0.9580
# Initial CNN Epoch 143/200, Train Loss: 0.0751, Val Loss: 0.1047, Val Accuracy: 0.9610
# Initial CNN Epoch 144/200, Train Loss: 0.0700, Val Loss: 0.1088, Val Accuracy: 0.9640
# Initial CNN Epoch 145/200, Train Loss: 0.0634, Val Loss: 0.0943, Val Accuracy: 0.9650
# Initial CNN Epoch 146/200, Train Loss: 0.0669, Val Loss: 0.0972, Val Accuracy: 0.9630
# Initial CNN Epoch 147/200, Train Loss: 0.0519, Val Loss: 0.0985, Val Accuracy: 0.9630
# Initial CNN Epoch 148/200, Train Loss: 0.0686, Val Loss: 0.1000, Val Accuracy: 0.9610
# Initial CNN Epoch 149/200, Train Loss: 0.0614, Val Loss: 0.0990, Val Accuracy: 0.9630
# Initial CNN Epoch 150/200, Train Loss: 0.0666, Val Loss: 0.1048, Val Accuracy: 0.9590
# Initial CNN Epoch 151/200, Train Loss: 0.0640, Val Loss: 0.1012, Val Accuracy: 0.9620
# Initial CNN Epoch 152/200, Train Loss: 0.0676, Val Loss: 0.0958, Val Accuracy: 0.9630
# Initial CNN Epoch 153/200, Train Loss: 0.0633, Val Loss: 0.1049, Val Accuracy: 0.9610
# Initial CNN Epoch 154/200, Train Loss: 0.0609, Val Loss: 0.1094, Val Accuracy: 0.9590
# Initial CNN Epoch 155/200, Train Loss: 0.0787, Val Loss: 0.0989, Val Accuracy: 0.9620
# Initial CNN Epoch 156/200, Train Loss: 0.0770, Val Loss: 0.0987, Val Accuracy: 0.9620
# Initial CNN Epoch 157/200, Train Loss: 0.0574, Val Loss: 0.1027, Val Accuracy: 0.9620
# Initial CNN Epoch 158/200, Train Loss: 0.0573, Val Loss: 0.0974, Val Accuracy: 0.9620
# Initial CNN Epoch 159/200, Train Loss: 0.0642, Val Loss: 0.0956, Val Accuracy: 0.9640
# Initial CNN Epoch 160/200, Train Loss: 0.0644, Val Loss: 0.1423, Val Accuracy: 0.9520
# Initial CNN Epoch 161/200, Train Loss: 0.0632, Val Loss: 0.0986, Val Accuracy: 0.9650
# Initial CNN Epoch 162/200, Train Loss: 0.0653, Val Loss: 0.1029, Val Accuracy: 0.9660
# Initial CNN Epoch 163/200, Train Loss: 0.0630, Val Loss: 0.1038, Val Accuracy: 0.9570
# Initial CNN Epoch 164/200, Train Loss: 0.0580, Val Loss: 0.0943, Val Accuracy: 0.9630
# Initial CNN Epoch 165/200, Train Loss: 0.0732, Val Loss: 0.0972, Val Accuracy: 0.9570
# Initial CNN Epoch 166/200, Train Loss: 0.0736, Val Loss: 0.0971, Val Accuracy: 0.9650
# Initial CNN Epoch 167/200, Train Loss: 0.0667, Val Loss: 0.0970, Val Accuracy: 0.9600
# Initial CNN Epoch 168/200, Train Loss: 0.0636, Val Loss: 0.1069, Val Accuracy: 0.9600
# Initial CNN Epoch 169/200, Train Loss: 0.0695, Val Loss: 0.0979, Val Accuracy: 0.9590
# Initial CNN Epoch 170/200, Train Loss: 0.0580, Val Loss: 0.0958, Val Accuracy: 0.9650
# Initial CNN Epoch 171/200, Train Loss: 0.0644, Val Loss: 0.0990, Val Accuracy: 0.9680
# Initial CNN Epoch 172/200, Train Loss: 0.0695, Val Loss: 0.0950, Val Accuracy: 0.9660
# Initial CNN Epoch 173/200, Train Loss: 0.0605, Val Loss: 0.1041, Val Accuracy: 0.9650
# Early stopping triggered after 173 epochs.
# Saved initial CNN model
#
# ============================================================
# Initial CNN Test Results:
# ============================================================
#   Test Loss: 0.0732
#   Accuracy: 0.9670
#   Precision: 0.9682
#   Recall: 0.9670
#   F1 Score: 0.9673
#
# ============================================================
# Initializing Adversarial Components
# ============================================================
# Selected num_heads=2 for input_size=18
# DQN Agent initialized with input size: 19
# Context Model initialized with input size: 18
#
# ============================================================
# Starting Adversarial Training
# ============================================================
# Pre-training ContextAwareNetwork...
# Pretrain Epoch 1/20, Loss: 2.0192
# Pretrain Epoch 2/20, Loss: 1.5681
# Pretrain Epoch 3/20, Loss: 1.3125
# Pretrain Epoch 4/20, Loss: 1.1405
# Pretrain Epoch 5/20, Loss: 0.9582
# Pretrain Epoch 6/20, Loss: 0.7596
# Pretrain Epoch 7/20, Loss: 0.6879
# Pretrain Epoch 8/20, Loss: 0.6473
# Pretrain Epoch 9/20, Loss: 0.5852
# Pretrain Epoch 10/20, Loss: 0.5570
# Pretrain Epoch 11/20, Loss: 0.5023
# Pretrain Epoch 12/20, Loss: 0.4662
# Pretrain Epoch 13/20, Loss: 0.3995
# Pretrain Epoch 14/20, Loss: 0.3838
# Pretrain Epoch 15/20, Loss: 0.3463
# Pretrain Epoch 16/20, Loss: 0.3171
# Pretrain Epoch 17/20, Loss: 0.2832
# Pretrain Epoch 18/20, Loss: 0.2911
# Pretrain Epoch 19/20, Loss: 0.2832
# Pretrain Epoch 20/20, Loss: 0.2767
# Starting adversarial training on full dataset...
# Adversarial Epoch 1/200:
#   Context Loss: 0.4015
#   DQN Loss: 1.1572
#   Context Updated Samples: 1505
#   Average Reward: 0.6503
#   Action Distribution (skip/apply): [1495 1505]
# Validation Results at Epoch 1:
#   Val Loss: 0.3296
#   Val Accuracy: 0.8730
#   Val Precision: 0.8808
#   Val Recall: 0.8730
#   Val F1 Score: 0.8730
# ✓ Updated best adversarial model states (Accuracy: 0.8730)
# Adversarial Epoch 2/200:
#   Context Loss: 0.4611
#   DQN Loss: 0.9153
#   Context Updated Samples: 1519
#   Average Reward: 0.6458
#   Action Distribution (skip/apply): [1481 1519]
# Validation Results at Epoch 2:
#   Val Loss: 0.3326
#   Val Accuracy: 0.8680
#   Val Precision: 0.8731
#   Val Recall: 0.8680
#   Val F1 Score: 0.8689
# Adversarial Epoch 3/200:
#   Context Loss: 0.4734
#   DQN Loss: 0.7149
#   Context Updated Samples: 1500
#   Average Reward: 0.6425
#   Action Distribution (skip/apply): [1500 1500]
# Validation Results at Epoch 3:
#   Val Loss: 0.4047
#   Val Accuracy: 0.8510
#   Val Precision: 0.8580
#   Val Recall: 0.8510
#   Val F1 Score: 0.8501
# Adversarial Epoch 4/200:
#   Context Loss: 0.4104
#   DQN Loss: 0.5784
#   Context Updated Samples: 1406
#   Average Reward: 0.6997
#   Action Distribution (skip/apply): [1594 1406]
# Validation Results at Epoch 4:
#   Val Loss: 0.3149
#   Val Accuracy: 0.8790
#   Val Precision: 0.8825
#   Val Recall: 0.8790
#   Val F1 Score: 0.8773
# ✓ Updated best adversarial model states (Accuracy: 0.8790)
# Adversarial Epoch 5/200:
#   Context Loss: 0.4253
#   DQN Loss: 0.5068
#   Context Updated Samples: 1423
#   Average Reward: 0.6842
#   Action Distribution (skip/apply): [1577 1423]
# Validation Results at Epoch 5:
#   Val Loss: 0.4957
#   Val Accuracy: 0.8160
#   Val Precision: 0.8264
#   Val Recall: 0.8160
#   Val F1 Score: 0.8152
# Adversarial Epoch 6/200:
#   Context Loss: 0.4386
#   DQN Loss: 0.4269
#   Context Updated Samples: 1484
#   Average Reward: 0.6607
#   Action Distribution (skip/apply): [1516 1484]
# Validation Results at Epoch 6:
#   Val Loss: 0.3042
#   Val Accuracy: 0.8890
#   Val Precision: 0.8909
#   Val Recall: 0.8890
#   Val F1 Score: 0.8890
# ✓ Updated best adversarial model states (Accuracy: 0.8890)
# Adversarial Epoch 7/200:
#   Context Loss: 0.4025
#   DQN Loss: 0.4441
#   Context Updated Samples: 1469
#   Average Reward: 0.6735
#   Action Distribution (skip/apply): [1531 1469]
# Validation Results at Epoch 7:
#   Val Loss: 0.2989
#   Val Accuracy: 0.8810
#   Val Precision: 0.8862
#   Val Recall: 0.8810
#   Val F1 Score: 0.8796
# Adversarial Epoch 8/200:
#   Context Loss: 0.3937
#   DQN Loss: 0.4316
#   Context Updated Samples: 1393
#   Average Reward: 0.7280
#   Action Distribution (skip/apply): [1607 1393]
# Validation Results at Epoch 8:
#   Val Loss: 0.2982
#   Val Accuracy: 0.8920
#   Val Precision: 0.8964
#   Val Recall: 0.8920
#   Val F1 Score: 0.8920
# ✓ Updated best adversarial model states (Accuracy: 0.8920)
# Adversarial Epoch 9/200:
#   Context Loss: 0.3887
#   DQN Loss: 0.3980
#   Context Updated Samples: 1442
#   Average Reward: 0.6920
#   Action Distribution (skip/apply): [1558 1442]
# Validation Results at Epoch 9:
#   Val Loss: 0.2756
#   Val Accuracy: 0.8890
#   Val Precision: 0.8942
#   Val Recall: 0.8890
#   Val F1 Score: 0.8894
# Adversarial Epoch 10/200:
#   Context Loss: 0.3799
#   DQN Loss: 0.4315
#   Context Updated Samples: 1447
#   Average Reward: 0.7052
#   Action Distribution (skip/apply): [1553 1447]
# Validation Results at Epoch 10:
#   Val Loss: 0.2790
#   Val Accuracy: 0.8930
#   Val Precision: 0.8984
#   Val Recall: 0.8930
#   Val F1 Score: 0.8931
# ✓ Updated best adversarial model states (Accuracy: 0.8930)
# Adversarial Epoch 11/200:
#   Context Loss: 0.4025
#   DQN Loss: 0.4066
#   Context Updated Samples: 1336
#   Average Reward: 0.7500
#   Action Distribution (skip/apply): [1664 1336]
# Validation Results at Epoch 11:
#   Val Loss: 0.2615
#   Val Accuracy: 0.8950
#   Val Precision: 0.8983
#   Val Recall: 0.8950
#   Val F1 Score: 0.8951
# ✓ Updated best adversarial model states (Accuracy: 0.8950)
# Adversarial Epoch 12/200:
#   Context Loss: 0.3656
#   DQN Loss: 0.4075
#   Context Updated Samples: 1375
#   Average Reward: 0.7320
#   Action Distribution (skip/apply): [1625 1375]
# Validation Results at Epoch 12:
#   Val Loss: 0.2871
#   Val Accuracy: 0.8830
#   Val Precision: 0.8881
#   Val Recall: 0.8830
#   Val F1 Score: 0.8832
# Adversarial Epoch 13/200:
#   Context Loss: 0.3777
#   DQN Loss: 0.4132
#   Context Updated Samples: 1281
#   Average Reward: 0.7773
#   Action Distribution (skip/apply): [1719 1281]
# Validation Results at Epoch 13:
#   Val Loss: 0.2499
#   Val Accuracy: 0.9030
#   Val Precision: 0.9040
#   Val Recall: 0.9030
#   Val F1 Score: 0.9030
# ✓ Updated best adversarial model states (Accuracy: 0.9030)
# Adversarial Epoch 14/200:
#   Context Loss: 0.3622
#   DQN Loss: 0.3737
#   Context Updated Samples: 1487
#   Average Reward: 0.6885
#   Action Distribution (skip/apply): [1513 1487]
# Validation Results at Epoch 14:
#   Val Loss: 0.2632
#   Val Accuracy: 0.9070
#   Val Precision: 0.9099
#   Val Recall: 0.9070
#   Val F1 Score: 0.9069
# ✓ Updated best adversarial model states (Accuracy: 0.9070)
# Adversarial Epoch 15/200:
#   Context Loss: 0.3867
#   DQN Loss: 0.3690
#   Context Updated Samples: 1402
#   Average Reward: 0.7130
#   Action Distribution (skip/apply): [1598 1402]
# Validation Results at Epoch 15:
#   Val Loss: 0.3438
#   Val Accuracy: 0.8460
#   Val Precision: 0.8717
#   Val Recall: 0.8460
#   Val F1 Score: 0.8477
# Adversarial Epoch 16/200:
#   Context Loss: 0.3837
#   DQN Loss: 0.3622
#   Context Updated Samples: 1451
#   Average Reward: 0.6905
#   Action Distribution (skip/apply): [1549 1451]
# Validation Results at Epoch 16:
#   Val Loss: 0.2239
#   Val Accuracy: 0.9180
#   Val Precision: 0.9200
#   Val Recall: 0.9180
#   Val F1 Score: 0.9178
# ✓ Updated best adversarial model states (Accuracy: 0.9180)
# Adversarial Epoch 17/200:
#   Context Loss: 0.3498
#   DQN Loss: 0.3844
#   Context Updated Samples: 1462
#   Average Reward: 0.6942
#   Action Distribution (skip/apply): [1538 1462]
# Validation Results at Epoch 17:
#   Val Loss: 0.2279
#   Val Accuracy: 0.9180
#   Val Precision: 0.9188
#   Val Recall: 0.9180
#   Val F1 Score: 0.9175
# Adversarial Epoch 18/200:
#   Context Loss: 0.3388
#   DQN Loss: 0.3918
#   Context Updated Samples: 1390
#   Average Reward: 0.7440
#   Action Distribution (skip/apply): [1610 1390]
# Validation Results at Epoch 18:
#   Val Loss: 0.2287
#   Val Accuracy: 0.9060
#   Val Precision: 0.9091
#   Val Recall: 0.9060
#   Val F1 Score: 0.9064
# Adversarial Epoch 19/200:
#   Context Loss: 0.3559
#   DQN Loss: 0.3894
#   Context Updated Samples: 1299
#   Average Reward: 0.7932
#   Action Distribution (skip/apply): [1701 1299]
# Validation Results at Epoch 19:
#   Val Loss: 0.2438
#   Val Accuracy: 0.8990
#   Val Precision: 0.9035
#   Val Recall: 0.8990
#   Val F1 Score: 0.8992
# Adversarial Epoch 20/200:
#   Context Loss: 0.3244
#   DQN Loss: 0.3669
#   Context Updated Samples: 1371
#   Average Reward: 0.7633
#   Action Distribution (skip/apply): [1629 1371]
# Validation Results at Epoch 20:
#   Val Loss: 0.2583
#   Val Accuracy: 0.9060
#   Val Precision: 0.9078
#   Val Recall: 0.9060
#   Val F1 Score: 0.9057
# Adversarial Epoch 21/200:
#   Context Loss: 0.3292
#   DQN Loss: 0.3564
#   Context Updated Samples: 1448
#   Average Reward: 0.6923
#   Action Distribution (skip/apply): [1552 1448]
# Validation Results at Epoch 21:
#   Val Loss: 0.2062
#   Val Accuracy: 0.9230
#   Val Precision: 0.9249
#   Val Recall: 0.9230
#   Val F1 Score: 0.9229
# ✓ Updated best adversarial model states (Accuracy: 0.9230)
# Adversarial Epoch 22/200:
#   Context Loss: 0.3222
#   DQN Loss: 0.3434
#   Context Updated Samples: 1355
#   Average Reward: 0.7745
#   Action Distribution (skip/apply): [1645 1355]
# Validation Results at Epoch 22:
#   Val Loss: 0.2857
#   Val Accuracy: 0.9100
#   Val Precision: 0.9139
#   Val Recall: 0.9100
#   Val F1 Score: 0.9096
# Adversarial Epoch 23/200:
#   Context Loss: 0.3818
#   DQN Loss: 0.3395
#   Context Updated Samples: 1433
#   Average Reward: 0.7202
#   Action Distribution (skip/apply): [1567 1433]
# Validation Results at Epoch 23:
#   Val Loss: 0.2154
#   Val Accuracy: 0.9190
#   Val Precision: 0.9204
#   Val Recall: 0.9190
#   Val F1 Score: 0.9192
# Adversarial Epoch 24/200:
#   Context Loss: 0.3387
#   DQN Loss: 0.3347
#   Context Updated Samples: 1367
#   Average Reward: 0.7645
#   Action Distribution (skip/apply): [1633 1367]
# Validation Results at Epoch 24:
#   Val Loss: 0.1985
#   Val Accuracy: 0.9160
#   Val Precision: 0.9172
#   Val Recall: 0.9160
#   Val F1 Score: 0.9161
# Adversarial Epoch 25/200:
#   Context Loss: 0.3179
#   DQN Loss: 0.3357
#   Context Updated Samples: 1306
#   Average Reward: 0.7977
#   Action Distribution (skip/apply): [1694 1306]
# Validation Results at Epoch 25:
#   Val Loss: 0.1986
#   Val Accuracy: 0.9150
#   Val Precision: 0.9176
#   Val Recall: 0.9150
#   Val F1 Score: 0.9155
# Adversarial Epoch 26/200:
#   Context Loss: 0.2911
#   DQN Loss: 0.3249
#   Context Updated Samples: 1365
#   Average Reward: 0.7760
#   Action Distribution (skip/apply): [1635 1365]
# Validation Results at Epoch 26:
#   Val Loss: 0.1917
#   Val Accuracy: 0.9230
#   Val Precision: 0.9247
#   Val Recall: 0.9230
#   Val F1 Score: 0.9234
# Adversarial Epoch 27/200:
#   Context Loss: 0.2870
#   DQN Loss: 0.3399
#   Context Updated Samples: 1356
#   Average Reward: 0.7720
#   Action Distribution (skip/apply): [1644 1356]
# Validation Results at Epoch 27:
#   Val Loss: 0.1875
#   Val Accuracy: 0.9210
#   Val Precision: 0.9218
#   Val Recall: 0.9210
#   Val F1 Score: 0.9209
# Adversarial Epoch 28/200:
#   Context Loss: 0.3303
#   DQN Loss: 0.3106
#   Context Updated Samples: 1418
#   Average Reward: 0.7367
#   Action Distribution (skip/apply): [1582 1418]
# Validation Results at Epoch 28:
#   Val Loss: 0.1924
#   Val Accuracy: 0.9290
#   Val Precision: 0.9302
#   Val Recall: 0.9290
#   Val F1 Score: 0.9292
# ✓ Updated best adversarial model states (Accuracy: 0.9290)
# Adversarial Epoch 29/200:
#   Context Loss: 0.3242
#   DQN Loss: 0.2949
#   Context Updated Samples: 1224
#   Average Reward: 0.8188
#   Action Distribution (skip/apply): [1776 1224]
# Validation Results at Epoch 29:
#   Val Loss: 0.1786
#   Val Accuracy: 0.9280
#   Val Precision: 0.9302
#   Val Recall: 0.9280
#   Val F1 Score: 0.9284
# Adversarial Epoch 30/200:
#   Context Loss: 0.3130
#   DQN Loss: 0.3150
#   Context Updated Samples: 1220
#   Average Reward: 0.8300
#   Action Distribution (skip/apply): [1780 1220]
# Validation Results at Epoch 30:
#   Val Loss: 0.1637
#   Val Accuracy: 0.9410
#   Val Precision: 0.9426
#   Val Recall: 0.9410
#   Val F1 Score: 0.9413
# ✓ Updated best adversarial model states (Accuracy: 0.9410)
# Adversarial Epoch 31/200:
#   Context Loss: 0.3044
#   DQN Loss: 0.2953
#   Context Updated Samples: 1294
#   Average Reward: 0.7865
#   Action Distribution (skip/apply): [1706 1294]
# Validation Results at Epoch 31:
#   Val Loss: 0.1938
#   Val Accuracy: 0.9270
#   Val Precision: 0.9296
#   Val Recall: 0.9270
#   Val F1 Score: 0.9271
# Adversarial Epoch 32/200:
#   Context Loss: 0.2960
#   DQN Loss: 0.3132
#   Context Updated Samples: 1228
#   Average Reward: 0.8380
#   Action Distribution (skip/apply): [1772 1228]
# Validation Results at Epoch 32:
#   Val Loss: 0.1577
#   Val Accuracy: 0.9410
#   Val Precision: 0.9419
#   Val Recall: 0.9410
#   Val F1 Score: 0.9409
# Adversarial Epoch 33/200:
#   Context Loss: 0.3019
#   DQN Loss: 0.2997
#   Context Updated Samples: 1178
#   Average Reward: 0.8672
#   Action Distribution (skip/apply): [1822 1178]
# Validation Results at Epoch 33:
#   Val Loss: 0.1820
#   Val Accuracy: 0.9240
#   Val Precision: 0.9254
#   Val Recall: 0.9240
#   Val F1 Score: 0.9241
# Adversarial Epoch 34/200:
#   Context Loss: 0.3043
#   DQN Loss: 0.2795
#   Context Updated Samples: 1291
#   Average Reward: 0.7962
#   Action Distribution (skip/apply): [1709 1291]
# Validation Results at Epoch 34:
#   Val Loss: 0.1816
#   Val Accuracy: 0.9270
#   Val Precision: 0.9279
#   Val Recall: 0.9270
#   Val F1 Score: 0.9272
# Adversarial Epoch 35/200:
#   Context Loss: 0.2898
#   DQN Loss: 0.2880
#   Context Updated Samples: 1226
#   Average Reward: 0.8390
#   Action Distribution (skip/apply): [1774 1226]
# Validation Results at Epoch 35:
#   Val Loss: 0.1830
#   Val Accuracy: 0.9270
#   Val Precision: 0.9286
#   Val Recall: 0.9270
#   Val F1 Score: 0.9271
# Adversarial Epoch 36/200:
#   Context Loss: 0.2968
#   DQN Loss: 0.2713
#   Context Updated Samples: 1227
#   Average Reward: 0.8377
#   Action Distribution (skip/apply): [1773 1227]
# Validation Results at Epoch 36:
#   Val Loss: 0.1863
#   Val Accuracy: 0.9320
#   Val Precision: 0.9332
#   Val Recall: 0.9320
#   Val F1 Score: 0.9313
# Adversarial Epoch 37/200:
#   Context Loss: 0.3132
#   DQN Loss: 0.2863
#   Context Updated Samples: 1265
#   Average Reward: 0.8050
#   Action Distribution (skip/apply): [1735 1265]
# Validation Results at Epoch 37:
#   Val Loss: 0.1817
#   Val Accuracy: 0.9240
#   Val Precision: 0.9267
#   Val Recall: 0.9240
#   Val F1 Score: 0.9245
# Adversarial Epoch 38/200:
#   Context Loss: 0.2863
#   DQN Loss: 0.2807
#   Context Updated Samples: 1158
#   Average Reward: 0.8733
#   Action Distribution (skip/apply): [1842 1158]
# Validation Results at Epoch 38:
#   Val Loss: 0.1520
#   Val Accuracy: 0.9470
#   Val Precision: 0.9480
#   Val Recall: 0.9470
#   Val F1 Score: 0.9472
# ✓ Updated best adversarial model states (Accuracy: 0.9470)
# Adversarial Epoch 39/200:
#   Context Loss: 0.2667
#   DQN Loss: 0.2665
#   Context Updated Samples: 1222
#   Average Reward: 0.8538
#   Action Distribution (skip/apply): [1778 1222]
# Validation Results at Epoch 39:
#   Val Loss: 0.1609
#   Val Accuracy: 0.9410
#   Val Precision: 0.9416
#   Val Recall: 0.9410
#   Val F1 Score: 0.9412
# Adversarial Epoch 40/200:
#   Context Loss: 0.2852
#   DQN Loss: 0.2595
#   Context Updated Samples: 1215
#   Average Reward: 0.8328
#   Action Distribution (skip/apply): [1785 1215]
# Validation Results at Epoch 40:
#   Val Loss: 0.1533
#   Val Accuracy: 0.9430
#   Val Precision: 0.9456
#   Val Recall: 0.9430
#   Val F1 Score: 0.9435
# Adversarial Epoch 41/200:
#   Context Loss: 0.2848
#   DQN Loss: 0.2702
#   Context Updated Samples: 1171
#   Average Reward: 0.8825
#   Action Distribution (skip/apply): [1829 1171]
# Validation Results at Epoch 41:
#   Val Loss: 0.1523
#   Val Accuracy: 0.9370
#   Val Precision: 0.9379
#   Val Recall: 0.9370
#   Val F1 Score: 0.9368
# Adversarial Epoch 42/200:
#   Context Loss: 0.2730
#   DQN Loss: 0.2628
#   Context Updated Samples: 1410
#   Average Reward: 0.7502
#   Action Distribution (skip/apply): [1590 1410]
# Validation Results at Epoch 42:
#   Val Loss: 0.1423
#   Val Accuracy: 0.9530
#   Val Precision: 0.9533
#   Val Recall: 0.9530
#   Val F1 Score: 0.9531
# ✓ Updated best adversarial model states (Accuracy: 0.9530)
# Adversarial Epoch 43/200:
#   Context Loss: 0.2944
#   DQN Loss: 0.2517
#   Context Updated Samples: 1169
#   Average Reward: 0.8882
#   Action Distribution (skip/apply): [1831 1169]
# Validation Results at Epoch 43:
#   Val Loss: 0.1647
#   Val Accuracy: 0.9310
#   Val Precision: 0.9325
#   Val Recall: 0.9310
#   Val F1 Score: 0.9311
# Adversarial Epoch 44/200:
#   Context Loss: 0.2660
#   DQN Loss: 0.2648
#   Context Updated Samples: 1162
#   Average Reward: 0.8943
#   Action Distribution (skip/apply): [1838 1162]
# Validation Results at Epoch 44:
#   Val Loss: 0.1389
#   Val Accuracy: 0.9430
#   Val Precision: 0.9438
#   Val Recall: 0.9430
#   Val F1 Score: 0.9429
# Adversarial Epoch 45/200:
#   Context Loss: 0.2509
#   DQN Loss: 0.2570
#   Context Updated Samples: 1232
#   Average Reward: 0.8482
#   Action Distribution (skip/apply): [1768 1232]
# Validation Results at Epoch 45:
#   Val Loss: 0.1228
#   Val Accuracy: 0.9540
#   Val Precision: 0.9551
#   Val Recall: 0.9540
#   Val F1 Score: 0.9543
# ✓ Updated best adversarial model states (Accuracy: 0.9540)
# Adversarial Epoch 46/200:
#   Context Loss: 0.2643
#   DQN Loss: 0.2494
#   Context Updated Samples: 1257
#   Average Reward: 0.8488
#   Action Distribution (skip/apply): [1743 1257]
# Validation Results at Epoch 46:
#   Val Loss: 0.1254
#   Val Accuracy: 0.9510
#   Val Precision: 0.9531
#   Val Recall: 0.9510
#   Val F1 Score: 0.9513
# Adversarial Epoch 47/200:
#   Context Loss: 0.2586
#   DQN Loss: 0.2472
#   Context Updated Samples: 1055
#   Average Reward: 0.9320
#   Action Distribution (skip/apply): [1945 1055]
# Validation Results at Epoch 47:
#   Val Loss: 0.1305
#   Val Accuracy: 0.9490
#   Val Precision: 0.9495
#   Val Recall: 0.9490
#   Val F1 Score: 0.9490
# Adversarial Epoch 48/200:
#   Context Loss: 0.2501
#   DQN Loss: 0.2520
#   Context Updated Samples: 1123
#   Average Reward: 0.9042
#   Action Distribution (skip/apply): [1877 1123]
# Validation Results at Epoch 48:
#   Val Loss: 0.1332
#   Val Accuracy: 0.9460
#   Val Precision: 0.9467
#   Val Recall: 0.9460
#   Val F1 Score: 0.9461
# Adversarial Epoch 49/200:
#   Context Loss: 0.2427
#   DQN Loss: 0.2495
#   Context Updated Samples: 1207
#   Average Reward: 0.8637
#   Action Distribution (skip/apply): [1793 1207]
# Validation Results at Epoch 49:
#   Val Loss: 0.1480
#   Val Accuracy: 0.9430
#   Val Precision: 0.9437
#   Val Recall: 0.9430
#   Val F1 Score: 0.9429
# Adversarial Epoch 50/200:
#   Context Loss: 0.2538
#   DQN Loss: 0.2313
#   Context Updated Samples: 1179
#   Average Reward: 0.8603
#   Action Distribution (skip/apply): [1821 1179]
# Validation Results at Epoch 50:
#   Val Loss: 0.1324
#   Val Accuracy: 0.9450
#   Val Precision: 0.9464
#   Val Recall: 0.9450
#   Val F1 Score: 0.9450
# Adversarial Epoch 51/200:
#   Context Loss: 0.2410
#   DQN Loss: 0.2391
#   Context Updated Samples: 1097
#   Average Reward: 0.9128
#   Action Distribution (skip/apply): [1903 1097]
# Validation Results at Epoch 51:
#   Val Loss: 0.1254
#   Val Accuracy: 0.9590
#   Val Precision: 0.9597
#   Val Recall: 0.9590
#   Val F1 Score: 0.9588
# ✓ Updated best adversarial model states (Accuracy: 0.9590)
# Adversarial Epoch 52/200:
#   Context Loss: 0.2491
#   DQN Loss: 0.2457
#   Context Updated Samples: 1167
#   Average Reward: 0.8805
#   Action Distribution (skip/apply): [1833 1167]
# Validation Results at Epoch 52:
#   Val Loss: 0.1428
#   Val Accuracy: 0.9390
#   Val Precision: 0.9398
#   Val Recall: 0.9390
#   Val F1 Score: 0.9393
# Adversarial Epoch 53/200:
#   Context Loss: 0.2275
#   DQN Loss: 0.2211
#   Context Updated Samples: 1133
#   Average Reward: 0.8977
#   Action Distribution (skip/apply): [1867 1133]
# Validation Results at Epoch 53:
#   Val Loss: 0.1838
#   Val Accuracy: 0.9340
#   Val Precision: 0.9358
#   Val Recall: 0.9340
#   Val F1 Score: 0.9339
# Adversarial Epoch 54/200:
#   Context Loss: 0.2501
#   DQN Loss: 0.2299
#   Context Updated Samples: 1082
#   Average Reward: 0.9078
#   Action Distribution (skip/apply): [1918 1082]
# Validation Results at Epoch 54:
#   Val Loss: 0.1201
#   Val Accuracy: 0.9570
#   Val Precision: 0.9581
#   Val Recall: 0.9570
#   Val F1 Score: 0.9572
# Adversarial Epoch 55/200:
#   Context Loss: 0.2370
#   DQN Loss: 0.2284
#   Context Updated Samples: 1209
#   Average Reward: 0.8487
#   Action Distribution (skip/apply): [1791 1209]
# Validation Results at Epoch 55:
#   Val Loss: 0.1561
#   Val Accuracy: 0.9410
#   Val Precision: 0.9425
#   Val Recall: 0.9410
#   Val F1 Score: 0.9412
# Adversarial Epoch 56/200:
#   Context Loss: 0.2538
#   DQN Loss: 0.2295
#   Context Updated Samples: 1120
#   Average Reward: 0.9072
#   Action Distribution (skip/apply): [1880 1120]
# Validation Results at Epoch 56:
#   Val Loss: 0.1355
#   Val Accuracy: 0.9490
#   Val Precision: 0.9497
#   Val Recall: 0.9490
#   Val F1 Score: 0.9492
# Adversarial Epoch 57/200:
#   Context Loss: 0.2142
#   DQN Loss: 0.2185
#   Context Updated Samples: 990
#   Average Reward: 0.9602
#   Action Distribution (skip/apply): [2010  990]
# Validation Results at Epoch 57:
#   Val Loss: 0.1259
#   Val Accuracy: 0.9470
#   Val Precision: 0.9482
#   Val Recall: 0.9470
#   Val F1 Score: 0.9470
# Adversarial Epoch 58/200:
#   Context Loss: 0.2364
#   DQN Loss: 0.2187
#   Context Updated Samples: 1013
#   Average Reward: 0.9532
#   Action Distribution (skip/apply): [1987 1013]
# Validation Results at Epoch 58:
#   Val Loss: 0.1344
#   Val Accuracy: 0.9460
#   Val Precision: 0.9473
#   Val Recall: 0.9460
#   Val F1 Score: 0.9464
# Adversarial Epoch 59/200:
#   Context Loss: 0.2495
#   DQN Loss: 0.2157
#   Context Updated Samples: 1021
#   Average Reward: 0.9408
#   Action Distribution (skip/apply): [1979 1021]
# Validation Results at Epoch 59:
#   Val Loss: 0.1235
#   Val Accuracy: 0.9480
#   Val Precision: 0.9486
#   Val Recall: 0.9480
#   Val F1 Score: 0.9481
# Adversarial Epoch 60/200:
#   Context Loss: 0.2256
#   DQN Loss: 0.2105
#   Context Updated Samples: 1041
#   Average Reward: 0.9422
#   Action Distribution (skip/apply): [1959 1041]
# Validation Results at Epoch 60:
#   Val Loss: 0.1150
#   Val Accuracy: 0.9600
#   Val Precision: 0.9611
#   Val Recall: 0.9600
#   Val F1 Score: 0.9602
# ✓ Updated best adversarial model states (Accuracy: 0.9600)
# Adversarial Epoch 61/200:
#   Context Loss: 0.2424
#   DQN Loss: 0.2037
#   Context Updated Samples: 1179
#   Average Reward: 0.8588
#   Action Distribution (skip/apply): [1821 1179]
# Validation Results at Epoch 61:
#   Val Loss: 0.1100
#   Val Accuracy: 0.9590
#   Val Precision: 0.9593
#   Val Recall: 0.9590
#   Val F1 Score: 0.9591
# Adversarial Epoch 62/200:
#   Context Loss: 0.2170
#   DQN Loss: 0.2096
#   Context Updated Samples: 1040
#   Average Reward: 0.9263
#   Action Distribution (skip/apply): [1960 1040]
# Validation Results at Epoch 62:
#   Val Loss: 0.1245
#   Val Accuracy: 0.9550
#   Val Precision: 0.9556
#   Val Recall: 0.9550
#   Val F1 Score: 0.9551
# Adversarial Epoch 63/200:
#   Context Loss: 0.2260
#   DQN Loss: 0.2176
#   Context Updated Samples: 953
#   Average Reward: 0.9865
#   Action Distribution (skip/apply): [2047  953]
# Validation Results at Epoch 63:
#   Val Loss: 0.1209
#   Val Accuracy: 0.9580
#   Val Precision: 0.9584
#   Val Recall: 0.9580
#   Val F1 Score: 0.9581
# Adversarial Epoch 64/200:
#   Context Loss: 0.2168
#   DQN Loss: 0.2043
#   Context Updated Samples: 1081
#   Average Reward: 0.9202
#   Action Distribution (skip/apply): [1919 1081]
# Validation Results at Epoch 64:
#   Val Loss: 0.1175
#   Val Accuracy: 0.9460
#   Val Precision: 0.9461
#   Val Recall: 0.9460
#   Val F1 Score: 0.9460
# Adversarial Epoch 65/200:
#   Context Loss: 0.2095
#   DQN Loss: 0.2029
#   Context Updated Samples: 886
#   Average Reward: 1.0075
#   Action Distribution (skip/apply): [2114  886]
# Validation Results at Epoch 65:
#   Val Loss: 0.1214
#   Val Accuracy: 0.9530
#   Val Precision: 0.9542
#   Val Recall: 0.9530
#   Val F1 Score: 0.9530
# Adversarial Epoch 66/200:
#   Context Loss: 0.2421
#   DQN Loss: 0.1961
#   Context Updated Samples: 1010
#   Average Reward: 0.9645
#   Action Distribution (skip/apply): [1990 1010]
# Validation Results at Epoch 66:
#   Val Loss: 0.1142
#   Val Accuracy: 0.9490
#   Val Precision: 0.9496
#   Val Recall: 0.9490
#   Val F1 Score: 0.9491
# Adversarial Epoch 67/200:
#   Context Loss: 0.2042
#   DQN Loss: 0.1987
#   Context Updated Samples: 1116
#   Average Reward: 0.9212
#   Action Distribution (skip/apply): [1884 1116]
# Validation Results at Epoch 67:
#   Val Loss: 0.1202
#   Val Accuracy: 0.9560
#   Val Precision: 0.9566
#   Val Recall: 0.9560
#   Val F1 Score: 0.9561
# Adversarial Epoch 68/200:
#   Context Loss: 0.2341
#   DQN Loss: 0.2048
#   Context Updated Samples: 1101
#   Average Reward: 0.9038
#   Action Distribution (skip/apply): [1899 1101]
# Validation Results at Epoch 68:
#   Val Loss: 0.1249
#   Val Accuracy: 0.9490
#   Val Precision: 0.9499
#   Val Recall: 0.9490
#   Val F1 Score: 0.9493
# Adversarial Epoch 69/200:
#   Context Loss: 0.2229
#   DQN Loss: 0.2181
#   Context Updated Samples: 1025
#   Average Reward: 0.9583
#   Action Distribution (skip/apply): [1975 1025]
# Validation Results at Epoch 69:
#   Val Loss: 0.1244
#   Val Accuracy: 0.9530
#   Val Precision: 0.9535
#   Val Recall: 0.9530
#   Val F1 Score: 0.9531
# Adversarial Epoch 70/200:
#   Context Loss: 0.2537
#   DQN Loss: 0.2152
#   Context Updated Samples: 1072
#   Average Reward: 0.9323
#   Action Distribution (skip/apply): [1928 1072]
# Validation Results at Epoch 70:
#   Val Loss: 0.1233
#   Val Accuracy: 0.9560
#   Val Precision: 0.9563
#   Val Recall: 0.9560
#   Val F1 Score: 0.9561
# Adversarial Epoch 71/200:
#   Context Loss: 0.2115
#   DQN Loss: 0.2009
#   Context Updated Samples: 1037
#   Average Reward: 0.9420
#   Action Distribution (skip/apply): [1963 1037]
# Validation Results at Epoch 71:
#   Val Loss: 0.1137
#   Val Accuracy: 0.9490
#   Val Precision: 0.9495
#   Val Recall: 0.9490
#   Val F1 Score: 0.9492
# Adversarial Epoch 72/200:
#   Context Loss: 0.2304
#   DQN Loss: 0.2146
#   Context Updated Samples: 966
#   Average Reward: 0.9708
#   Action Distribution (skip/apply): [2034  966]
# Validation Results at Epoch 72:
#   Val Loss: 0.1168
#   Val Accuracy: 0.9550
#   Val Precision: 0.9554
#   Val Recall: 0.9550
#   Val F1 Score: 0.9552
# Adversarial Epoch 73/200:
#   Context Loss: 0.2163
#   DQN Loss: 0.2030
#   Context Updated Samples: 885
#   Average Reward: 1.0278
#   Action Distribution (skip/apply): [2115  885]
# Validation Results at Epoch 73:
#   Val Loss: 0.1195
#   Val Accuracy: 0.9560
#   Val Precision: 0.9565
#   Val Recall: 0.9560
#   Val F1 Score: 0.9561
# Adversarial Epoch 74/200:
#   Context Loss: 0.2091
#   DQN Loss: 0.1957
#   Context Updated Samples: 1023
#   Average Reward: 0.9503
#   Action Distribution (skip/apply): [1977 1023]
# Validation Results at Epoch 74:
#   Val Loss: 0.1120
#   Val Accuracy: 0.9490
#   Val Precision: 0.9501
#   Val Recall: 0.9490
#   Val F1 Score: 0.9492
# Adversarial Epoch 75/200:
#   Context Loss: 0.2147
#   DQN Loss: 0.1879
#   Context Updated Samples: 1016
#   Average Reward: 0.9607
#   Action Distribution (skip/apply): [1984 1016]
# Validation Results at Epoch 75:
#   Val Loss: 0.1229
#   Val Accuracy: 0.9460
#   Val Precision: 0.9465
#   Val Recall: 0.9460
#   Val F1 Score: 0.9461
# Adversarial Epoch 76/200:
#   Context Loss: 0.2183
#   DQN Loss: 0.1801
#   Context Updated Samples: 1093
#   Average Reward: 0.9203
#   Action Distribution (skip/apply): [1907 1093]
# Validation Results at Epoch 76:
#   Val Loss: 0.1175
#   Val Accuracy: 0.9540
#   Val Precision: 0.9546
#   Val Recall: 0.9540
#   Val F1 Score: 0.9542
# Adversarial Epoch 77/200:
#   Context Loss: 0.2352
#   DQN Loss: 0.1845
#   Context Updated Samples: 982
#   Average Reward: 0.9732
#   Action Distribution (skip/apply): [2018  982]
# Validation Results at Epoch 77:
#   Val Loss: 0.1139
#   Val Accuracy: 0.9540
#   Val Precision: 0.9548
#   Val Recall: 0.9540
#   Val F1 Score: 0.9542
# Adversarial Epoch 78/200:
#   Context Loss: 0.2108
#   DQN Loss: 0.1942
#   Context Updated Samples: 1086
#   Average Reward: 0.9305
#   Action Distribution (skip/apply): [1914 1086]
# Validation Results at Epoch 78:
#   Val Loss: 0.1206
#   Val Accuracy: 0.9560
#   Val Precision: 0.9567
#   Val Recall: 0.9560
#   Val F1 Score: 0.9562
# Adversarial Epoch 79/200:
#   Context Loss: 0.2271
#   DQN Loss: 0.2005
#   Context Updated Samples: 1042
#   Average Reward: 0.9408
#   Action Distribution (skip/apply): [1958 1042]
# Validation Results at Epoch 79:
#   Val Loss: 0.1159
#   Val Accuracy: 0.9590
#   Val Precision: 0.9592
#   Val Recall: 0.9590
#   Val F1 Score: 0.9591
# Adversarial Epoch 80/200:
#   Context Loss: 0.2176
#   DQN Loss: 0.1925
#   Context Updated Samples: 1116
#   Average Reward: 0.9107
#   Action Distribution (skip/apply): [1884 1116]
# Validation Results at Epoch 80:
#   Val Loss: 0.1292
#   Val Accuracy: 0.9470
#   Val Precision: 0.9475
#   Val Recall: 0.9470
#   Val F1 Score: 0.9471
# Early stopping triggered after 80 epochs.
# Loaded best context model
# Loaded best DQN model
# Saved best adversarial Context model
# Saved best adversarial DQN model with replay buffer
#
# ============================================================
# Final Evaluation - Adversarial System
# ============================================================
# Adversarial System Test Results:
#   Test Loss: 0.1123
#   Accuracy: 0.9550
#   Precision: 0.9561
#   Recall: 0.9550
#   F1 Score: 0.9552
#
# ============================================================
# Performance Improvement Summary
# ============================================================
# Accuracy Improvement: -1.20%
# F1 Score Improvement: -1.21%
# Precision Improvement: -1.21%
# Recall Improvement: -1.20%
#
# Training completed successfully!

# %% [markdown]
# ## New Method

# %% [markdown]
# ## Sperate testing

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler, SubsetRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import random
from collections import deque
import matplotlib.pyplot as plt
import os
import glob
import hashlib
import uuid

# Check for GPU (CUDA) availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Class Definitions (Assuming these are defined in your previous code blocks) ---
# Make sure CNN1D, ContextAwareNetwork, DQNSelector, ReplayBuffer, DQNSelectorAgent are defined here
# If they are in another file, import them. For this solution, I will assume they are available.
# If not, please paste the class definitions from the previous turn.

# For the sake of this complete runnable script, I will re-define the necessary classes briefly if they are missing,
# but usually, you should have them defined. I will focus on the `test_system` and `main` logic.

def compute_reward(action, cnn_pred, weighted_pred, label):
    # Ensure inputs are integers for comparison
    action = int(action)
    cnn_pred = int(cnn_pred)
    weighted_pred = int(weighted_pred)
    label = int(label)
    
    if action == 1:
        if weighted_pred != label and cnn_pred != label:
            reward = 3.0
        elif weighted_pred == label and cnn_pred != label:
            reward = 2.0
        elif weighted_pred != label and cnn_pred == label:
            reward = -2.0
        else:
            reward = 0.0
    else:
        reward = 1.5 if cnn_pred == label else -1.0
    return reward

def load_data(base_path='Dataset', train_perturb_level=0):
    X_all, y_all = [], []
    dataset_indices = []
    if not os.path.exists(base_path):
        print(f"Error: Data directory '{base_path}' not found.")
        return None, None, None, None, None, None, None, None, None, None, None
    try:
        df = pd.read_csv(f'{base_path}/UNSW_IoT_original.csv')
        X = df.iloc[:, :-1].values
        y = df.iloc[:, -1].values
        X_all.append(X)
        y_all.append(y)
        dataset_indices.append(list(range(len(y))))
        print(f"Loaded data for perturbation level {train_perturb_level} with {X.shape[0]} samples.")
    except FileNotFoundError:
        print(f"Error: File for perturbation level {train_perturb_level} not found.")
        return None, None, None, None, None, None, None, None, None, None, None
    if not X_all or not y_all:
        print("Error: No valid data loaded for training.")
        return None, None, None, None, None, None, None, None, None, None, None
    
    # Create full dataset before splitting
    X = np.vstack(X_all)
    y = np.hstack(y_all)
    
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y)
    
    # --- تغییر مهم ۱: حذف شرط سخت‌گیرانه ۶ کلاس ---
    num_classes = len(label_encoder.classes_)
    # if num_classes != 6:  <-- این خط را حذف یا کامنت کنید
    #     print(f"Error: Expected 6 classes, found {num_classes} classes.")
    #     return ...
    
    print(f"Detected {num_classes} classes for perturbation level {train_perturb_level}.")
    
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    class_counts = np.bincount(y)
    print(f"Input length: {X.shape[1]}")
  
    return num_classes, label_encoder, scaler, X.shape[1], class_counts


def test_system(cnn_model, dqn_agent, context_model, base_path, attack_type, perturb_level, 
                label_encoder, scaler, device, threshold, class_count, budget=300, 
                fine_tune_lr=0.0001, max_test_samples=100):
    
    # --- تغییر مهم ۲: محاسبه وزن‌ها بر اساس تعداد کلاس‌های واقعی ---
    # کلاس_count باید آرایه‌ای از تعداد نمونه‌های هر کلاس باشد
    # اگر class_count یک عدد است، باید آن را به آرایه تبدیل کنید یا از bincount استفاده کنید
    # فرض بر این است که class_count ورودی، آرایه bincount است.
    
    # اگر ورودی class_count عدد باشد (که غلط است)، باید اصلاح شود.
    # در کد اصلی شما احتمالاً class_count همان آرایه bincount است.
    # برای اطمینان:
    if isinstance(class_count, int):
        print("Warning: class_count is int, expected array. Calculating from scratch might be needed or check caller.")
        # در حالت عادی caller باید آرایه بفرستد.
    
    class_weights = torch.FloatTensor(class_count).to(device)
    
    cnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
    cumulative_accuracy_df = pd.DataFrame(columns=['Sample Index', f'Perturbation {perturb_level}'])
    results = []
    softmax = nn.Softmax(dim=1)
    
    # Ensure models are in eval mode
    cnn_model.eval()
    context_model.eval()
    
    # Load test data
    test_file = f'{base_path}/{attack_type}/{attack_type}_eps_{perturb_level}.csv'
    try:
        df_test = pd.read_csv(test_file)
        X_test = df_test.iloc[:, :-1].values
        y_test = df_test.iloc[:, -1].values
        max_samples = min(len(df_test), max_test_samples)
        X_test = X_test[:max_samples]
        y_test = y_test[:max_samples]
        cumulative_accuracy_df = pd.DataFrame({'Sample Index': range(1, max_samples + 1)})
    except FileNotFoundError:
        print(f"Error: File {test_file} not found.")
        return [], cumulative_accuracy_df
        
    try:
        y_test = label_encoder.transform(y_test)
    except ValueError:
        print(f"Error: Unknown labels in {test_file}. Skipping.")
        return [], cumulative_accuracy_df
        
    X_test = scaler.transform(X_test)
    X_test = torch.FloatTensor(X_test).unsqueeze(1).to(device)
    y_test = torch.LongTensor(y_test).to(device)
    
    test_dataset = TensorDataset(X_test, y_test)
    
    # Optimizer for context_model
    context_optimizer = optim.Adam(context_model.parameters(), lr=fine_tune_lr, weight_decay=1e-4)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    
    correct = 0
    total = 0
    y_pred = []
    y_true = []
    sample_accuracies = []
    updates_used = 0
    dqn_updates_used = 0
    dqn_loss_count = 0
    running_dqn_loss = 0.0
    sample_idx = 0
    rewards = []
    actions = []
    target_update_counter = 0
    TARGET_UPDATE_FREQ = 10
    
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        sample_idx += 1
        
        # Compute CNN outputs and state
        with torch.no_grad():
            cnn_outputs = cnn_model(inputs)
            # CNN outputs shape should be (batch, num_classes)
            probs = softmax(cnn_outputs)
            _, cnn_pred = torch.max(probs, 1)
            max_prob, _ = torch.max(probs, dim=1, keepdim=True)
            uncertainty = 1 - max_prob
            features = inputs.squeeze(1)
            state = torch.cat([features, uncertainty], dim=1)
            
        # Select action
        action_tensor = dqn_agent.select_action(state)
        action = action_tensor.item() if isinstance(action_tensor, torch.Tensor) else int(action_tensor)
        actions.append(action)
        
        # Compute weighted outputs BEFORE any context update
        with torch.no_grad():
            encoded_inputs_before = context_model(inputs)
            cnn_outputs_weighted_before = cnn_model(encoded_inputs_before)
            weighted_probs_before = softmax(cnn_outputs_weighted_before)
            _, weighted_pred_before = torch.max(cnn_outputs_weighted_before, 1)
            
        # Update ContextAwareNetwork only when action=1
        if action == 1:
            _, weighted_pred = torch.max(cnn_outputs_weighted_before, 1)
            max_weighted_prob, _ = torch.max(weighted_probs_before, dim=1, keepdim=True)
            max_prob_diff = torch.max(torch.abs(max_weighted_prob - max_prob)).item()
            
            if weighted_pred != cnn_pred and max_prob_diff >= threshold and updates_used < budget:
                updates_used += 1
                context_optimizer.zero_grad()
                encoded_inputs = context_model(inputs)
                outputs = cnn_model(encoded_inputs)
                context_loss = cnn_criterion(outputs, labels)
                orig_cnn_loss = cnn_criterion(cnn_outputs.detach(), labels)
                epsilon = 1e-8
                loss_ratio = context_loss / (orig_cnn_loss + epsilon)
                total_context_loss = 0.8 * context_loss + 0.2 / (1 + loss_ratio)
                total_context_loss.backward()
                context_optimizer.step()
                
                # Compute reward for action=1
                reward = compute_reward(action, cnn_pred.item(), weighted_pred.item(), labels.item())
                rewards.append(reward)
                
                # Compute next state with updated context
                with torch.no_grad():
                    encoded_inputs_new = context_model(inputs)
                    cnn_outputs_new = cnn_model(encoded_inputs_new)
                    probs_new = softmax(cnn_outputs_new)
                    max_prob_new, _ = torch.max(probs_new, dim=1, keepdim=True)
                    uncertainty_new = 1 - max_prob_new
                    next_state = torch.cat([features, uncertainty_new], dim=1)
                    
                # Push action=1 to replay buffer
                dqn_agent.replay_buffer.push(state, action, reward, next_state, 1.0)
                target_update_counter += 1
                
                # Hindsight Experience Replay
                if reward < 0:
                    reward_action0 = compute_reward(0, cnn_pred.item(), weighted_pred.item(), labels.item())
                    dqn_agent.replay_buffer.push(state, 0, reward_action0, state, 1.0)
                    target_update_counter += 1
                    
                # Optimize DQN
                dqn_loss = dqn_agent.optimize()
                if dqn_loss is not None:
                    running_dqn_loss += dqn_loss
                    dqn_loss_count += 1
                    dqn_updates_used += 1
                    
                # Update target network every N steps
                if target_update_counter >= TARGET_UPDATE_FREQ:
                    dqn_agent.update_target_network()
                    target_update_counter = 0
                    
                # Final output with updated context
                with torch.no_grad():
                    encoded_inputs_final = context_model(inputs)
                    outputs = cnn_model(encoded_inputs_final)
            else:
                # No context update, use current context
                with torch.no_grad():
                    encoded_inputs_final = context_model(inputs)
                    outputs = cnn_model(encoded_inputs_final)
        else:
            # Action = 0: no context update
            with torch.no_grad():
                encoded_inputs_final = context_model(inputs)
                outputs = cnn_model(encoded_inputs_final)
                
        with torch.no_grad():
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            current_accuracy = correct / total
            sample_accuracies.append(current_accuracy)
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(labels.cpu().numpy())
            cumulative_accuracy_df.loc[cumulative_accuracy_df['Sample Index'] == sample_idx, f'Perturbation {perturb_level}'] = current_accuracy
            
    test_accuracy = correct / total
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    
    results.append({
        'Perturbation Level': perturb_level,
        'Test Accuracy': test_accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1,
        'Context Updates Used': updates_used,
        'DQN Updates Used': dqn_updates_used,
        'DQN Loss': running_dqn_loss / max(dqn_loss_count, 1)
    })
    
    print(f"\nResults for Perturbation Level {perturb_level}:")
    print(f"  Test Accuracy: {test_accuracy:.4f}")
    print(f"  Precision (weighted): {precision:.4f}")
    print(f"  Recall (weighted): {recall:.4f}")
    print(f"  F1 Score (weighted): {f1:.4f}")
    print(f"  Context Updates Used: {updates_used}/{budget}")
    print(f"  DQN Updates Used: {dqn_updates_used}/{budget}")
    print(f"  Average DQN Loss: {running_dqn_loss / max(dqn_loss_count, 1):.4f}")
    print(f"  Average Reward: {np.mean(rewards) if rewards else 0.0:.4f}")
    
    actions_np = np.array(actions)
    print(f"  Action Distribution: {np.bincount(actions_np, minlength=2) if len(actions_np) > 0 else [0, 0]}")
    
    return results, cumulative_accuracy_df

def plot_accuracies(combined_accuracy_df, test_perturb_levels):
    plt.figure(figsize=(12, 8))
    for perturb in test_perturb_levels:
        if f'Perturbation {perturb}' in combined_accuracy_df.columns:
            plt.plot(combined_accuracy_df['Sample Index'], combined_accuracy_df[f'Perturbation {perturb}'], 
                     label=f'Perturbation {perturb}', marker='o', markersize=4, linewidth=1.5)
    plt.xlabel('Sample Index')
    plt.ylabel('Cumulative Accuracy')
    plt.title('Cumulative Accuracy per Sample Across Perturbation Levels')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    os.makedirs('Results', exist_ok=True)
    plt.savefig('Results/cumulative_accuracy_per_sample_all_levels.png', dpi=300)
    plt.show()
    print("Plot saved to 'Results/cumulative_accuracy_per_sample_all_levels.png'")
# Out:
# Using device: cuda

# %%
def main(attack_type, fine_tune_lr,test_perturb_levels, context_budget_test, threshold):
    
    base_path = 'Dataset'
    cnn_model_path = 'Models/initial_cnn_model.pth'
    context_model_path = 'Models/adversarial_best_context.pth'
    dqn_model_path = 'Models/adversarial_best_dqn.pth'
    max_test_samples = 50000
    
    print(f"Current working directory: {os.getcwd()}")
    print(f"Expected data directory: {os.path.abspath(base_path)}")
    print("Available files in data directory:")
    for file in glob.glob(f"{base_path}/*.csv"):
        print(file)
        
    all_results = []
    all_accuracy_dfs = []
    max_sample_index = 0
    accuracy_by_perturb = {}
    
    for perturb_level in test_perturb_levels:
        print(f"\n{'='*50}")
        print(f"Starting processing for perturbation level {perturb_level}")
        print(f"{'='*50}")
        
        try:
            num_classes, label_encoder, scaler, input_length, class_counts = load_data(
                base_path
            )
        except Exception as e:
            print(f"Error loading data metadata: {e}")
            continue
            
        if num_classes is None:
            print("Failed to load data metadata. Skipping.")
            continue

        try:
            # Load CNN model
            cnn_checkpoint = torch.load(cnn_model_path, map_location=device)
            cnn_input_length = cnn_checkpoint['input_length']
            cnn_num_classes = cnn_checkpoint['num_classes']
            
            if cnn_input_length != input_length or cnn_num_classes != num_classes:
                print(f"Error: Mismatch in CNN model parameters (input_length: {cnn_input_length} vs {input_length}, num_classes: {cnn_num_classes} vs {num_classes})")
                continue
                
            cnn_model = CNN1D(input_length=input_length, num_classes=num_classes).to(device)
            cnn_model.load_state_dict(cnn_checkpoint['model_state_dict'])
            cnn_model.eval() # Set to eval mode
            print(f"Successfully loaded CNN model from {cnn_model_path}")
            
            # Load ContextAwareNetwork model
            context_checkpoint = torch.load(context_model_path, map_location=device)
            context_input_length = context_checkpoint['input_length']
            context_num_classes = context_checkpoint['num_classes']
            
            if context_input_length != input_length or context_num_classes != num_classes:
                print(f"Error: Mismatch in Context model parameters (input_length: {context_input_length} vs {input_length}, num_classes: {context_num_classes} vs {num_classes})")
                continue
                
            context_model = ContextAwareNetwork(input_size=input_length, num_layers=4).to(device)
            context_model.load_state_dict(context_checkpoint['context_model_state_dict'])
            context_model.eval() # Set to eval mode
            print(f"Successfully loaded Context model from {context_model_path}")
            
            # Load DQNSelector model
            dqn_checkpoint = torch.load(dqn_model_path, map_location=device)
            dqn_input_length = dqn_checkpoint['input_length']
            dqn_num_classes = dqn_checkpoint['num_classes']
            
            if dqn_input_length != input_length or dqn_num_classes != num_classes:
                print(f"Error: Mismatch in DQN model parameters (input_length: {dqn_input_length} vs {input_length}, num_classes: {dqn_num_classes} vs {num_classes})")
                continue
                
            dqn_agent = DQNSelectorAgent(
                input_size=input_length + 1,
                device=device,
                epsilon_decay=0.5,
                buffer_capacity=5000,
                batch_size=32
            )
            dqn_agent.policy_net.load_state_dict(dqn_checkpoint['dqn_policy_net_state_dict'])
            dqn_agent.target_net.load_state_dict(dqn_checkpoint['dqn_policy_net_state_dict'])
            dqn_agent.target_net.eval()
            
            # Load replay buffer if exists
            if 'replay_buffer' in dqn_checkpoint:
                dqn_agent.replay_buffer = ReplayBuffer(1000)
                for experience in dqn_checkpoint['replay_buffer']:
                    state, action, reward, next_state, done = experience
                    
                    if not isinstance(state, torch.Tensor):
                        state = torch.FloatTensor(state).to(device)
                    if not isinstance(next_state, torch.Tensor):
                        next_state = torch.FloatTensor(next_state).to(device)
                        
                    if state.dim() == 0:
                        state = state.unsqueeze(0)
                    if next_state.dim() == 0:
                        next_state = next_state.unsqueeze(0)
                        
                    dqn_agent.replay_buffer.push(state, action, reward, next_state, done)
                print(f"Loaded replay buffer with {len(dqn_agent.replay_buffer)} experiences")
            else:
                print("Warning: No replay buffer found in checkpoint. Starting with empty buffer.")
                dqn_agent.replay_buffer = ReplayBuffer(200)
                
            print(f"Successfully loaded DQN model from {dqn_model_path}")
            
        except FileNotFoundError as e:
            print(f"Error: Model file not found: {e}")
            continue
        except KeyError as e:
            print(f"Error: Missing key {e} in checkpoint.")
            continue
        except Exception as e:
            print(f"Error loading model: {e}")
            import traceback
            traceback.print_exc()
            continue
            
        print(f"Test - Using DQN threshold: {threshold:.4f}")
        
        results, cumulative_accuracy_df = test_system(
            cnn_model, dqn_agent, context_model, base_path, attack_type, perturb_level,
            label_encoder, scaler, device, threshold, class_counts, budget=context_budget_test, 
            fine_tune_lr=fine_tune_lr, max_test_samples=max_test_samples
        )
        
        all_results.extend(results)
        if not cumulative_accuracy_df.empty:
            all_accuracy_dfs.append(cumulative_accuracy_df)
            max_sample_index = max(max_sample_index, cumulative_accuracy_df['Sample Index'].max())
            accuracy_by_perturb[perturb_level] = cumulative_accuracy_df[f'Perturbation {perturb_level}'].values.tolist()
            
    if accuracy_by_perturb:
        max_samples = max(len(acc) for acc in accuracy_by_perturb.values())
        combined_accuracy_df = pd.DataFrame({'Size': list(accuracy_by_perturb.keys())})
        for i in range(max_samples):
            column_data = []
            for perturb_level in accuracy_by_perturb:
                acc_list = accuracy_by_perturb[perturb_level]
                value = acc_list[i] if i < len(acc_list) else np.nan
                column_data.append(value)
            combined_accuracy_df[f'{i+1}'] = column_data
        
        os.makedirs('Results', exist_ok=True)
        combined_accuracy_df.to_csv('Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv', index=False)
        print("Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'")
        
    if all_results:
        results_df = pd.DataFrame(all_results)
        os.makedirs('Results', exist_ok=True)
        results_df.to_csv('Results/AMCAL_20_cumulative_accuracy.csv', index=False)
        print("\nCombined Results Table:")
        print(results_df.to_string(index=False))
        print("\nCombined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.")
        
    if accuracy_by_perturb:
        plt.figure(figsize=(12, 8))
        for perturb_level in test_perturb_levels:
            if perturb_level in accuracy_by_perturb:
                plt.plot(range(1, len(accuracy_by_perturb[perturb_level]) + 1), 
                         accuracy_by_perturb[perturb_level], 
                         label=f'Perturbation {perturb_level}', marker='o', markersize=4, linewidth=1.5)
        plt.xlabel('Sample Index')
        plt.ylabel('Cumulative Accuracy')
        plt.title('Cumulative Accuracy per Sample Across Perturbation Levels')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.7)
        os.makedirs('Results', exist_ok=True)
        plt.savefig('Results/AMCAL_20_cumulative_accuracy.png', dpi=300)
        plt.show()
        print("Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'")

# %% [markdown]
# # FGSM Adversarial Attack

# %%
import warnings
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

if __name__ == "__main__":
    fine_tune_lr = 0.0002
    test_perturb_levels = [0.01, 0.05, 0.1, 0.2, 0.5]
    attack_type = "FGSM" # or "PGD" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 200
    threshold = 0.005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST\Dataset
# Available files in data directory:
# Dataset\UNSW_IoT_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.01
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.01:
#   Test Accuracy: 0.9500
#   Precision (weighted): 0.9522
#   Recall (weighted): 0.9500
#   F1 Score (weighted): 0.9504
#   Context Updates Used: 16/200
#   DQN Updates Used: 16/200
#   Average DQN Loss: 0.1956
#   Average Reward: -0.5000
#   Action Distribution: [512 488]
#
# ==================================================
# Starting processing for perturbation level 0.05
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.05:
#   Test Accuracy: 0.8950
#   Precision (weighted): 0.9013
#   Recall (weighted): 0.8950
#   F1 Score (weighted): 0.8955
#   Context Updates Used: 93/200
#   DQN Updates Used: 93/200
#   Average DQN Loss: 0.3564
#   Average Reward: 0.8710
#   Action Distribution: [503 497]
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.8640
#   Precision (weighted): 0.8673
#   Recall (weighted): 0.8640
#   F1 Score (weighted): 0.8641
#   Context Updates Used: 153/200
#   DQN Updates Used: 153/200
#   Average DQN Loss: 0.5240
#   Average Reward: 1.5229
#   Action Distribution: [517 483]
#
# ==================================================
# Starting processing for perturbation level 0.2
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.2:
#   Test Accuracy: 0.7180
#   Precision (weighted): 0.7387
#   Recall (weighted): 0.7180
#   F1 Score (weighted): 0.7183
#   Context Updates Used: 200/200
#   DQN Updates Used: 200/200
#   Average DQN Loss: 0.6130
#   Average Reward: 1.7700
#   Action Distribution: [489 511]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.6110
#   Precision (weighted): 0.6182
#   Recall (weighted): 0.6110
#   F1 Score (weighted): 0.5951
#   Context Updates Used: 200/200
#   DQN Updates Used: 200/200
#   Average DQN Loss: 0.6807
#   Average Reward: 1.9550
#   Action Distribution: [516 484]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision  Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                0.01          0.950   0.952195   0.950  0.950387                    16                16  0.195556
#                0.05          0.895   0.901334   0.895  0.895472                    93                93  0.356394
#                0.10          0.864   0.867290   0.864  0.864135                   153               153  0.524047
#                0.20          0.718   0.738709   0.718  0.718254                   200               200  0.612950
#                0.50          0.611   0.618235   0.611  0.595076                   200               200  0.680658
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %% [markdown]
# ## PGD Adversarial Attack

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0002
    test_perturb_levels = [0.01, 0.05, 0.1, 0.2, 0.5]
    attack_type = "PGD" # or "FGSM" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 200
    threshold = 0.05
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST\Dataset
# Available files in data directory:
# Dataset\UNSW_IoT_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.01
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0500
#
# Results for Perturbation Level 0.01:
#   Test Accuracy: 0.9250
#   Precision (weighted): 0.9259
#   Recall (weighted): 0.9250
#   F1 Score (weighted): 0.9252
#   Context Updates Used: 34/200
#   DQN Updates Used: 34/200
#   Average DQN Loss: 0.2438
#   Average Reward: -0.3235
#   Action Distribution: [494 506]
#
# ==================================================
# Starting processing for perturbation level 0.05
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0500
#
# Results for Perturbation Level 0.05:
#   Test Accuracy: 0.8400
#   Precision (weighted): 0.8559
#   Recall (weighted): 0.8400
#   F1 Score (weighted): 0.8407
#   Context Updates Used: 47/200
#   DQN Updates Used: 47/200
#   Average DQN Loss: 0.2176
#   Average Reward: -0.3830
#   Action Distribution: [486 514]
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0500
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.7010
#   Precision (weighted): 0.7348
#   Recall (weighted): 0.7010
#   F1 Score (weighted): 0.6917
#   Context Updates Used: 128/200
#   DQN Updates Used: 128/200
#   Average DQN Loss: 0.4819
#   Average Reward: 0.4766
#   Action Distribution: [494 506]
#
# ==================================================
# Starting processing for perturbation level 0.2
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0500
#
# Results for Perturbation Level 0.2:
#   Test Accuracy: 0.6720
#   Precision (weighted): 0.7185
#   Recall (weighted): 0.6720
#   F1 Score (weighted): 0.6792
#   Context Updates Used: 200/200
#   DQN Updates Used: 200/200
#   Average DQN Loss: 0.7224
#   Average Reward: 1.4350
#   Action Distribution: [479 521]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0500
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.5740
#   Precision (weighted): 0.6423
#   Recall (weighted): 0.5740
#   F1 Score (weighted): 0.5849
#   Context Updates Used: 200/200
#   DQN Updates Used: 200/200
#   Average DQN Loss: 0.7329
#   Average Reward: 2.0050
#   Action Distribution: [497 503]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision  Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                0.01          0.925   0.925935   0.925  0.925178                    34                34  0.243768
#                0.05          0.840   0.855907   0.840  0.840698                    47                47  0.217603
#                0.10          0.701   0.734771   0.701  0.691726                   128               128  0.481928
#                0.20          0.672   0.718467   0.672  0.679206                   200               200  0.722398
#                0.50          0.574   0.642290   0.574  0.584939                   200               200  0.732867
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0002
    test_perturb_levels = [0.1, 0.5, 1.0, 2.0, 5.0]
    attack_type = "CW" # or "FGSM" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 200
    threshold = 0.005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST\Dataset
# Available files in data directory:
# Dataset\UNSW_IoT_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.9500
#   Precision (weighted): 0.9509
#   Recall (weighted): 0.9500
#   F1 Score (weighted): 0.9500
#   Context Updates Used: 22/200
#   DQN Updates Used: 22/200
#   Average DQN Loss: 0.2281
#   Average Reward: -0.5455
#   Action Distribution: [508 492]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.9160
#   Precision (weighted): 0.9197
#   Recall (weighted): 0.9160
#   F1 Score (weighted): 0.9165
#   Context Updates Used: 58/200
#   DQN Updates Used: 58/200
#   Average DQN Loss: 0.3050
#   Average Reward: 0.7069
#   Action Distribution: [492 508]
#
# ==================================================
# Starting processing for perturbation level 1.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 1.0:
#   Test Accuracy: 0.8220
#   Precision (weighted): 0.8589
#   Recall (weighted): 0.8220
#   F1 Score (weighted): 0.8207
#   Context Updates Used: 102/200
#   DQN Updates Used: 102/200
#   Average DQN Loss: 0.4526
#   Average Reward: 1.2451
#   Action Distribution: [507 493]
#
# ==================================================
# Starting processing for perturbation level 2.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 2.0:
#   Test Accuracy: 0.8740
#   Precision (weighted): 0.8885
#   Recall (weighted): 0.8740
#   F1 Score (weighted): 0.8764
#   Context Updates Used: 152/200
#   DQN Updates Used: 152/200
#   Average DQN Loss: 0.5096
#   Average Reward: 1.3355
#   Action Distribution: [512 488]
#
# ==================================================
# Starting processing for perturbation level 5.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0050
#
# Results for Perturbation Level 5.0:
#   Test Accuracy: 0.8630
#   Precision (weighted): 0.8738
#   Recall (weighted): 0.8630
#   F1 Score (weighted): 0.8635
#   Context Updates Used: 118/200
#   DQN Updates Used: 118/200
#   Average DQN Loss: 0.4448
#   Average Reward: 1.2288
#   Action Distribution: [534 466]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision  Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                 0.1          0.950   0.950867   0.950  0.950021                    22                22  0.228105
#                 0.5          0.916   0.919678   0.916  0.916536                    58                58  0.304964
#                 1.0          0.822   0.858864   0.822  0.820679                   102               102  0.452644
#                 2.0          0.874   0.888484   0.874  0.876412                   152               152  0.509592
#                 5.0          0.863   0.873789   0.863  0.863505                   118               118  0.444791
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0002
    test_perturb_levels = [0.1, 0.5, 1.0, 2.0, 5.0]
    attack_type = "DeepFool" # or "FGSM" or "CW" or "DeepFool" 
    context_budget_test = 200
    threshold = 0.0005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\UNSW_IoT_TEST\Dataset
# Available files in data directory:
# Dataset\UNSW_IoT_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.9140
#   Precision (weighted): 0.9163
#   Recall (weighted): 0.9140
#   F1 Score (weighted): 0.9139
#   Context Updates Used: 31/200
#   DQN Updates Used: 31/200
#   Average DQN Loss: 0.2279
#   Average Reward: -0.5484
#   Action Distribution: [502 498]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.8310
#   Precision (weighted): 0.8398
#   Recall (weighted): 0.8310
#   F1 Score (weighted): 0.8296
#   Context Updates Used: 156/200
#   DQN Updates Used: 156/200
#   Average DQN Loss: 0.5872
#   Average Reward: 1.7628
#   Action Distribution: [494 506]
#
# ==================================================
# Starting processing for perturbation level 1.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 1.0:
#   Test Accuracy: 0.7930
#   Precision (weighted): 0.7959
#   Recall (weighted): 0.7930
#   F1 Score (weighted): 0.7931
#   Context Updates Used: 166/200
#   DQN Updates Used: 166/200
#   Average DQN Loss: 0.6315
#   Average Reward: 1.3373
#   Action Distribution: [497 503]
#
# ==================================================
# Starting processing for perturbation level 2.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 2.0:
#   Test Accuracy: 0.7570
#   Precision (weighted): 0.7682
#   Recall (weighted): 0.7570
#   F1 Score (weighted): 0.7569
#   Context Updates Used: 188/200
#   DQN Updates Used: 188/200
#   Average DQN Loss: 0.6493
#   Average Reward: 1.2074
#   Action Distribution: [495 505]
#
# ==================================================
# Starting processing for perturbation level 5.0
# ==================================================
# Loaded data for perturbation level 0 with 5000 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 18
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=2 for input_size=18
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 5.0:
#   Test Accuracy: 0.7730
#   Precision (weighted): 0.7745
#   Recall (weighted): 0.7730
#   F1 Score (weighted): 0.7721
#   Context Updates Used: 200/200
#   DQN Updates Used: 200/200
#   Average DQN Loss: 0.6335
#   Average Reward: 1.3750
#   Action Distribution: [496 504]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision  Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                 0.1          0.914   0.916281   0.914  0.913870                    31                31  0.227881
#                 0.5          0.831   0.839781   0.831  0.829621                   156               156  0.587163
#                 1.0          0.793   0.795876   0.793  0.793109                   166               166  0.631505
#                 2.0          0.757   0.768233   0.757  0.756892                   188               188  0.649256
#                 5.0          0.773   0.774480   0.773  0.772119                   200               200  0.633487
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'
