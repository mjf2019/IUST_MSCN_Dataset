# %% [markdown]
# ## ------------------------------------ Final method --------------------------------------

# %% [markdown]
# ## intial train nash equillibriam

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import random
from collections import deque
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define 1D-CNN model
class CNN1D(nn.Module):
    def __init__(self, input_length, num_classes):
        super(CNN1D, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.25)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.25)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv1d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2),
            nn.Dropout(0.3)
        )
        self.flatten = nn.Flatten()
        output_length = input_length // 8
        self.dense_layers = nn.Sequential(
            nn.Linear(256 * output_length, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, num_classes)
        )
    
    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.flatten(x)
        x = self.dense_layers(x)
        return x

# Define ContextAwareNetwork
class ContextAwareNetwork(nn.Module):
    def __init__(self, input_size, num_layers=4, dim_feedforward=1024):
        super(ContextAwareNetwork, self).__init__()
        self.input_size = input_size
        
        # محاسبه خودکار تعداد heads بر اساس input_size
        possible_heads = [8, 4, 2, 1]
        num_heads = 1
        for h in possible_heads:
            if input_size % h == 0:
                num_heads = h
                break
        
        if input_size % num_heads != 0:
            num_heads = 1
            print(f"Warning: Using num_heads=1 for input_size={input_size}")
        
        print(f"Selected num_heads={num_heads} for input_size={input_size}")
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=input_size,
            nhead=num_heads,
            dim_feedforward=dim_feedforward,
            dropout=0.3,
            activation='relu',
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        self.encoder = nn.Sequential(
            nn.Conv1d(in_channels=2, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Flatten(),
            nn.Linear(128 * input_size, 512),
            nn.ReLU(),
            nn.LayerNorm(512),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, input_size),
            nn.ReLU(),
            nn.LayerNorm(input_size)
        )
    
    def forward(self, x):
        x_flat = x.squeeze(1)
        x_transformed = self.transformer(x_flat.unsqueeze(1)).squeeze(1)
        weights = torch.sigmoid(x_transformed)
        combined = torch.stack([x_flat, weights], dim=1)
        encoded = self.encoder(combined)
        return encoded.unsqueeze(1)

# Define DQNSelector
class DQNSelector(nn.Module):
    def __init__(self, input_size):
        super(DQNSelector, self).__init__()
        hidden_size1 = min(512, max(128, input_size * 2))
        hidden_size2 = min(256, hidden_size1 // 2)
        
        self.network = nn.Sequential(
            nn.Linear(input_size, hidden_size1),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size1, hidden_size2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size2, 2)
        )
    
    def forward(self, x):
        return self.network(x)

# Replay Buffer for DQN
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    
    def push(self, state, action, reward, next_state, done):
        state = state.squeeze().cpu()
        next_state = next_state.squeeze().cpu()
        self.buffer.append((state, action, reward, next_state, done))
    
    def sample(self, batch_size):
        state, action, reward, next_state, done = zip(*random.sample(self.buffer, batch_size))
        states = torch.stack([torch.FloatTensor(s) for s in state])
        next_states = torch.stack([torch.FloatTensor(s) for s in next_state])
        return (
            states,
            torch.tensor(action, dtype=torch.long),
            torch.tensor(reward, dtype=torch.float32),
            next_states,
            torch.tensor(done, dtype=torch.float32)
        )
    
    def __len__(self):
        return len(self.buffer)

# DQN Agent
class DQNSelectorAgent:
    def __init__(self, input_size, device, lr=1e-4, gamma=0.5, epsilon_start=1.0, epsilon_end=0.01, epsilon_decay=0.995, buffer_capacity=50000, batch_size=256):
        self.device = device
        self.policy_net = DQNSelector(input_size).to(device)
        self.target_net = DQNSelector(input_size).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.replay_buffer = ReplayBuffer(buffer_capacity)
        self.batch_size = batch_size
        self.gamma = gamma
        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.steps_done = 0
    
    def select_action(self, state):
        """Select action for given state. Always returns a tensor."""
        self.steps_done += 1
        
        if len(state.shape) == 1:
            state = state.unsqueeze(0)
        
        state = state.to(self.device)
        
        if random.random() < self.epsilon:
            return torch.randint(0, 2, (state.size(0),), device=self.device)
        else:
            with torch.no_grad():
                q_values = self.policy_net(state)
                return q_values.argmax(dim=1)
    
    def update_epsilon(self):
        self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)
    
    def optimize(self):
        if len(self.replay_buffer) < self.batch_size:
            return None
        
        states, actions, rewards, next_states, dones = self.replay_buffer.sample(self.batch_size)
        states = states.to(self.device)
        actions = actions.to(self.device)
        rewards = rewards.to(self.device)
        next_states = next_states.to(self.device)
        dones = dones.to(self.device)
        
        current_q_values = self.policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        
        with torch.no_grad():
            next_actions = self.policy_net(next_states).argmax(1)
            next_q_values = self.target_net(next_states).gather(1, next_actions.unsqueeze(1)).squeeze(1)
            target_q_values = rewards + (1 - dones) * self.gamma * next_q_values
        
        loss = nn.MSELoss()(current_q_values, target_q_values)
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), max_norm=1.0)
        self.optimizer.step()
        return loss.item()
    
    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# Load and preprocess data - GENERALIZED version
def load_data(dataset_path='Dataset', csv_filename='IUST_MSCN_original.csv'):
    try:
        original_df = pd.read_csv(f'{dataset_path}/{csv_filename}')
        
        # تقسیم داده به train (60%)، validation (20%)، test (20%)
        train_df, temp_df = train_test_split(original_df, test_size=0.4, random_state=42)
        val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)
        
        X_train = train_df.iloc[:, :-1].values
        y_train = train_df.iloc[:, -1].values
        X_val = val_df.iloc[:, :-1].values
        y_val = val_df.iloc[:, -1].values
        X_test = test_df.iloc[:, :-1].values
        y_test = test_df.iloc[:, -1].values
        
    except FileNotFoundError as e:
        print(f"Error: Dataset file not found: {e}")
        return None, None, None, None, None, None, None
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return None, None, None, None, None, None, None
    
    # Encode labels
    label_encoder = LabelEncoder()
    y_train = label_encoder.fit_transform(y_train)
    y_val = label_encoder.transform(y_val)
    y_test = label_encoder.transform(y_test)
    num_classes = len(label_encoder.classes_)
    
    print(f"Detected {num_classes} classes in the dataset")
    print(f"Classes: {label_encoder.classes_}")
    
    # Scale features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)
    
    # Convert to tensors
    X_train_tensor = torch.FloatTensor(X_train).unsqueeze(1).to(device)
    y_train_tensor = torch.LongTensor(y_train).to(device)
    X_val_tensor = torch.FloatTensor(X_val).unsqueeze(1).to(device)
    y_val_tensor = torch.LongTensor(y_val).to(device)
    X_test_tensor = torch.FloatTensor(X_test).unsqueeze(1).to(device)
    y_test_tensor = torch.LongTensor(y_test).to(device)
    
    # Create datasets
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    
    # Handle class imbalance
    class_counts = np.bincount(y_train)
    if len(class_counts) < num_classes:
        class_counts = np.append(class_counts, [0] * (num_classes - len(class_counts)))
    
    weights = 1.0 / class_counts[y_train]
    train_sampler = WeightedRandomSampler(weights, len(weights))
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler) 
    full_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)  
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False) 
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)  
    
    print("Class distribution in training data:", np.bincount(y_train))
    print("Class distribution in validation data:", np.bincount(y_val))
    print("Class distribution in test data:", np.bincount(y_test))
    print(f"Total training samples: {X_train.shape[0]}, validation samples: {X_val.shape[0]}, test samples: {X_test.shape[0]}")
    print(f"Input length: {X_train.shape[1]}")
    print(f"Full dataset size for adversarial training: {len(train_dataset)}")
    
    return train_loader, val_loader, test_loader, full_loader, num_classes, X_train.shape[1], class_counts

# Compute combined loss
def compute_combined_loss(outputs, labels, class_weights):
    criterion = nn.CrossEntropyLoss(weight=class_weights, reduction='none')
    per_sample_loss = criterion(outputs, labels)
    mean_loss = per_sample_loss.mean()
    return mean_loss, per_sample_loss

# Train initial CNN model
def train_initial_cnn(cnn_model, train_loader, val_loader, class_counts, epochs=500, patience=50):
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(cnn_model.parameters(), lr=0.0005, weight_decay=1e-4)  
    scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=1e-6)
    
    best_val_loss = float('inf')
    epochs_no_improve = 0
    best_model_state = None
    
    for epoch in range(epochs):
        cnn_model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = cnn_model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        
        cnn_model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = cnn_model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_loss = val_loss / len(val_loader.dataset)
        val_accuracy = correct / total
        print(f"Initial CNN Epoch {epoch+1}/{epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = cnn_model.state_dict()
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs.")
                if best_model_state is not None:
                    cnn_model.load_state_dict(best_model_state)
                break
        
        scheduler.step()
    
    return cnn_model

# Evaluate model
def evaluate_model(model, test_loader, class_weights, context_model=None, dqn_agent=None, threshold=None):
    model.eval()
    y_true = []
    y_pred = []
    running_loss = 0.0
    total_samples = 0
    softmax = nn.Softmax(dim=1)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            batch_size = inputs.size(0)
            total_samples += batch_size
            
            if context_model and dqn_agent and threshold is not None:
                cnn_outputs = model(inputs)
                probs = softmax(cnn_outputs)
                
                encoded_inputs = context_model(inputs)
                outputs = model(encoded_inputs)
                
                _, predicted = torch.max(outputs, 1)
                final_loss = criterion(outputs, labels)
                running_loss += final_loss.item() * batch_size
            else:
                outputs = model(inputs)
                final_loss = criterion(outputs, labels)
                running_loss += final_loss.item() * batch_size
                _, predicted = torch.max(outputs, 1)
            
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(labels.cpu().numpy())
    
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    test_loss = running_loss / total_samples
    
    return {
        'Test Loss': test_loss,
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    }

def compute_reward(action, cnn_pred, weighted_pred, label):
    if action == 1:
        if weighted_pred != label and cnn_pred != label:
            reward = 3.0
        elif weighted_pred == label and cnn_pred != label:
            reward = 2.0
        elif weighted_pred != label and cnn_pred == label:
            reward = -2.0
        else:
            reward = 0.0
    else:
        reward = 1.5 if cnn_pred == label else -1.0
    return reward

def train_adversarial_system(cnn_model, dqn_agent, context_model, full_loader, val_loader, class_counts, input_length, num_classes, fine_tune_epochs=500, patience=50):
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    cnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
    context_optimizer = optim.Adam(context_model.parameters(), lr=5e-4, weight_decay=1e-4)
    context_scheduler = lr_scheduler.CosineAnnealingLR(context_optimizer, T_max=100)
    
    best_val_accuracy = 0.0
    epochs_no_improve = 0
    softmax = nn.Softmax(dim=1)
    best_context_state = None
    best_dqn_state = None
    
    # Pre-train ContextAwareNetwork
    print("Pre-training ContextAwareNetwork...")
    for pretrain_epoch in range(20):
        context_model.train()
        total_context_loss = 0.0
        num_batches = 0
        for inputs, labels in full_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            context_optimizer.zero_grad()
            encoded_inputs = context_model(inputs)
            cnn_outputs_weighted = cnn_model(encoded_inputs)
            context_loss = cnn_criterion(cnn_outputs_weighted, labels)
            context_loss.backward()
            context_optimizer.step()
            total_context_loss += context_loss.item()
            num_batches += 1
        context_scheduler.step()
        print(f"Pretrain Epoch {pretrain_epoch+1}/20, Loss: {total_context_loss/num_batches:.4f}")
    
    print("Starting adversarial training on full dataset...")
    target_update_counter = 0
    TARGET_UPDATE_FREQ = 100
    
    for epoch in range(fine_tune_epochs):
        cnn_model.eval()
        context_model.train()
        dqn_agent.policy_net.train()
        
        running_context_loss = 0.0
        running_dqn_loss = 0.0
        dqn_loss_count = 0
        total_samples = 0
        context_updated_samples = 0
        rewards = []
        actions = []
        context_updated = False
        
        for inputs, labels in full_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            batch_size = inputs.size(0)
            total_samples += batch_size
            
            # Compute CNN outputs and state for DQN
            with torch.no_grad():
                cnn_outputs = cnn_model(inputs).detach()
                probs = softmax(cnn_outputs)
                _, cnn_pred = torch.max(cnn_outputs, 1)
                max_prob, _ = torch.max(probs, dim=1, keepdim=True)
                uncertainty = 1 - max_prob
            
            features = inputs.squeeze(1).detach()
            state = torch.cat([features, uncertainty], dim=1).detach()
            
            # Select actions for all samples in batch
            actions_batch = dqn_agent.select_action(state)
            actions.extend(actions_batch.cpu().tolist())
            
            # Find indices where action=1
            action_mask = (actions_batch == 1).cpu()
            action_indices = action_mask.nonzero(as_tuple=True)[0]
            
            # Update ContextAwareNetwork only for samples with action=1
            if len(action_indices) > 0:
                context_updated = True
                context_updated_samples += len(action_indices)
                
                selected_inputs = inputs[action_indices]
                selected_labels = labels[action_indices]
                
                # Handle batch size 1
                if selected_inputs.size(0) == 1:
                    selected_inputs = torch.cat([selected_inputs, selected_inputs], dim=0)
                    selected_labels = torch.cat([selected_labels, selected_labels], dim=0)
                
                context_optimizer.zero_grad()
                encoded_inputs = context_model(selected_inputs)
                cnn_outputs_weighted = cnn_model(encoded_inputs)
                context_loss = cnn_criterion(cnn_outputs_weighted, selected_labels)
                orig_cnn_loss = cnn_criterion(cnn_model(selected_inputs), selected_labels)
                epsilon = 1e-8
                loss_ratio = orig_cnn_loss / (context_loss + epsilon)
                total_context_loss = 0.8 * context_loss + 0.2 / (1 + loss_ratio)
                total_context_loss = torch.clamp(total_context_loss, max=1.0)
                total_context_loss.backward()
                context_optimizer.step()
                running_context_loss += total_context_loss.item() * len(action_indices)
            
            # Compute rewards and next states
            with torch.no_grad():
                encoded_inputs = context_model(inputs).detach()
                cnn_outputs_weighted = cnn_model(encoded_inputs).detach()
                _, weighted_pred = torch.max(cnn_outputs_weighted, 1)
            
            # Compute rewards for all samples
            batch_rewards = []
            for i in range(batch_size):
                r = compute_reward(actions_batch[i].item(), cnn_pred[i].item(), weighted_pred[i].item(), labels[i].item())
                batch_rewards.append(r)
            rewards.extend(batch_rewards)
            
            # Compute next states based on action
            with torch.no_grad():
                if len(action_indices) > 0:
                    cnn_outputs_new = cnn_model(context_model(inputs)).detach()
                    probs_new = softmax(cnn_outputs_new)
                    max_prob_new, _ = torch.max(probs_new, dim=1, keepdim=True)
                    uncertainty_new = 1 - max_prob_new
                    features_new = inputs.squeeze(1).detach()
                    next_state_new = torch.cat([features_new, uncertainty_new], dim=1).detach()
                else:
                    next_state_new = state
            
            # Push to replay buffer for ALL actions
            for i in range(batch_size):
                if actions_batch[i] == 1 and len(action_indices) > 0:
                    next_state = next_state_new[i:i+1]
                else:
                    next_state = state[i:i+1]
                
                dqn_agent.replay_buffer.push(
                    state[i:i+1],
                    actions_batch[i].item(),
                    batch_rewards[i],
                    next_state,
                    1.0
                )
                target_update_counter += 1
            
            # Update target network every N steps
            if target_update_counter >= TARGET_UPDATE_FREQ:
                dqn_agent.update_target_network()
                target_update_counter = 0
            
            # Optimize DQN
            dqn_loss = dqn_agent.optimize()
            if dqn_loss is not None:
                running_dqn_loss += dqn_loss
                dqn_loss_count += 1
        
        if context_updated:
            context_scheduler.step()
        
        dqn_agent.update_epsilon()
        
        if epoch % 5 == 0:
            dqn_agent.update_target_network()
        
        avg_reward = np.mean(rewards) if rewards else 0.0
        action_dist = np.bincount(actions, minlength=2) if actions else [0, 0]
        
        print(f"Adversarial Epoch {epoch+1}/{fine_tune_epochs}:")
        print(f"  Context Loss: {running_context_loss / max(context_updated_samples, 1):.4f}")
        print(f"  DQN Loss: {running_dqn_loss / max(dqn_loss_count, 1):.4f}")
        print(f"  Context Updated Samples: {context_updated_samples}")
        print(f"  Average Reward: {avg_reward:.4f}")
        print(f"  Action Distribution (skip/apply): {action_dist}")
        
        # Validation
        val_results = evaluate_model(cnn_model, val_loader, class_weights, context_model, dqn_agent, threshold=0.5)
        print(f"Validation Results at Epoch {epoch+1}:")
        print(f"  Val Loss: {val_results['Test Loss']:.4f}")
        print(f"  Val Accuracy: {val_results['Accuracy']:.4f}")
        print(f"  Val Precision: {val_results['Precision']:.4f}")
        print(f"  Val Recall: {val_results['Recall']:.4f}")
        print(f"  Val F1 Score: {val_results['F1 Score']:.4f}")
        
        if val_results['Accuracy'] > best_val_accuracy:
            best_val_accuracy = val_results['Accuracy']
            epochs_no_improve = 0
            best_context_state = context_model.state_dict().copy()
            best_dqn_state = dqn_agent.policy_net.state_dict().copy()
            print(f"✓ Updated best adversarial model states (Accuracy: {best_val_accuracy:.4f})")
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs.")
                break
    
    # Load best models
    if best_context_state is not None:
        context_model.load_state_dict(best_context_state)
        print("Loaded best context model")
    
    if best_dqn_state is not None:
        dqn_agent.policy_net.load_state_dict(best_dqn_state)
        print("Loaded best DQN model")
    
    # Save best models
    os.makedirs('Models', exist_ok=True)
    
    torch.save({
        'context_model_state_dict': context_model.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes
    }, 'Models/adversarial_best_context.pth')
    print("Saved best adversarial Context model")
    
    torch.save({
        'dqn_policy_net_state_dict': dqn_agent.policy_net.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes,
        'replay_buffer': list(dqn_agent.replay_buffer.buffer)
    }, 'Models/adversarial_best_dqn.pth')
    print("Saved best adversarial DQN model with replay buffer")
    
    return cnn_model, dqn_agent, context_model

# Main execution
def main():
    base_epoch = 200
    base_patience = 50
    adver_epoch = 200
    adver_patience = 20
    
    print("=" * 60)
    print("Starting Adversarial Training System for Network Traffic Classification")
    print("=" * 60)
    
    # Load data
    train_loader, val_loader, test_loader, full_loader, num_classes, input_length, class_counts = load_data()
    if train_loader is None or full_loader is None:
        print("Failed to load data. Exiting.")
        return
    
    print(f"\nDataset Statistics:")
    print(f"  - Number of classes: {num_classes}")
    print(f"  - Input feature length: {input_length}")
    print(f"  - Class distribution (train): {class_counts}")
    
    # Train and evaluate initial CNN
    print("\n" + "=" * 60)
    print("Training Initial CNN Model")
    print("=" * 60)
    
    cnn_model = CNN1D(input_length, num_classes).to(device)
    cnn_model = train_initial_cnn(cnn_model, train_loader, val_loader, class_counts, base_epoch, base_patience)
    
    os.makedirs('Models', exist_ok=True)
    
    torch.save({
        'model_state_dict': cnn_model.state_dict(),
        'input_length': input_length,
        'num_classes': num_classes
    }, 'Models/initial_cnn_model.pth')
    print("Saved initial CNN model")
    
    class_weights = torch.FloatTensor(1.0 / class_counts).to(device)
    initial_results = evaluate_model(cnn_model, test_loader, class_weights)
    print("\n" + "=" * 60)
    print("Initial CNN Test Results:")
    print("=" * 60)
    print(f"  Test Loss: {initial_results['Test Loss']:.4f}")
    print(f"  Accuracy: {initial_results['Accuracy']:.4f}")
    print(f"  Precision: {initial_results['Precision']:.4f}")
    print(f"  Recall: {initial_results['Recall']:.4f}")
    print(f"  F1 Score: {initial_results['F1 Score']:.4f}")
    
    # Initialize DQN and Context models
    print("\n" + "=" * 60)
    print("Initializing Adversarial Components")
    print("=" * 60)
    
    dqn_agent = DQNSelectorAgent(input_length + 1, device)
    context_model = ContextAwareNetwork(input_length).to(device)
    
    print(f"DQN Agent initialized with input size: {input_length + 1}")
    print(f"Context Model initialized with input size: {input_length}")
    
    # Train adversarial system
    print("\n" + "=" * 60)
    print("Starting Adversarial Training")
    print("=" * 60)
    
    cnn_model, dqn_agent, context_model = train_adversarial_system(
        cnn_model, dqn_agent, context_model, full_loader, val_loader, class_counts, 
        input_length, num_classes, adver_epoch, adver_patience
    )
    
    # Evaluate adversarial system
    print("\n" + "=" * 60)
    print("Final Evaluation - Adversarial System")
    print("=" * 60)
    
    adversarial_results = evaluate_model(cnn_model, test_loader, class_weights, context_model, dqn_agent, threshold=0.5)
    print("Adversarial System Test Results:")
    print(f"  Test Loss: {adversarial_results['Test Loss']:.4f}")
    print(f"  Accuracy: {adversarial_results['Accuracy']:.4f}")
    print(f"  Precision: {adversarial_results['Precision']:.4f}")
    print(f"  Recall: {adversarial_results['Recall']:.4f}")
    print(f"  F1 Score: {adversarial_results['F1 Score']:.4f}")
    
    # Comparison
    print("\n" + "=" * 60)
    print("Performance Improvement Summary")
    print("=" * 60)
    print(f"Accuracy Improvement: {(adversarial_results['Accuracy'] - initial_results['Accuracy']) * 100:+.2f}%")
    print(f"F1 Score Improvement: {(adversarial_results['F1 Score'] - initial_results['F1 Score']) * 100:+.2f}%")
    print(f"Precision Improvement: {(adversarial_results['Precision'] - initial_results['Precision']) * 100:+.2f}%")
    print(f"Recall Improvement: {(adversarial_results['Recall'] - initial_results['Recall']) * 100:+.2f}%")
    
    print("\nTraining completed successfully!")
# Out:
# Using device: cuda

# %% [markdown]
# ## RUN

# %%
if __name__ == "__main__":
    main()
# Out:
# ============================================================
# Starting Adversarial Training System for Network Traffic Classification
# ============================================================
# Detected 5 classes in the dataset
# Classes: ['HTTP' 'SFTP' 'SMTP' 'SSH' 'VIDEO']
# Class distribution in training data: [2126  288  276  217 1374]
# Class distribution in validation data: [714  76 118  89 430]
# Class distribution in test data: [687  82 106 110 443]
# Total training samples: 4281, validation samples: 1427, test samples: 1428
# Input length: 36
# Full dataset size for adversarial training: 4281
#
# Dataset Statistics:
#   - Number of classes: 5
#   - Input feature length: 36
#   - Class distribution (train): [2126  288  276  217 1374]
#
# ============================================================
# Training Initial CNN Model
# ============================================================
# Initial CNN Epoch 1/200, Train Loss: 0.7564, Val Loss: 0.7198, Val Accuracy: 0.4695
# Initial CNN Epoch 2/200, Train Loss: 0.1875, Val Loss: 0.4070, Val Accuracy: 0.7295
# Initial CNN Epoch 3/200, Train Loss: 0.1107, Val Loss: 0.2940, Val Accuracy: 0.8255
# Initial CNN Epoch 4/200, Train Loss: 0.0920, Val Loss: 0.2565, Val Accuracy: 0.8374
# Initial CNN Epoch 5/200, Train Loss: 0.0844, Val Loss: 0.2643, Val Accuracy: 0.8472
# Initial CNN Epoch 6/200, Train Loss: 0.0721, Val Loss: 0.2449, Val Accuracy: 0.8500
# Initial CNN Epoch 7/200, Train Loss: 0.0654, Val Loss: 0.2473, Val Accuracy: 0.8374
# Initial CNN Epoch 8/200, Train Loss: 0.0607, Val Loss: 0.2729, Val Accuracy: 0.8570
# Initial CNN Epoch 9/200, Train Loss: 0.0725, Val Loss: 0.2379, Val Accuracy: 0.8648
# Initial CNN Epoch 10/200, Train Loss: 0.0622, Val Loss: 0.1851, Val Accuracy: 0.8493
# Initial CNN Epoch 11/200, Train Loss: 0.0578, Val Loss: 0.1987, Val Accuracy: 0.8626
# Initial CNN Epoch 12/200, Train Loss: 0.0531, Val Loss: 0.2120, Val Accuracy: 0.8753
# Initial CNN Epoch 13/200, Train Loss: 0.0482, Val Loss: 0.2124, Val Accuracy: 0.8746
# Initial CNN Epoch 14/200, Train Loss: 0.0477, Val Loss: 0.2054, Val Accuracy: 0.8591
# Initial CNN Epoch 15/200, Train Loss: 0.0450, Val Loss: 0.1866, Val Accuracy: 0.8655
# Initial CNN Epoch 16/200, Train Loss: 0.0432, Val Loss: 0.2613, Val Accuracy: 0.8704
# Initial CNN Epoch 17/200, Train Loss: 0.0385, Val Loss: 0.2918, Val Accuracy: 0.8746
# Initial CNN Epoch 18/200, Train Loss: 0.0373, Val Loss: 0.1914, Val Accuracy: 0.8605
# Initial CNN Epoch 19/200, Train Loss: 0.0470, Val Loss: 0.2513, Val Accuracy: 0.8725
# Initial CNN Epoch 20/200, Train Loss: 0.0495, Val Loss: 0.1868, Val Accuracy: 0.8633
# Initial CNN Epoch 21/200, Train Loss: 0.0465, Val Loss: 0.2497, Val Accuracy: 0.8767
# Initial CNN Epoch 22/200, Train Loss: 0.0414, Val Loss: 0.2355, Val Accuracy: 0.8732
# Initial CNN Epoch 23/200, Train Loss: 0.0410, Val Loss: 0.2489, Val Accuracy: 0.8718
# Initial CNN Epoch 24/200, Train Loss: 0.0430, Val Loss: 0.2225, Val Accuracy: 0.8809
# Initial CNN Epoch 25/200, Train Loss: 0.0393, Val Loss: 0.3053, Val Accuracy: 0.8753
# Initial CNN Epoch 26/200, Train Loss: 0.0398, Val Loss: 0.2741, Val Accuracy: 0.8760
# Initial CNN Epoch 27/200, Train Loss: 0.0440, Val Loss: 0.1999, Val Accuracy: 0.8732
# Initial CNN Epoch 28/200, Train Loss: 0.0346, Val Loss: 0.2145, Val Accuracy: 0.8746
# Initial CNN Epoch 29/200, Train Loss: 0.0288, Val Loss: 0.2072, Val Accuracy: 0.8795
# Initial CNN Epoch 30/200, Train Loss: 0.0313, Val Loss: 0.2213, Val Accuracy: 0.8802
# Initial CNN Epoch 31/200, Train Loss: 0.0315, Val Loss: 0.2144, Val Accuracy: 0.8851
# Initial CNN Epoch 32/200, Train Loss: 0.0333, Val Loss: 0.2486, Val Accuracy: 0.8851
# Initial CNN Epoch 33/200, Train Loss: 0.0288, Val Loss: 0.2104, Val Accuracy: 0.8844
# Initial CNN Epoch 34/200, Train Loss: 0.0383, Val Loss: 0.3143, Val Accuracy: 0.8626
# Initial CNN Epoch 35/200, Train Loss: 0.0525, Val Loss: 0.2022, Val Accuracy: 0.8795
# Initial CNN Epoch 36/200, Train Loss: 0.0362, Val Loss: 0.1957, Val Accuracy: 0.8830
# Initial CNN Epoch 37/200, Train Loss: 0.0332, Val Loss: 0.1825, Val Accuracy: 0.8718
# Initial CNN Epoch 38/200, Train Loss: 0.0356, Val Loss: 0.2082, Val Accuracy: 0.8893
# Initial CNN Epoch 39/200, Train Loss: 0.0332, Val Loss: 0.2119, Val Accuracy: 0.8823
# Initial CNN Epoch 40/200, Train Loss: 0.0359, Val Loss: 0.2395, Val Accuracy: 0.8886
# Initial CNN Epoch 41/200, Train Loss: 0.0297, Val Loss: 0.2198, Val Accuracy: 0.8879
# Initial CNN Epoch 42/200, Train Loss: 0.0326, Val Loss: 0.2488, Val Accuracy: 0.8767
# Initial CNN Epoch 43/200, Train Loss: 0.0499, Val Loss: 0.1771, Val Accuracy: 0.8816
# Initial CNN Epoch 44/200, Train Loss: 0.0309, Val Loss: 0.1884, Val Accuracy: 0.8851
# Initial CNN Epoch 45/200, Train Loss: 0.0289, Val Loss: 0.2050, Val Accuracy: 0.8865
# Initial CNN Epoch 46/200, Train Loss: 0.0319, Val Loss: 0.2104, Val Accuracy: 0.8900
# Initial CNN Epoch 47/200, Train Loss: 0.0334, Val Loss: 0.2240, Val Accuracy: 0.8788
# Initial CNN Epoch 48/200, Train Loss: 0.0361, Val Loss: 0.2066, Val Accuracy: 0.8788
# Initial CNN Epoch 49/200, Train Loss: 0.0334, Val Loss: 0.2013, Val Accuracy: 0.8844
# Initial CNN Epoch 50/200, Train Loss: 0.0312, Val Loss: 0.1821, Val Accuracy: 0.8886
# Initial CNN Epoch 51/200, Train Loss: 0.0296, Val Loss: 0.1754, Val Accuracy: 0.8886
# Initial CNN Epoch 52/200, Train Loss: 0.0253, Val Loss: 0.1998, Val Accuracy: 0.8907
# Initial CNN Epoch 53/200, Train Loss: 0.0268, Val Loss: 0.2359, Val Accuracy: 0.8753
# Initial CNN Epoch 54/200, Train Loss: 0.0353, Val Loss: 0.2002, Val Accuracy: 0.8844
# Initial CNN Epoch 55/200, Train Loss: 0.0470, Val Loss: 0.2091, Val Accuracy: 0.8781
# Initial CNN Epoch 56/200, Train Loss: 0.0282, Val Loss: 0.2127, Val Accuracy: 0.8879
# Initial CNN Epoch 57/200, Train Loss: 0.0338, Val Loss: 0.2391, Val Accuracy: 0.8788
# Initial CNN Epoch 58/200, Train Loss: 0.0355, Val Loss: 0.2076, Val Accuracy: 0.8795
# Initial CNN Epoch 59/200, Train Loss: 0.0331, Val Loss: 0.2590, Val Accuracy: 0.8900
# Initial CNN Epoch 60/200, Train Loss: 0.0335, Val Loss: 0.1960, Val Accuracy: 0.8809
# Initial CNN Epoch 61/200, Train Loss: 0.0356, Val Loss: 0.2076, Val Accuracy: 0.8851
# Initial CNN Epoch 62/200, Train Loss: 0.0299, Val Loss: 0.1864, Val Accuracy: 0.8935
# Initial CNN Epoch 63/200, Train Loss: 0.0278, Val Loss: 0.2235, Val Accuracy: 0.8956
# Initial CNN Epoch 64/200, Train Loss: 0.0282, Val Loss: 0.2337, Val Accuracy: 0.8900
# Initial CNN Epoch 65/200, Train Loss: 0.0253, Val Loss: 0.2242, Val Accuracy: 0.8921
# Initial CNN Epoch 66/200, Train Loss: 0.0248, Val Loss: 0.2252, Val Accuracy: 0.8865
# Initial CNN Epoch 67/200, Train Loss: 0.0310, Val Loss: 0.2446, Val Accuracy: 0.8837
# Initial CNN Epoch 68/200, Train Loss: 0.0376, Val Loss: 0.2192, Val Accuracy: 0.8886
# Initial CNN Epoch 69/200, Train Loss: 0.0279, Val Loss: 0.1859, Val Accuracy: 0.9040
# Initial CNN Epoch 70/200, Train Loss: 0.0253, Val Loss: 0.2013, Val Accuracy: 0.9040
# Initial CNN Epoch 71/200, Train Loss: 0.0266, Val Loss: 0.1935, Val Accuracy: 0.9054
# Initial CNN Epoch 72/200, Train Loss: 0.0311, Val Loss: 0.1857, Val Accuracy: 0.8956
# Initial CNN Epoch 73/200, Train Loss: 0.0265, Val Loss: 0.1831, Val Accuracy: 0.8949
# Initial CNN Epoch 74/200, Train Loss: 0.0269, Val Loss: 0.2063, Val Accuracy: 0.8900
# Initial CNN Epoch 75/200, Train Loss: 0.0245, Val Loss: 0.1967, Val Accuracy: 0.8935
# Initial CNN Epoch 76/200, Train Loss: 0.0294, Val Loss: 0.1805, Val Accuracy: 0.8900
# Initial CNN Epoch 77/200, Train Loss: 0.0264, Val Loss: 0.1792, Val Accuracy: 0.8949
# Initial CNN Epoch 78/200, Train Loss: 0.0251, Val Loss: 0.1934, Val Accuracy: 0.8991
# Initial CNN Epoch 79/200, Train Loss: 0.0262, Val Loss: 0.1956, Val Accuracy: 0.8935
# Initial CNN Epoch 80/200, Train Loss: 0.0234, Val Loss: 0.1921, Val Accuracy: 0.8977
# Initial CNN Epoch 81/200, Train Loss: 0.0271, Val Loss: 0.1976, Val Accuracy: 0.8963
# Initial CNN Epoch 82/200, Train Loss: 0.0281, Val Loss: 0.1824, Val Accuracy: 0.8970
# Initial CNN Epoch 83/200, Train Loss: 0.0264, Val Loss: 0.1852, Val Accuracy: 0.8963
# Initial CNN Epoch 84/200, Train Loss: 0.0239, Val Loss: 0.1865, Val Accuracy: 0.9012
# Initial CNN Epoch 85/200, Train Loss: 0.0218, Val Loss: 0.2685, Val Accuracy: 0.8921
# Initial CNN Epoch 86/200, Train Loss: 0.0232, Val Loss: 0.2431, Val Accuracy: 0.8991
# Initial CNN Epoch 87/200, Train Loss: 0.0262, Val Loss: 0.2439, Val Accuracy: 0.8956
# Initial CNN Epoch 88/200, Train Loss: 0.0248, Val Loss: 0.2460, Val Accuracy: 0.9012
# Initial CNN Epoch 89/200, Train Loss: 0.0286, Val Loss: 0.2400, Val Accuracy: 0.8942
# Initial CNN Epoch 90/200, Train Loss: 0.0231, Val Loss: 0.2185, Val Accuracy: 0.9026
# Initial CNN Epoch 91/200, Train Loss: 0.0276, Val Loss: 0.2164, Val Accuracy: 0.9033
# Initial CNN Epoch 92/200, Train Loss: 0.0257, Val Loss: 0.2230, Val Accuracy: 0.9026
# Initial CNN Epoch 93/200, Train Loss: 0.0243, Val Loss: 0.2011, Val Accuracy: 0.8935
# Initial CNN Epoch 94/200, Train Loss: 0.0293, Val Loss: 0.2068, Val Accuracy: 0.9019
# Initial CNN Epoch 95/200, Train Loss: 0.0257, Val Loss: 0.2099, Val Accuracy: 0.8984
# Initial CNN Epoch 96/200, Train Loss: 0.0218, Val Loss: 0.2071, Val Accuracy: 0.8984
# Initial CNN Epoch 97/200, Train Loss: 0.0250, Val Loss: 0.1993, Val Accuracy: 0.8865
# Initial CNN Epoch 98/200, Train Loss: 0.0235, Val Loss: 0.2014, Val Accuracy: 0.8949
# Initial CNN Epoch 99/200, Train Loss: 0.0229, Val Loss: 0.1795, Val Accuracy: 0.8970
# Initial CNN Epoch 100/200, Train Loss: 0.0249, Val Loss: 0.1652, Val Accuracy: 0.9012
# Initial CNN Epoch 101/200, Train Loss: 0.0221, Val Loss: 0.1804, Val Accuracy: 0.9005
# Initial CNN Epoch 102/200, Train Loss: 0.0229, Val Loss: 0.1891, Val Accuracy: 0.8900
# Initial CNN Epoch 103/200, Train Loss: 0.0210, Val Loss: 0.1934, Val Accuracy: 0.8970
# Initial CNN Epoch 104/200, Train Loss: 0.0213, Val Loss: 0.1962, Val Accuracy: 0.9019
# Initial CNN Epoch 105/200, Train Loss: 0.0243, Val Loss: 0.1897, Val Accuracy: 0.8914
# Initial CNN Epoch 106/200, Train Loss: 0.0278, Val Loss: 0.1891, Val Accuracy: 0.9012
# Initial CNN Epoch 107/200, Train Loss: 0.0231, Val Loss: 0.1758, Val Accuracy: 0.8991
# Initial CNN Epoch 108/200, Train Loss: 0.0250, Val Loss: 0.1853, Val Accuracy: 0.9089
# Initial CNN Epoch 109/200, Train Loss: 0.0238, Val Loss: 0.2075, Val Accuracy: 0.8970
# Initial CNN Epoch 110/200, Train Loss: 0.0253, Val Loss: 0.1947, Val Accuracy: 0.8977
# Initial CNN Epoch 111/200, Train Loss: 0.0241, Val Loss: 0.1888, Val Accuracy: 0.8977
# Initial CNN Epoch 112/200, Train Loss: 0.0255, Val Loss: 0.1884, Val Accuracy: 0.8970
# Initial CNN Epoch 113/200, Train Loss: 0.0237, Val Loss: 0.1934, Val Accuracy: 0.8991
# Initial CNN Epoch 114/200, Train Loss: 0.0228, Val Loss: 0.1844, Val Accuracy: 0.9005
# Initial CNN Epoch 115/200, Train Loss: 0.0260, Val Loss: 0.1920, Val Accuracy: 0.8991
# Initial CNN Epoch 116/200, Train Loss: 0.0235, Val Loss: 0.1909, Val Accuracy: 0.8998
# Initial CNN Epoch 117/200, Train Loss: 0.0200, Val Loss: 0.1919, Val Accuracy: 0.8998
# Initial CNN Epoch 118/200, Train Loss: 0.0210, Val Loss: 0.2013, Val Accuracy: 0.8900
# Initial CNN Epoch 119/200, Train Loss: 0.0228, Val Loss: 0.1995, Val Accuracy: 0.8956
# Initial CNN Epoch 120/200, Train Loss: 0.0224, Val Loss: 0.2176, Val Accuracy: 0.9047
# Initial CNN Epoch 121/200, Train Loss: 0.0203, Val Loss: 0.2285, Val Accuracy: 0.8998
# Initial CNN Epoch 122/200, Train Loss: 0.0214, Val Loss: 0.2064, Val Accuracy: 0.9040
# Initial CNN Epoch 123/200, Train Loss: 0.0209, Val Loss: 0.1989, Val Accuracy: 0.9103
# Initial CNN Epoch 124/200, Train Loss: 0.0202, Val Loss: 0.2084, Val Accuracy: 0.9019
# Initial CNN Epoch 125/200, Train Loss: 0.0194, Val Loss: 0.2112, Val Accuracy: 0.8991
# Initial CNN Epoch 126/200, Train Loss: 0.0238, Val Loss: 0.2075, Val Accuracy: 0.9089
# Initial CNN Epoch 127/200, Train Loss: 0.0224, Val Loss: 0.1982, Val Accuracy: 0.9096
# Initial CNN Epoch 128/200, Train Loss: 0.0196, Val Loss: 0.2147, Val Accuracy: 0.9026
# Initial CNN Epoch 129/200, Train Loss: 0.0198, Val Loss: 0.2119, Val Accuracy: 0.9012
# Initial CNN Epoch 130/200, Train Loss: 0.0222, Val Loss: 0.2054, Val Accuracy: 0.9047
# Initial CNN Epoch 131/200, Train Loss: 0.0207, Val Loss: 0.1910, Val Accuracy: 0.9075
# Initial CNN Epoch 132/200, Train Loss: 0.0190, Val Loss: 0.1950, Val Accuracy: 0.9047
# Initial CNN Epoch 133/200, Train Loss: 0.0225, Val Loss: 0.1976, Val Accuracy: 0.9103
# Initial CNN Epoch 134/200, Train Loss: 0.0187, Val Loss: 0.2000, Val Accuracy: 0.9019
# Initial CNN Epoch 135/200, Train Loss: 0.0225, Val Loss: 0.1937, Val Accuracy: 0.9012
# Initial CNN Epoch 136/200, Train Loss: 0.0210, Val Loss: 0.1908, Val Accuracy: 0.9054
# Initial CNN Epoch 137/200, Train Loss: 0.0189, Val Loss: 0.1921, Val Accuracy: 0.9019
# Initial CNN Epoch 138/200, Train Loss: 0.0194, Val Loss: 0.2018, Val Accuracy: 0.8970
# Initial CNN Epoch 139/200, Train Loss: 0.0217, Val Loss: 0.1961, Val Accuracy: 0.9040
# Initial CNN Epoch 140/200, Train Loss: 0.0204, Val Loss: 0.1986, Val Accuracy: 0.9089
# Initial CNN Epoch 141/200, Train Loss: 0.0193, Val Loss: 0.2019, Val Accuracy: 0.9012
# Initial CNN Epoch 142/200, Train Loss: 0.0192, Val Loss: 0.2042, Val Accuracy: 0.9089
# Initial CNN Epoch 143/200, Train Loss: 0.0175, Val Loss: 0.2086, Val Accuracy: 0.9047
# Initial CNN Epoch 144/200, Train Loss: 0.0196, Val Loss: 0.1881, Val Accuracy: 0.9075
# Initial CNN Epoch 145/200, Train Loss: 0.0208, Val Loss: 0.1976, Val Accuracy: 0.9054
# Initial CNN Epoch 146/200, Train Loss: 0.0201, Val Loss: 0.2051, Val Accuracy: 0.9103
# Initial CNN Epoch 147/200, Train Loss: 0.0181, Val Loss: 0.1987, Val Accuracy: 0.9075
# Initial CNN Epoch 148/200, Train Loss: 0.0209, Val Loss: 0.1877, Val Accuracy: 0.9068
# Initial CNN Epoch 149/200, Train Loss: 0.0190, Val Loss: 0.1892, Val Accuracy: 0.9075
# Initial CNN Epoch 150/200, Train Loss: 0.0182, Val Loss: 0.1973, Val Accuracy: 0.9026
# Early stopping triggered after 150 epochs.
# Saved initial CNN model
#
# ============================================================
# Initial CNN Test Results:
# ============================================================
#   Test Loss: 0.1171
#   Accuracy: 0.9076
#   Precision: 0.9143
#   Recall: 0.9076
#   F1 Score: 0.9085
#
# ============================================================
# Initializing Adversarial Components
# ============================================================
# Selected num_heads=4 for input_size=36
# DQN Agent initialized with input size: 37
# Context Model initialized with input size: 36
#
# ============================================================
# Starting Adversarial Training
# ============================================================
# Pre-training ContextAwareNetwork...
# Pretrain Epoch 1/20, Loss: 1.5344
# Pretrain Epoch 2/20, Loss: 0.3258
# Pretrain Epoch 3/20, Loss: 0.1546
# Pretrain Epoch 4/20, Loss: 0.1229
# Pretrain Epoch 5/20, Loss: 0.0889
# Pretrain Epoch 6/20, Loss: 0.0786
# Pretrain Epoch 7/20, Loss: 0.0737
# Pretrain Epoch 8/20, Loss: 0.0554
# Pretrain Epoch 9/20, Loss: 0.0636
# Pretrain Epoch 10/20, Loss: 0.0536
# Pretrain Epoch 11/20, Loss: 0.0470
# Pretrain Epoch 12/20, Loss: 0.0459
# Pretrain Epoch 13/20, Loss: 0.0572
# Pretrain Epoch 14/20, Loss: 0.0436
# Pretrain Epoch 15/20, Loss: 0.0433
# Pretrain Epoch 16/20, Loss: 0.0380
# Pretrain Epoch 17/20, Loss: 0.0326
# Pretrain Epoch 18/20, Loss: 0.0314
# Pretrain Epoch 19/20, Loss: 0.0268
# Pretrain Epoch 20/20, Loss: 0.0299
# Starting adversarial training on full dataset...
# Adversarial Epoch 1/200:
#   Context Loss: 0.1731
#   DQN Loss: 1.0405
#   Context Updated Samples: 2157
#   Average Reward: 0.7188
#   Action Distribution (skip/apply): [2124 2157]
# Validation Results at Epoch 1:
#   Val Loss: 0.2291
#   Val Accuracy: 0.8521
#   Val Precision: 0.8736
#   Val Recall: 0.8521
#   Val F1 Score: 0.8543
# ✓ Updated best adversarial model states (Accuracy: 0.8521)
# Adversarial Epoch 2/200:
#   Context Loss: 0.1961
#   DQN Loss: 0.6906
#   Context Updated Samples: 2147
#   Average Reward: 0.7151
#   Action Distribution (skip/apply): [2134 2147]
# Validation Results at Epoch 2:
#   Val Loss: 0.2470
#   Val Accuracy: 0.8479
#   Val Precision: 0.8723
#   Val Recall: 0.8479
#   Val F1 Score: 0.8507
# Adversarial Epoch 3/200:
#   Context Loss: 0.1956
#   DQN Loss: 0.4738
#   Context Updated Samples: 2097
#   Average Reward: 0.7283
#   Action Distribution (skip/apply): [2184 2097]
# Validation Results at Epoch 3:
#   Val Loss: 0.2393
#   Val Accuracy: 0.8479
#   Val Precision: 0.8842
#   Val Recall: 0.8479
#   Val F1 Score: 0.8506
# Adversarial Epoch 4/200:
#   Context Loss: 0.1723
#   DQN Loss: 0.3777
#   Context Updated Samples: 2107
#   Average Reward: 0.7357
#   Action Distribution (skip/apply): [2174 2107]
# Validation Results at Epoch 4:
#   Val Loss: 0.2102
#   Val Accuracy: 0.8500
#   Val Precision: 0.8905
#   Val Recall: 0.8500
#   Val F1 Score: 0.8523
# Adversarial Epoch 5/200:
#   Context Loss: 0.1679
#   DQN Loss: 0.3746
#   Context Updated Samples: 2151
#   Average Reward: 0.7288
#   Action Distribution (skip/apply): [2130 2151]
# Validation Results at Epoch 5:
#   Val Loss: 0.2302
#   Val Accuracy: 0.8409
#   Val Precision: 0.8881
#   Val Recall: 0.8409
#   Val F1 Score: 0.8428
# Adversarial Epoch 6/200:
#   Context Loss: 0.1852
#   DQN Loss: 0.3524
#   Context Updated Samples: 2171
#   Average Reward: 0.7063
#   Action Distribution (skip/apply): [2110 2171]
# Validation Results at Epoch 6:
#   Val Loss: 0.2503
#   Val Accuracy: 0.8479
#   Val Precision: 0.8723
#   Val Recall: 0.8479
#   Val F1 Score: 0.8497
# Adversarial Epoch 7/200:
#   Context Loss: 0.1936
#   DQN Loss: 0.3311
#   Context Updated Samples: 2105
#   Average Reward: 0.7325
#   Action Distribution (skip/apply): [2176 2105]
# Validation Results at Epoch 7:
#   Val Loss: 0.2922
#   Val Accuracy: 0.8584
#   Val Precision: 0.8738
#   Val Recall: 0.8584
#   Val F1 Score: 0.8605
# ✓ Updated best adversarial model states (Accuracy: 0.8584)
# Adversarial Epoch 8/200:
#   Context Loss: 0.2250
#   DQN Loss: 0.3170
#   Context Updated Samples: 1978
#   Average Reward: 0.7728
#   Action Distribution (skip/apply): [2303 1978]
# Validation Results at Epoch 8:
#   Val Loss: 0.2587
#   Val Accuracy: 0.8451
#   Val Precision: 0.8838
#   Val Recall: 0.8451
#   Val F1 Score: 0.8477
# Adversarial Epoch 9/200:
#   Context Loss: 0.1842
#   DQN Loss: 0.3151
#   Context Updated Samples: 2126
#   Average Reward: 0.7237
#   Action Distribution (skip/apply): [2155 2126]
# Validation Results at Epoch 9:
#   Val Loss: 0.2475
#   Val Accuracy: 0.8227
#   Val Precision: 0.8786
#   Val Recall: 0.8227
#   Val F1 Score: 0.8246
# Adversarial Epoch 10/200:
#   Context Loss: 0.1918
#   DQN Loss: 0.3065
#   Context Updated Samples: 2084
#   Average Reward: 0.7373
#   Action Distribution (skip/apply): [2197 2084]
# Validation Results at Epoch 10:
#   Val Loss: 0.1913
#   Val Accuracy: 0.8514
#   Val Precision: 0.8880
#   Val Recall: 0.8514
#   Val F1 Score: 0.8537
# Adversarial Epoch 11/200:
#   Context Loss: 0.1665
#   DQN Loss: 0.2954
#   Context Updated Samples: 2001
#   Average Reward: 0.7651
#   Action Distribution (skip/apply): [2280 2001]
# Validation Results at Epoch 11:
#   Val Loss: 0.1870
#   Val Accuracy: 0.8598
#   Val Precision: 0.8749
#   Val Recall: 0.8598
#   Val F1 Score: 0.8616
# ✓ Updated best adversarial model states (Accuracy: 0.8598)
# Adversarial Epoch 12/200:
#   Context Loss: 0.1740
#   DQN Loss: 0.3100
#   Context Updated Samples: 1964
#   Average Reward: 0.7789
#   Action Distribution (skip/apply): [2317 1964]
# Validation Results at Epoch 12:
#   Val Loss: 0.1807
#   Val Accuracy: 0.8493
#   Val Precision: 0.8894
#   Val Recall: 0.8493
#   Val F1 Score: 0.8514
# Adversarial Epoch 13/200:
#   Context Loss: 0.1651
#   DQN Loss: 0.2857
#   Context Updated Samples: 1976
#   Average Reward: 0.7733
#   Action Distribution (skip/apply): [2305 1976]
# Validation Results at Epoch 13:
#   Val Loss: 0.1777
#   Val Accuracy: 0.8633
#   Val Precision: 0.8923
#   Val Recall: 0.8633
#   Val F1 Score: 0.8656
# ✓ Updated best adversarial model states (Accuracy: 0.8633)
# Adversarial Epoch 14/200:
#   Context Loss: 0.1732
#   DQN Loss: 0.2967
#   Context Updated Samples: 2027
#   Average Reward: 0.7641
#   Action Distribution (skip/apply): [2254 2027]
# Validation Results at Epoch 14:
#   Val Loss: 0.1923
#   Val Accuracy: 0.8633
#   Val Precision: 0.8897
#   Val Recall: 0.8633
#   Val F1 Score: 0.8655
# Adversarial Epoch 15/200:
#   Context Loss: 0.1527
#   DQN Loss: 0.3036
#   Context Updated Samples: 1841
#   Average Reward: 0.8224
#   Action Distribution (skip/apply): [2440 1841]
# Validation Results at Epoch 15:
#   Val Loss: 0.2182
#   Val Accuracy: 0.8626
#   Val Precision: 0.8911
#   Val Recall: 0.8626
#   Val F1 Score: 0.8649
# Adversarial Epoch 16/200:
#   Context Loss: 0.1561
#   DQN Loss: 0.2894
#   Context Updated Samples: 2004
#   Average Reward: 0.7737
#   Action Distribution (skip/apply): [2277 2004]
# Validation Results at Epoch 16:
#   Val Loss: 0.2193
#   Val Accuracy: 0.8472
#   Val Precision: 0.8880
#   Val Recall: 0.8472
#   Val F1 Score: 0.8494
# Adversarial Epoch 17/200:
#   Context Loss: 0.1705
#   DQN Loss: 0.2782
#   Context Updated Samples: 1884
#   Average Reward: 0.8081
#   Action Distribution (skip/apply): [2397 1884]
# Validation Results at Epoch 17:
#   Val Loss: 0.2118
#   Val Accuracy: 0.8619
#   Val Precision: 0.8939
#   Val Recall: 0.8619
#   Val F1 Score: 0.8642
# Adversarial Epoch 18/200:
#   Context Loss: 0.1651
#   DQN Loss: 0.2820
#   Context Updated Samples: 1826
#   Average Reward: 0.8180
#   Action Distribution (skip/apply): [2455 1826]
# Validation Results at Epoch 18:
#   Val Loss: 0.2108
#   Val Accuracy: 0.8556
#   Val Precision: 0.8915
#   Val Recall: 0.8556
#   Val F1 Score: 0.8582
# Adversarial Epoch 19/200:
#   Context Loss: 0.1481
#   DQN Loss: 0.2729
#   Context Updated Samples: 1919
#   Average Reward: 0.8025
#   Action Distribution (skip/apply): [2362 1919]
# Validation Results at Epoch 19:
#   Val Loss: 0.2765
#   Val Accuracy: 0.8444
#   Val Precision: 0.8911
#   Val Recall: 0.8444
#   Val F1 Score: 0.8469
# Adversarial Epoch 20/200:
#   Context Loss: 0.1515
#   DQN Loss: 0.2807
#   Context Updated Samples: 2012
#   Average Reward: 0.7867
#   Action Distribution (skip/apply): [2269 2012]
# Validation Results at Epoch 20:
#   Val Loss: 0.2225
#   Val Accuracy: 0.8648
#   Val Precision: 0.8951
#   Val Recall: 0.8648
#   Val F1 Score: 0.8673
# ✓ Updated best adversarial model states (Accuracy: 0.8648)
# Adversarial Epoch 21/200:
#   Context Loss: 0.1572
#   DQN Loss: 0.2755
#   Context Updated Samples: 1915
#   Average Reward: 0.7936
#   Action Distribution (skip/apply): [2366 1915]
# Validation Results at Epoch 21:
#   Val Loss: 0.2959
#   Val Accuracy: 0.8465
#   Val Precision: 0.8911
#   Val Recall: 0.8465
#   Val F1 Score: 0.8494
# Adversarial Epoch 22/200:
#   Context Loss: 0.1611
#   DQN Loss: 0.2647
#   Context Updated Samples: 1952
#   Average Reward: 0.7920
#   Action Distribution (skip/apply): [2329 1952]
# Validation Results at Epoch 22:
#   Val Loss: 0.2210
#   Val Accuracy: 0.8690
#   Val Precision: 0.8899
#   Val Recall: 0.8690
#   Val F1 Score: 0.8713
# ✓ Updated best adversarial model states (Accuracy: 0.8690)
# Adversarial Epoch 23/200:
#   Context Loss: 0.1504
#   DQN Loss: 0.2593
#   Context Updated Samples: 1836
#   Average Reward: 0.8208
#   Action Distribution (skip/apply): [2445 1836]
# Validation Results at Epoch 23:
#   Val Loss: 0.2216
#   Val Accuracy: 0.8633
#   Val Precision: 0.8911
#   Val Recall: 0.8633
#   Val F1 Score: 0.8657
# Adversarial Epoch 24/200:
#   Context Loss: 0.1599
#   DQN Loss: 0.2728
#   Context Updated Samples: 2013
#   Average Reward: 0.7656
#   Action Distribution (skip/apply): [2268 2013]
# Validation Results at Epoch 24:
#   Val Loss: 0.2249
#   Val Accuracy: 0.8683
#   Val Precision: 0.8880
#   Val Recall: 0.8683
#   Val F1 Score: 0.8704
# Adversarial Epoch 25/200:
#   Context Loss: 0.1475
#   DQN Loss: 0.2708
#   Context Updated Samples: 2073
#   Average Reward: 0.7537
#   Action Distribution (skip/apply): [2208 2073]
# Validation Results at Epoch 25:
#   Val Loss: 0.2470
#   Val Accuracy: 0.8598
#   Val Precision: 0.8876
#   Val Recall: 0.8598
#   Val F1 Score: 0.8621
# Adversarial Epoch 26/200:
#   Context Loss: 0.1780
#   DQN Loss: 0.2622
#   Context Updated Samples: 1838
#   Average Reward: 0.8295
#   Action Distribution (skip/apply): [2443 1838]
# Validation Results at Epoch 26:
#   Val Loss: 0.2306
#   Val Accuracy: 0.8626
#   Val Precision: 0.8920
#   Val Recall: 0.8626
#   Val F1 Score: 0.8651
# Adversarial Epoch 27/200:
#   Context Loss: 0.1553
#   DQN Loss: 0.2582
#   Context Updated Samples: 1871
#   Average Reward: 0.8241
#   Action Distribution (skip/apply): [2410 1871]
# Validation Results at Epoch 27:
#   Val Loss: 0.1825
#   Val Accuracy: 0.8767
#   Val Precision: 0.8856
#   Val Recall: 0.8767
#   Val F1 Score: 0.8784
# ✓ Updated best adversarial model states (Accuracy: 0.8767)
# Adversarial Epoch 28/200:
#   Context Loss: 0.1685
#   DQN Loss: 0.2555
#   Context Updated Samples: 2043
#   Average Reward: 0.7697
#   Action Distribution (skip/apply): [2238 2043]
# Validation Results at Epoch 28:
#   Val Loss: 0.2384
#   Val Accuracy: 0.8591
#   Val Precision: 0.8834
#   Val Recall: 0.8591
#   Val F1 Score: 0.8615
# Adversarial Epoch 29/200:
#   Context Loss: 0.1581
#   DQN Loss: 0.2562
#   Context Updated Samples: 1837
#   Average Reward: 0.8145
#   Action Distribution (skip/apply): [2444 1837]
# Validation Results at Epoch 29:
#   Val Loss: 0.2525
#   Val Accuracy: 0.8605
#   Val Precision: 0.8914
#   Val Recall: 0.8605
#   Val F1 Score: 0.8630
# Adversarial Epoch 30/200:
#   Context Loss: 0.1884
#   DQN Loss: 0.2625
#   Context Updated Samples: 1923
#   Average Reward: 0.7875
#   Action Distribution (skip/apply): [2358 1923]
# Validation Results at Epoch 30:
#   Val Loss: 0.2687
#   Val Accuracy: 0.8669
#   Val Precision: 0.8848
#   Val Recall: 0.8669
#   Val F1 Score: 0.8692
# Adversarial Epoch 31/200:
#   Context Loss: 0.1769
#   DQN Loss: 0.2500
#   Context Updated Samples: 1858
#   Average Reward: 0.8227
#   Action Distribution (skip/apply): [2423 1858]
# Validation Results at Epoch 31:
#   Val Loss: 0.2164
#   Val Accuracy: 0.8591
#   Val Precision: 0.8914
#   Val Recall: 0.8591
#   Val F1 Score: 0.8612
# Adversarial Epoch 32/200:
#   Context Loss: 0.1536
#   DQN Loss: 0.2592
#   Context Updated Samples: 1774
#   Average Reward: 0.8436
#   Action Distribution (skip/apply): [2507 1774]
# Validation Results at Epoch 32:
#   Val Loss: 0.2189
#   Val Accuracy: 0.8669
#   Val Precision: 0.8902
#   Val Recall: 0.8669
#   Val F1 Score: 0.8692
# Adversarial Epoch 33/200:
#   Context Loss: 0.1491
#   DQN Loss: 0.2622
#   Context Updated Samples: 1738
#   Average Reward: 0.8556
#   Action Distribution (skip/apply): [2543 1738]
# Validation Results at Epoch 33:
#   Val Loss: 0.2164
#   Val Accuracy: 0.8655
#   Val Precision: 0.8942
#   Val Recall: 0.8655
#   Val F1 Score: 0.8679
# Adversarial Epoch 34/200:
#   Context Loss: 0.1572
#   DQN Loss: 0.2459
#   Context Updated Samples: 1828
#   Average Reward: 0.8413
#   Action Distribution (skip/apply): [2453 1828]
# Validation Results at Epoch 34:
#   Val Loss: 0.1890
#   Val Accuracy: 0.8767
#   Val Precision: 0.8945
#   Val Recall: 0.8767
#   Val F1 Score: 0.8787
# Adversarial Epoch 35/200:
#   Context Loss: 0.1432
#   DQN Loss: 0.2556
#   Context Updated Samples: 1673
#   Average Reward: 0.8980
#   Action Distribution (skip/apply): [2608 1673]
# Validation Results at Epoch 35:
#   Val Loss: 0.2139
#   Val Accuracy: 0.8746
#   Val Precision: 0.8905
#   Val Recall: 0.8746
#   Val F1 Score: 0.8767
# Adversarial Epoch 36/200:
#   Context Loss: 0.1305
#   DQN Loss: 0.2406
#   Context Updated Samples: 1762
#   Average Reward: 0.8662
#   Action Distribution (skip/apply): [2519 1762]
# Validation Results at Epoch 36:
#   Val Loss: 0.2473
#   Val Accuracy: 0.8676
#   Val Precision: 0.8995
#   Val Recall: 0.8676
#   Val F1 Score: 0.8699
# Adversarial Epoch 37/200:
#   Context Loss: 0.1397
#   DQN Loss: 0.2488
#   Context Updated Samples: 1795
#   Average Reward: 0.8465
#   Action Distribution (skip/apply): [2486 1795]
# Validation Results at Epoch 37:
#   Val Loss: 0.2038
#   Val Accuracy: 0.8739
#   Val Precision: 0.9020
#   Val Recall: 0.8739
#   Val F1 Score: 0.8762
# Adversarial Epoch 38/200:
#   Context Loss: 0.1509
#   DQN Loss: 0.2469
#   Context Updated Samples: 1717
#   Average Reward: 0.8778
#   Action Distribution (skip/apply): [2564 1717]
# Validation Results at Epoch 38:
#   Val Loss: 0.2176
#   Val Accuracy: 0.8788
#   Val Precision: 0.8916
#   Val Recall: 0.8788
#   Val F1 Score: 0.8806
# ✓ Updated best adversarial model states (Accuracy: 0.8788)
# Adversarial Epoch 39/200:
#   Context Loss: 0.1484
#   DQN Loss: 0.2449
#   Context Updated Samples: 1711
#   Average Reward: 0.8680
#   Action Distribution (skip/apply): [2570 1711]
# Validation Results at Epoch 39:
#   Val Loss: 0.1928
#   Val Accuracy: 0.8704
#   Val Precision: 0.8962
#   Val Recall: 0.8704
#   Val F1 Score: 0.8726
# Adversarial Epoch 40/200:
#   Context Loss: 0.1410
#   DQN Loss: 0.2448
#   Context Updated Samples: 1823
#   Average Reward: 0.8360
#   Action Distribution (skip/apply): [2458 1823]
# Validation Results at Epoch 40:
#   Val Loss: 0.1814
#   Val Accuracy: 0.8837
#   Val Precision: 0.9025
#   Val Recall: 0.8837
#   Val F1 Score: 0.8856
# ✓ Updated best adversarial model states (Accuracy: 0.8837)
# Adversarial Epoch 41/200:
#   Context Loss: 0.1321
#   DQN Loss: 0.2578
#   Context Updated Samples: 1680
#   Average Reward: 0.8715
#   Action Distribution (skip/apply): [2601 1680]
# Validation Results at Epoch 41:
#   Val Loss: 0.2065
#   Val Accuracy: 0.8858
#   Val Precision: 0.9014
#   Val Recall: 0.8858
#   Val F1 Score: 0.8877
# ✓ Updated best adversarial model states (Accuracy: 0.8858)
# Adversarial Epoch 42/200:
#   Context Loss: 0.1411
#   DQN Loss: 0.2427
#   Context Updated Samples: 1837
#   Average Reward: 0.8388
#   Action Distribution (skip/apply): [2444 1837]
# Validation Results at Epoch 42:
#   Val Loss: 0.2440
#   Val Accuracy: 0.8690
#   Val Precision: 0.8978
#   Val Recall: 0.8690
#   Val F1 Score: 0.8713
# Adversarial Epoch 43/200:
#   Context Loss: 0.1384
#   DQN Loss: 0.2377
#   Context Updated Samples: 1627
#   Average Reward: 0.9015
#   Action Distribution (skip/apply): [2654 1627]
# Validation Results at Epoch 43:
#   Val Loss: 0.2200
#   Val Accuracy: 0.8802
#   Val Precision: 0.9025
#   Val Recall: 0.8802
#   Val F1 Score: 0.8823
# Adversarial Epoch 44/200:
#   Context Loss: 0.1306
#   DQN Loss: 0.2304
#   Context Updated Samples: 1751
#   Average Reward: 0.8674
#   Action Distribution (skip/apply): [2530 1751]
# Validation Results at Epoch 44:
#   Val Loss: 0.2311
#   Val Accuracy: 0.8781
#   Val Precision: 0.9004
#   Val Recall: 0.8781
#   Val F1 Score: 0.8802
# Adversarial Epoch 45/200:
#   Context Loss: 0.1361
#   DQN Loss: 0.2488
#   Context Updated Samples: 1675
#   Average Reward: 0.8819
#   Action Distribution (skip/apply): [2606 1675]
# Validation Results at Epoch 45:
#   Val Loss: 0.2062
#   Val Accuracy: 0.8865
#   Val Precision: 0.9019
#   Val Recall: 0.8865
#   Val F1 Score: 0.8884
# ✓ Updated best adversarial model states (Accuracy: 0.8865)
# Adversarial Epoch 46/200:
#   Context Loss: 0.1390
#   DQN Loss: 0.2341
#   Context Updated Samples: 1756
#   Average Reward: 0.8709
#   Action Distribution (skip/apply): [2525 1756]
# Validation Results at Epoch 46:
#   Val Loss: 0.2175
#   Val Accuracy: 0.8802
#   Val Precision: 0.8942
#   Val Recall: 0.8802
#   Val F1 Score: 0.8820
# Adversarial Epoch 47/200:
#   Context Loss: 0.1378
#   DQN Loss: 0.2273
#   Context Updated Samples: 1829
#   Average Reward: 0.8345
#   Action Distribution (skip/apply): [2452 1829]
# Validation Results at Epoch 47:
#   Val Loss: 0.2005
#   Val Accuracy: 0.8872
#   Val Precision: 0.9010
#   Val Recall: 0.8872
#   Val F1 Score: 0.8890
# ✓ Updated best adversarial model states (Accuracy: 0.8872)
# Adversarial Epoch 48/200:
#   Context Loss: 0.1356
#   DQN Loss: 0.2406
#   Context Updated Samples: 1868
#   Average Reward: 0.8235
#   Action Distribution (skip/apply): [2413 1868]
# Validation Results at Epoch 48:
#   Val Loss: 0.2110
#   Val Accuracy: 0.8753
#   Val Precision: 0.8992
#   Val Recall: 0.8753
#   Val F1 Score: 0.8775
# Adversarial Epoch 49/200:
#   Context Loss: 0.1390
#   DQN Loss: 0.2344
#   Context Updated Samples: 1895
#   Average Reward: 0.8103
#   Action Distribution (skip/apply): [2386 1895]
# Validation Results at Epoch 49:
#   Val Loss: 0.2132
#   Val Accuracy: 0.8774
#   Val Precision: 0.8978
#   Val Recall: 0.8774
#   Val F1 Score: 0.8796
# Adversarial Epoch 50/200:
#   Context Loss: 0.1358
#   DQN Loss: 0.2213
#   Context Updated Samples: 1777
#   Average Reward: 0.8391
#   Action Distribution (skip/apply): [2504 1777]
# Validation Results at Epoch 50:
#   Val Loss: 0.2107
#   Val Accuracy: 0.8900
#   Val Precision: 0.9030
#   Val Recall: 0.8900
#   Val F1 Score: 0.8918
# ✓ Updated best adversarial model states (Accuracy: 0.8900)
# Adversarial Epoch 51/200:
#   Context Loss: 0.1465
#   DQN Loss: 0.2248
#   Context Updated Samples: 1715
#   Average Reward: 0.8783
#   Action Distribution (skip/apply): [2566 1715]
# Validation Results at Epoch 51:
#   Val Loss: 0.2134
#   Val Accuracy: 0.8795
#   Val Precision: 0.8955
#   Val Recall: 0.8795
#   Val F1 Score: 0.8815
# Adversarial Epoch 52/200:
#   Context Loss: 0.1291
#   DQN Loss: 0.2344
#   Context Updated Samples: 1717
#   Average Reward: 0.8763
#   Action Distribution (skip/apply): [2564 1717]
# Validation Results at Epoch 52:
#   Val Loss: 0.2106
#   Val Accuracy: 0.8816
#   Val Precision: 0.9003
#   Val Recall: 0.8816
#   Val F1 Score: 0.8837
# Adversarial Epoch 53/200:
#   Context Loss: 0.1382
#   DQN Loss: 0.2326
#   Context Updated Samples: 1839
#   Average Reward: 0.8431
#   Action Distribution (skip/apply): [2442 1839]
# Validation Results at Epoch 53:
#   Val Loss: 0.2043
#   Val Accuracy: 0.8935
#   Val Precision: 0.9037
#   Val Recall: 0.8935
#   Val F1 Score: 0.8951
# ✓ Updated best adversarial model states (Accuracy: 0.8935)
# Adversarial Epoch 54/200:
#   Context Loss: 0.1389
#   DQN Loss: 0.2223
#   Context Updated Samples: 1912
#   Average Reward: 0.8211
#   Action Distribution (skip/apply): [2369 1912]
# Validation Results at Epoch 54:
#   Val Loss: 0.2010
#   Val Accuracy: 0.8872
#   Val Precision: 0.9072
#   Val Recall: 0.8872
#   Val F1 Score: 0.8892
# Adversarial Epoch 55/200:
#   Context Loss: 0.1319
#   DQN Loss: 0.2114
#   Context Updated Samples: 1362
#   Average Reward: 0.9974
#   Action Distribution (skip/apply): [2919 1362]
# Validation Results at Epoch 55:
#   Val Loss: 0.2197
#   Val Accuracy: 0.8865
#   Val Precision: 0.9058
#   Val Recall: 0.8865
#   Val F1 Score: 0.8885
# Adversarial Epoch 56/200:
#   Context Loss: 0.1293
#   DQN Loss: 0.2343
#   Context Updated Samples: 1564
#   Average Reward: 0.9310
#   Action Distribution (skip/apply): [2717 1564]
# Validation Results at Epoch 56:
#   Val Loss: 0.1986
#   Val Accuracy: 0.8963
#   Val Precision: 0.9051
#   Val Recall: 0.8963
#   Val F1 Score: 0.8978
# ✓ Updated best adversarial model states (Accuracy: 0.8963)
# Adversarial Epoch 57/200:
#   Context Loss: 0.1297
#   DQN Loss: 0.2164
#   Context Updated Samples: 1552
#   Average Reward: 0.9284
#   Action Distribution (skip/apply): [2729 1552]
# Validation Results at Epoch 57:
#   Val Loss: 0.2249
#   Val Accuracy: 0.8886
#   Val Precision: 0.9004
#   Val Recall: 0.8886
#   Val F1 Score: 0.8904
# Adversarial Epoch 58/200:
#   Context Loss: 0.1361
#   DQN Loss: 0.2131
#   Context Updated Samples: 1435
#   Average Reward: 0.9692
#   Action Distribution (skip/apply): [2846 1435]
# Validation Results at Epoch 58:
#   Val Loss: 0.2246
#   Val Accuracy: 0.8774
#   Val Precision: 0.9007
#   Val Recall: 0.8774
#   Val F1 Score: 0.8796
# Adversarial Epoch 59/200:
#   Context Loss: 0.1355
#   DQN Loss: 0.2196
#   Context Updated Samples: 1632
#   Average Reward: 0.9004
#   Action Distribution (skip/apply): [2649 1632]
# Validation Results at Epoch 59:
#   Val Loss: 0.2187
#   Val Accuracy: 0.8900
#   Val Precision: 0.9004
#   Val Recall: 0.8900
#   Val F1 Score: 0.8917
# Adversarial Epoch 60/200:
#   Context Loss: 0.1290
#   DQN Loss: 0.2165
#   Context Updated Samples: 1440
#   Average Reward: 0.9729
#   Action Distribution (skip/apply): [2841 1440]
# Validation Results at Epoch 60:
#   Val Loss: 0.2372
#   Val Accuracy: 0.8851
#   Val Precision: 0.9040
#   Val Recall: 0.8851
#   Val F1 Score: 0.8871
# Adversarial Epoch 61/200:
#   Context Loss: 0.1267
#   DQN Loss: 0.2321
#   Context Updated Samples: 1447
#   Average Reward: 0.9743
#   Action Distribution (skip/apply): [2834 1447]
# Validation Results at Epoch 61:
#   Val Loss: 0.2238
#   Val Accuracy: 0.8753
#   Val Precision: 0.8967
#   Val Recall: 0.8753
#   Val F1 Score: 0.8776
# Adversarial Epoch 62/200:
#   Context Loss: 0.1390
#   DQN Loss: 0.2080
#   Context Updated Samples: 1519
#   Average Reward: 0.9188
#   Action Distribution (skip/apply): [2762 1519]
# Validation Results at Epoch 62:
#   Val Loss: 0.2150
#   Val Accuracy: 0.8942
#   Val Precision: 0.9071
#   Val Recall: 0.8942
#   Val F1 Score: 0.8959
# Adversarial Epoch 63/200:
#   Context Loss: 0.1207
#   DQN Loss: 0.2265
#   Context Updated Samples: 1721
#   Average Reward: 0.8666
#   Action Distribution (skip/apply): [2560 1721]
# Validation Results at Epoch 63:
#   Val Loss: 0.2219
#   Val Accuracy: 0.8886
#   Val Precision: 0.8990
#   Val Recall: 0.8886
#   Val F1 Score: 0.8903
# Adversarial Epoch 64/200:
#   Context Loss: 0.1410
#   DQN Loss: 0.2145
#   Context Updated Samples: 1594
#   Average Reward: 0.9348
#   Action Distribution (skip/apply): [2687 1594]
# Validation Results at Epoch 64:
#   Val Loss: 0.2248
#   Val Accuracy: 0.8837
#   Val Precision: 0.8977
#   Val Recall: 0.8837
#   Val F1 Score: 0.8856
# Adversarial Epoch 65/200:
#   Context Loss: 0.1284
#   DQN Loss: 0.2200
#   Context Updated Samples: 1528
#   Average Reward: 0.9411
#   Action Distribution (skip/apply): [2753 1528]
# Validation Results at Epoch 65:
#   Val Loss: 0.2347
#   Val Accuracy: 0.8802
#   Val Precision: 0.8978
#   Val Recall: 0.8802
#   Val F1 Score: 0.8822
# Adversarial Epoch 66/200:
#   Context Loss: 0.1425
#   DQN Loss: 0.2183
#   Context Updated Samples: 1623
#   Average Reward: 0.9188
#   Action Distribution (skip/apply): [2658 1623]
# Validation Results at Epoch 66:
#   Val Loss: 0.2204
#   Val Accuracy: 0.8893
#   Val Precision: 0.9043
#   Val Recall: 0.8893
#   Val F1 Score: 0.8912
# Adversarial Epoch 67/200:
#   Context Loss: 0.1372
#   DQN Loss: 0.2055
#   Context Updated Samples: 1444
#   Average Reward: 0.9587
#   Action Distribution (skip/apply): [2837 1444]
# Validation Results at Epoch 67:
#   Val Loss: 0.2423
#   Val Accuracy: 0.8865
#   Val Precision: 0.9039
#   Val Recall: 0.8865
#   Val F1 Score: 0.8885
# Adversarial Epoch 68/200:
#   Context Loss: 0.1357
#   DQN Loss: 0.2086
#   Context Updated Samples: 1682
#   Average Reward: 0.8914
#   Action Distribution (skip/apply): [2599 1682]
# Validation Results at Epoch 68:
#   Val Loss: 0.2045
#   Val Accuracy: 0.8963
#   Val Precision: 0.9101
#   Val Recall: 0.8963
#   Val F1 Score: 0.8980
# Adversarial Epoch 69/200:
#   Context Loss: 0.1237
#   DQN Loss: 0.2069
#   Context Updated Samples: 1561
#   Average Reward: 0.9318
#   Action Distribution (skip/apply): [2720 1561]
# Validation Results at Epoch 69:
#   Val Loss: 0.2161
#   Val Accuracy: 0.8970
#   Val Precision: 0.9111
#   Val Recall: 0.8970
#   Val F1 Score: 0.8987
# ✓ Updated best adversarial model states (Accuracy: 0.8970)
# Adversarial Epoch 70/200:
#   Context Loss: 0.1325
#   DQN Loss: 0.2026
#   Context Updated Samples: 1513
#   Average Reward: 0.9404
#   Action Distribution (skip/apply): [2768 1513]
# Validation Results at Epoch 70:
#   Val Loss: 0.2051
#   Val Accuracy: 0.8907
#   Val Precision: 0.9025
#   Val Recall: 0.8907
#   Val F1 Score: 0.8925
# Adversarial Epoch 71/200:
#   Context Loss: 0.1226
#   DQN Loss: 0.2205
#   Context Updated Samples: 1305
#   Average Reward: 1.0037
#   Action Distribution (skip/apply): [2976 1305]
# Validation Results at Epoch 71:
#   Val Loss: 0.2322
#   Val Accuracy: 0.8893
#   Val Precision: 0.9034
#   Val Recall: 0.8893
#   Val F1 Score: 0.8912
# Adversarial Epoch 72/200:
#   Context Loss: 0.1274
#   DQN Loss: 0.2093
#   Context Updated Samples: 1330
#   Average Reward: 1.0075
#   Action Distribution (skip/apply): [2951 1330]
# Validation Results at Epoch 72:
#   Val Loss: 0.2258
#   Val Accuracy: 0.8830
#   Val Precision: 0.8968
#   Val Recall: 0.8830
#   Val F1 Score: 0.8849
# Adversarial Epoch 73/200:
#   Context Loss: 0.1383
#   DQN Loss: 0.2021
#   Context Updated Samples: 1558
#   Average Reward: 0.9331
#   Action Distribution (skip/apply): [2723 1558]
# Validation Results at Epoch 73:
#   Val Loss: 0.2185
#   Val Accuracy: 0.8865
#   Val Precision: 0.9022
#   Val Recall: 0.8865
#   Val F1 Score: 0.8884
# Adversarial Epoch 74/200:
#   Context Loss: 0.1372
#   DQN Loss: 0.2057
#   Context Updated Samples: 1430
#   Average Reward: 0.9694
#   Action Distribution (skip/apply): [2851 1430]
# Validation Results at Epoch 74:
#   Val Loss: 0.2094
#   Val Accuracy: 0.8872
#   Val Precision: 0.9022
#   Val Recall: 0.8872
#   Val F1 Score: 0.8891
# Adversarial Epoch 75/200:
#   Context Loss: 0.1198
#   DQN Loss: 0.2131
#   Context Updated Samples: 1569
#   Average Reward: 0.9310
#   Action Distribution (skip/apply): [2712 1569]
# Validation Results at Epoch 75:
#   Val Loss: 0.1947
#   Val Accuracy: 0.8823
#   Val Precision: 0.8967
#   Val Recall: 0.8823
#   Val F1 Score: 0.8843
# Adversarial Epoch 76/200:
#   Context Loss: 0.1291
#   DQN Loss: 0.2075
#   Context Updated Samples: 1429
#   Average Reward: 0.9766
#   Action Distribution (skip/apply): [2852 1429]
# Validation Results at Epoch 76:
#   Val Loss: 0.2139
#   Val Accuracy: 0.8886
#   Val Precision: 0.9023
#   Val Recall: 0.8886
#   Val F1 Score: 0.8904
# Adversarial Epoch 77/200:
#   Context Loss: 0.1328
#   DQN Loss: 0.2032
#   Context Updated Samples: 1415
#   Average Reward: 0.9757
#   Action Distribution (skip/apply): [2866 1415]
# Validation Results at Epoch 77:
#   Val Loss: 0.2121
#   Val Accuracy: 0.8844
#   Val Precision: 0.8986
#   Val Recall: 0.8844
#   Val F1 Score: 0.8863
# Adversarial Epoch 78/200:
#   Context Loss: 0.1293
#   DQN Loss: 0.2052
#   Context Updated Samples: 1594
#   Average Reward: 0.9103
#   Action Distribution (skip/apply): [2687 1594]
# Validation Results at Epoch 78:
#   Val Loss: 0.2212
#   Val Accuracy: 0.8956
#   Val Precision: 0.9096
#   Val Recall: 0.8956
#   Val F1 Score: 0.8974
# Adversarial Epoch 79/200:
#   Context Loss: 0.1341
#   DQN Loss: 0.2092
#   Context Updated Samples: 1383
#   Average Reward: 0.9887
#   Action Distribution (skip/apply): [2898 1383]
# Validation Results at Epoch 79:
#   Val Loss: 0.2120
#   Val Accuracy: 0.8942
#   Val Precision: 0.9069
#   Val Recall: 0.8942
#   Val F1 Score: 0.8959
# Adversarial Epoch 80/200:
#   Context Loss: 0.1305
#   DQN Loss: 0.1974
#   Context Updated Samples: 1296
#   Average Reward: 1.0227
#   Action Distribution (skip/apply): [2985 1296]
# Validation Results at Epoch 80:
#   Val Loss: 0.2132
#   Val Accuracy: 0.8935
#   Val Precision: 0.9060
#   Val Recall: 0.8935
#   Val F1 Score: 0.8952
# Adversarial Epoch 81/200:
#   Context Loss: 0.1397
#   DQN Loss: 0.2010
#   Context Updated Samples: 1429
#   Average Reward: 0.9752
#   Action Distribution (skip/apply): [2852 1429]
# Validation Results at Epoch 81:
#   Val Loss: 0.2116
#   Val Accuracy: 0.8949
#   Val Precision: 0.9078
#   Val Recall: 0.8949
#   Val F1 Score: 0.8966
# Adversarial Epoch 82/200:
#   Context Loss: 0.1308
#   DQN Loss: 0.1993
#   Context Updated Samples: 1238
#   Average Reward: 1.0360
#   Action Distribution (skip/apply): [3043 1238]
# Validation Results at Epoch 82:
#   Val Loss: 0.2358
#   Val Accuracy: 0.8914
#   Val Precision: 0.9020
#   Val Recall: 0.8914
#   Val F1 Score: 0.8931
# Adversarial Epoch 83/200:
#   Context Loss: 0.1194
#   DQN Loss: 0.2062
#   Context Updated Samples: 1547
#   Average Reward: 0.9277
#   Action Distribution (skip/apply): [2734 1547]
# Validation Results at Epoch 83:
#   Val Loss: 0.2311
#   Val Accuracy: 0.8900
#   Val Precision: 0.9039
#   Val Recall: 0.8900
#   Val F1 Score: 0.8918
# Adversarial Epoch 84/200:
#   Context Loss: 0.1365
#   DQN Loss: 0.1886
#   Context Updated Samples: 1285
#   Average Reward: 1.0203
#   Action Distribution (skip/apply): [2996 1285]
# Validation Results at Epoch 84:
#   Val Loss: 0.1723
#   Val Accuracy: 0.8928
#   Val Precision: 0.9045
#   Val Recall: 0.8928
#   Val F1 Score: 0.8944
# Adversarial Epoch 85/200:
#   Context Loss: 0.1241
#   DQN Loss: 0.1959
#   Context Updated Samples: 1618
#   Average Reward: 0.9062
#   Action Distribution (skip/apply): [2663 1618]
# Validation Results at Epoch 85:
#   Val Loss: 0.2180
#   Val Accuracy: 0.8858
#   Val Precision: 0.8987
#   Val Recall: 0.8858
#   Val F1 Score: 0.8876
# Adversarial Epoch 86/200:
#   Context Loss: 0.1296
#   DQN Loss: 0.1942
#   Context Updated Samples: 1545
#   Average Reward: 0.9361
#   Action Distribution (skip/apply): [2736 1545]
# Validation Results at Epoch 86:
#   Val Loss: 0.2187
#   Val Accuracy: 0.8970
#   Val Precision: 0.9101
#   Val Recall: 0.8970
#   Val F1 Score: 0.8987
# Adversarial Epoch 87/200:
#   Context Loss: 0.1199
#   DQN Loss: 0.1905
#   Context Updated Samples: 1281
#   Average Reward: 1.0165
#   Action Distribution (skip/apply): [3000 1281]
# Validation Results at Epoch 87:
#   Val Loss: 0.2159
#   Val Accuracy: 0.8928
#   Val Precision: 0.9049
#   Val Recall: 0.8928
#   Val F1 Score: 0.8945
# Adversarial Epoch 88/200:
#   Context Loss: 0.1373
#   DQN Loss: 0.1889
#   Context Updated Samples: 1520
#   Average Reward: 0.9501
#   Action Distribution (skip/apply): [2761 1520]
# Validation Results at Epoch 88:
#   Val Loss: 0.2060
#   Val Accuracy: 0.8921
#   Val Precision: 0.9042
#   Val Recall: 0.8921
#   Val F1 Score: 0.8938
# Adversarial Epoch 89/200:
#   Context Loss: 0.1318
#   DQN Loss: 0.1988
#   Context Updated Samples: 1482
#   Average Reward: 0.9693
#   Action Distribution (skip/apply): [2799 1482]
# Validation Results at Epoch 89:
#   Val Loss: 0.2205
#   Val Accuracy: 0.8865
#   Val Precision: 0.9032
#   Val Recall: 0.8865
#   Val F1 Score: 0.8885
# Early stopping triggered after 89 epochs.
# Loaded best context model
# Loaded best DQN model
# Saved best adversarial Context model
# Saved best adversarial DQN model with replay buffer
#
# ============================================================
# Final Evaluation - Adversarial System
# ============================================================
# Adversarial System Test Results:
#   Test Loss: 0.1501
#   Accuracy: 0.8929
#   Precision: 0.9031
#   Recall: 0.8929
#   F1 Score: 0.8941
#
# ============================================================
# Performance Improvement Summary
# ============================================================
# Accuracy Improvement: -1.47%
# F1 Score Improvement: -1.44%
# Precision Improvement: -1.11%
# Recall Improvement: -1.47%
#
# Training completed successfully!

# %% [markdown]
# ## New Method

# %% [markdown]
# ## Sperate testing

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, WeightedRandomSampler, SubsetRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import random
from collections import deque
import matplotlib.pyplot as plt
import os
import glob
import hashlib
import uuid

# Check for GPU (CUDA) availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- Class Definitions (Assuming these are defined in your previous code blocks) ---
# Make sure CNN1D, ContextAwareNetwork, DQNSelector, ReplayBuffer, DQNSelectorAgent are defined here
# If they are in another file, import them. For this solution, I will assume they are available.
# If not, please paste the class definitions from the previous turn.

# For the sake of this complete runnable script, I will re-define the necessary classes briefly if they are missing,
# but usually, you should have them defined. I will focus on the `test_system` and `main` logic.

def compute_reward(action, cnn_pred, weighted_pred, label):
    # Ensure inputs are integers for comparison
    action = int(action)
    cnn_pred = int(cnn_pred)
    weighted_pred = int(weighted_pred)
    label = int(label)
    
    if action == 1:
        if weighted_pred != label and cnn_pred != label:
            reward = 3.0
        elif weighted_pred == label and cnn_pred != label:
            reward = 2.0
        elif weighted_pred != label and cnn_pred == label:
            reward = -2.0
        else:
            reward = 0.0
    else:
        reward = 1.5 if cnn_pred == label else -1.0
    return reward

def load_data(base_path='Dataset', train_perturb_level=0):
    X_all, y_all = [], []
    dataset_indices = []
    if not os.path.exists(base_path):
        print(f"Error: Data directory '{base_path}' not found.")
        return None, None, None, None, None, None, None, None, None, None, None
    try:
        df = pd.read_csv(f'{base_path}/IUST_MSCN_original.csv')
        X = df.iloc[:, :-1].values
        y = df.iloc[:, -1].values
        X_all.append(X)
        y_all.append(y)
        dataset_indices.append(list(range(len(y))))
        print(f"Loaded data for perturbation level {train_perturb_level} with {X.shape[0]} samples.")
    except FileNotFoundError:
        print(f"Error: File for perturbation level {train_perturb_level} not found.")
        return None, None, None, None, None, None, None, None, None, None, None
    if not X_all or not y_all:
        print("Error: No valid data loaded for training.")
        return None, None, None, None, None, None, None, None, None, None, None
    
    # Create full dataset before splitting
    X = np.vstack(X_all)
    y = np.hstack(y_all)
    
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y)
    
    # --- تغییر مهم ۱: حذف شرط سخت‌گیرانه ۶ کلاس ---
    num_classes = len(label_encoder.classes_)
    # if num_classes != 6:  <-- این خط را حذف یا کامنت کنید
    #     print(f"Error: Expected 6 classes, found {num_classes} classes.")
    #     return ...
    
    print(f"Detected {num_classes} classes for perturbation level {train_perturb_level}.")
    
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    class_counts = np.bincount(y)
    print(f"Input length: {X.shape[1]}")
  
    return num_classes, label_encoder, scaler, X.shape[1], class_counts


def test_system(cnn_model, dqn_agent, context_model, base_path, attack_type, perturb_level, 
                label_encoder, scaler, device, threshold, class_count, budget=300, 
                fine_tune_lr=0.0001, max_test_samples=100):
    
    # --- تغییر مهم ۲: محاسبه وزن‌ها بر اساس تعداد کلاس‌های واقعی ---
    # کلاس_count باید آرایه‌ای از تعداد نمونه‌های هر کلاس باشد
    # اگر class_count یک عدد است، باید آن را به آرایه تبدیل کنید یا از bincount استفاده کنید
    # فرض بر این است که class_count ورودی، آرایه bincount است.
    
    # اگر ورودی class_count عدد باشد (که غلط است)، باید اصلاح شود.
    # در کد اصلی شما احتمالاً class_count همان آرایه bincount است.
    # برای اطمینان:
    if isinstance(class_count, int):
        print("Warning: class_count is int, expected array. Calculating from scratch might be needed or check caller.")
        # در حالت عادی caller باید آرایه بفرستد.
    
    class_weights = torch.FloatTensor(class_count).to(device)
    
    cnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
    cumulative_accuracy_df = pd.DataFrame(columns=['Sample Index', f'Perturbation {perturb_level}'])
    results = []
    softmax = nn.Softmax(dim=1)
    
    # Ensure models are in eval mode
    cnn_model.eval()
    context_model.eval()
    
    # Load test data
    test_file = f'{base_path}/{attack_type}/{attack_type}_eps_{perturb_level}.csv'
    try:
        df_test = pd.read_csv(test_file)
        X_test = df_test.iloc[:, :-1].values
        y_test = df_test.iloc[:, -1].values
        max_samples = min(len(df_test), max_test_samples)
        X_test = X_test[:max_samples]
        y_test = y_test[:max_samples]
        cumulative_accuracy_df = pd.DataFrame({'Sample Index': range(1, max_samples + 1)})
    except FileNotFoundError:
        print(f"Error: File {test_file} not found.")
        return [], cumulative_accuracy_df
        
    try:
        y_test = label_encoder.transform(y_test)
    except ValueError:
        print(f"Error: Unknown labels in {test_file}. Skipping.")
        return [], cumulative_accuracy_df
        
    X_test = scaler.transform(X_test)
    X_test = torch.FloatTensor(X_test).unsqueeze(1).to(device)
    y_test = torch.LongTensor(y_test).to(device)
    
    test_dataset = TensorDataset(X_test, y_test)
    
    # Optimizer for context_model
    context_optimizer = optim.Adam(context_model.parameters(), lr=fine_tune_lr, weight_decay=1e-4)
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    
    correct = 0
    total = 0
    y_pred = []
    y_true = []
    sample_accuracies = []
    updates_used = 0
    dqn_updates_used = 0
    dqn_loss_count = 0
    running_dqn_loss = 0.0
    sample_idx = 0
    rewards = []
    actions = []
    target_update_counter = 0
    TARGET_UPDATE_FREQ = 10
    
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        sample_idx += 1
        
        # Compute CNN outputs and state
        with torch.no_grad():
            cnn_outputs = cnn_model(inputs)
            # CNN outputs shape should be (batch, num_classes)
            probs = softmax(cnn_outputs)
            _, cnn_pred = torch.max(probs, 1)
            max_prob, _ = torch.max(probs, dim=1, keepdim=True)
            uncertainty = 1 - max_prob
            features = inputs.squeeze(1)
            state = torch.cat([features, uncertainty], dim=1)
            
        # Select action
        action_tensor = dqn_agent.select_action(state)
        action = action_tensor.item() if isinstance(action_tensor, torch.Tensor) else int(action_tensor)
        actions.append(action)
        
        # Compute weighted outputs BEFORE any context update
        with torch.no_grad():
            encoded_inputs_before = context_model(inputs)
            cnn_outputs_weighted_before = cnn_model(encoded_inputs_before)
            weighted_probs_before = softmax(cnn_outputs_weighted_before)
            _, weighted_pred_before = torch.max(cnn_outputs_weighted_before, 1)
            
        # Update ContextAwareNetwork only when action=1
        if action == 1:
            _, weighted_pred = torch.max(cnn_outputs_weighted_before, 1)
            max_weighted_prob, _ = torch.max(weighted_probs_before, dim=1, keepdim=True)
            max_prob_diff = torch.max(torch.abs(max_weighted_prob - max_prob)).item()
            
            if weighted_pred != cnn_pred and max_prob_diff >= threshold and updates_used < budget:
                updates_used += 1
                context_optimizer.zero_grad()
                encoded_inputs = context_model(inputs)
                outputs = cnn_model(encoded_inputs)
                context_loss = cnn_criterion(outputs, labels)
                orig_cnn_loss = cnn_criterion(cnn_outputs.detach(), labels)
                epsilon = 1e-8
                loss_ratio = context_loss / (orig_cnn_loss + epsilon)
                total_context_loss = 0.8 * context_loss + 0.2 / (1 + loss_ratio)
                total_context_loss.backward()
                context_optimizer.step()
                
                # Compute reward for action=1
                reward = compute_reward(action, cnn_pred.item(), weighted_pred.item(), labels.item())
                rewards.append(reward)
                
                # Compute next state with updated context
                with torch.no_grad():
                    encoded_inputs_new = context_model(inputs)
                    cnn_outputs_new = cnn_model(encoded_inputs_new)
                    probs_new = softmax(cnn_outputs_new)
                    max_prob_new, _ = torch.max(probs_new, dim=1, keepdim=True)
                    uncertainty_new = 1 - max_prob_new
                    next_state = torch.cat([features, uncertainty_new], dim=1)
                    
                # Push action=1 to replay buffer
                dqn_agent.replay_buffer.push(state, action, reward, next_state, 1.0)
                target_update_counter += 1
                
                # Hindsight Experience Replay
                if reward < 0:
                    reward_action0 = compute_reward(0, cnn_pred.item(), weighted_pred.item(), labels.item())
                    dqn_agent.replay_buffer.push(state, 0, reward_action0, state, 1.0)
                    target_update_counter += 1
                    
                # Optimize DQN
                dqn_loss = dqn_agent.optimize()
                if dqn_loss is not None:
                    running_dqn_loss += dqn_loss
                    dqn_loss_count += 1
                    dqn_updates_used += 1
                    
                # Update target network every N steps
                if target_update_counter >= TARGET_UPDATE_FREQ:
                    dqn_agent.update_target_network()
                    target_update_counter = 0
                    
                # Final output with updated context
                with torch.no_grad():
                    encoded_inputs_final = context_model(inputs)
                    outputs = cnn_model(encoded_inputs_final)
            else:
                # No context update, use current context
                with torch.no_grad():
                    encoded_inputs_final = context_model(inputs)
                    outputs = cnn_model(encoded_inputs_final)
        else:
            # Action = 0: no context update
            with torch.no_grad():
                encoded_inputs_final = context_model(inputs)
                outputs = cnn_model(encoded_inputs_final)
                
        with torch.no_grad():
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            current_accuracy = correct / total
            sample_accuracies.append(current_accuracy)
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(labels.cpu().numpy())
            cumulative_accuracy_df.loc[cumulative_accuracy_df['Sample Index'] == sample_idx, f'Perturbation {perturb_level}'] = current_accuracy
            
    test_accuracy = correct / total
    precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    
    results.append({
        'Perturbation Level': perturb_level,
        'Test Accuracy': test_accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1,
        'Context Updates Used': updates_used,
        'DQN Updates Used': dqn_updates_used,
        'DQN Loss': running_dqn_loss / max(dqn_loss_count, 1)
    })
    
    print(f"\nResults for Perturbation Level {perturb_level}:")
    print(f"  Test Accuracy: {test_accuracy:.4f}")
    print(f"  Precision (weighted): {precision:.4f}")
    print(f"  Recall (weighted): {recall:.4f}")
    print(f"  F1 Score (weighted): {f1:.4f}")
    print(f"  Context Updates Used: {updates_used}/{budget}")
    print(f"  DQN Updates Used: {dqn_updates_used}/{budget}")
    print(f"  Average DQN Loss: {running_dqn_loss / max(dqn_loss_count, 1):.4f}")
    print(f"  Average Reward: {np.mean(rewards) if rewards else 0.0:.4f}")
    
    actions_np = np.array(actions)
    print(f"  Action Distribution: {np.bincount(actions_np, minlength=2) if len(actions_np) > 0 else [0, 0]}")
    
    return results, cumulative_accuracy_df

def plot_accuracies(combined_accuracy_df, test_perturb_levels):
    plt.figure(figsize=(12, 8))
    for perturb in test_perturb_levels:
        if f'Perturbation {perturb}' in combined_accuracy_df.columns:
            plt.plot(combined_accuracy_df['Sample Index'], combined_accuracy_df[f'Perturbation {perturb}'], 
                     label=f'Perturbation {perturb}', marker='o', markersize=4, linewidth=1.5)
    plt.xlabel('Sample Index')
    plt.ylabel('Cumulative Accuracy')
    plt.title('Cumulative Accuracy per Sample Across Perturbation Levels')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    os.makedirs('Results', exist_ok=True)
    plt.savefig('Results/cumulative_accuracy_per_sample_all_levels.png', dpi=300)
    plt.show()
    print("Plot saved to 'Results/cumulative_accuracy_per_sample_all_levels.png'")
# Out:
# Using device: cuda

# %%
def main(attack_type, fine_tune_lr,test_perturb_levels, context_budget_test, threshold):
    
    base_path = 'Dataset'
    cnn_model_path = 'Models/initial_cnn_model.pth'
    context_model_path = 'Models/adversarial_best_context.pth'
    dqn_model_path = 'Models/adversarial_best_dqn.pth'
    max_test_samples = 5000
    
    print(f"Current working directory: {os.getcwd()}")
    print(f"Expected data directory: {os.path.abspath(base_path)}")
    print("Available files in data directory:")
    for file in glob.glob(f"{base_path}/*.csv"):
        print(file)
        
    all_results = []
    all_accuracy_dfs = []
    max_sample_index = 0
    accuracy_by_perturb = {}
    
    for perturb_level in test_perturb_levels:
        print(f"\n{'='*50}")
        print(f"Starting processing for perturbation level {perturb_level}")
        print(f"{'='*50}")
        
        try:
            num_classes, label_encoder, scaler, input_length, class_counts = load_data(
                base_path
            )
        except Exception as e:
            print(f"Error loading data metadata: {e}")
            continue
            
        if num_classes is None:
            print("Failed to load data metadata. Skipping.")
            continue

        try:
            # Load CNN model
            cnn_checkpoint = torch.load(cnn_model_path, map_location=device)
            cnn_input_length = cnn_checkpoint['input_length']
            cnn_num_classes = cnn_checkpoint['num_classes']
            
            if cnn_input_length != input_length or cnn_num_classes != num_classes:
                print(f"Error: Mismatch in CNN model parameters (input_length: {cnn_input_length} vs {input_length}, num_classes: {cnn_num_classes} vs {num_classes})")
                continue
                
            cnn_model = CNN1D(input_length=input_length, num_classes=num_classes).to(device)
            cnn_model.load_state_dict(cnn_checkpoint['model_state_dict'])
            cnn_model.eval() # Set to eval mode
            print(f"Successfully loaded CNN model from {cnn_model_path}")
            
            # Load ContextAwareNetwork model
            context_checkpoint = torch.load(context_model_path, map_location=device)
            context_input_length = context_checkpoint['input_length']
            context_num_classes = context_checkpoint['num_classes']
            
            if context_input_length != input_length or context_num_classes != num_classes:
                print(f"Error: Mismatch in Context model parameters (input_length: {context_input_length} vs {input_length}, num_classes: {context_num_classes} vs {num_classes})")
                continue
                
            context_model = ContextAwareNetwork(input_size=input_length, num_layers=4).to(device)
            context_model.load_state_dict(context_checkpoint['context_model_state_dict'])
            context_model.eval() # Set to eval mode
            print(f"Successfully loaded Context model from {context_model_path}")
            
            # Load DQNSelector model
            dqn_checkpoint = torch.load(dqn_model_path, map_location=device)
            dqn_input_length = dqn_checkpoint['input_length']
            dqn_num_classes = dqn_checkpoint['num_classes']
            
            if dqn_input_length != input_length or dqn_num_classes != num_classes:
                print(f"Error: Mismatch in DQN model parameters (input_length: {dqn_input_length} vs {input_length}, num_classes: {dqn_num_classes} vs {num_classes})")
                continue
                
            dqn_agent = DQNSelectorAgent(
                input_size=input_length + 1,
                device=device,
                epsilon_decay=0.5,
                buffer_capacity=5000,
                batch_size=32
            )
            dqn_agent.policy_net.load_state_dict(dqn_checkpoint['dqn_policy_net_state_dict'])
            dqn_agent.target_net.load_state_dict(dqn_checkpoint['dqn_policy_net_state_dict'])
            dqn_agent.target_net.eval()
            
            # Load replay buffer if exists
            if 'replay_buffer' in dqn_checkpoint:
                dqn_agent.replay_buffer = ReplayBuffer(1000)
                for experience in dqn_checkpoint['replay_buffer']:
                    state, action, reward, next_state, done = experience
                    
                    if not isinstance(state, torch.Tensor):
                        state = torch.FloatTensor(state).to(device)
                    if not isinstance(next_state, torch.Tensor):
                        next_state = torch.FloatTensor(next_state).to(device)
                        
                    if state.dim() == 0:
                        state = state.unsqueeze(0)
                    if next_state.dim() == 0:
                        next_state = next_state.unsqueeze(0)
                        
                    dqn_agent.replay_buffer.push(state, action, reward, next_state, done)
                print(f"Loaded replay buffer with {len(dqn_agent.replay_buffer)} experiences")
            else:
                print("Warning: No replay buffer found in checkpoint. Starting with empty buffer.")
                dqn_agent.replay_buffer = ReplayBuffer(200)
                
            print(f"Successfully loaded DQN model from {dqn_model_path}")
            
        except FileNotFoundError as e:
            print(f"Error: Model file not found: {e}")
            continue
        except KeyError as e:
            print(f"Error: Missing key {e} in checkpoint.")
            continue
        except Exception as e:
            print(f"Error loading model: {e}")
            import traceback
            traceback.print_exc()
            continue
            
        print(f"Test - Using DQN threshold: {threshold:.4f}")
        
        results, cumulative_accuracy_df = test_system(
            cnn_model, dqn_agent, context_model, base_path, attack_type, perturb_level,
            label_encoder, scaler, device, threshold, class_counts, budget=context_budget_test, 
            fine_tune_lr=fine_tune_lr, max_test_samples=max_test_samples
        )
        
        all_results.extend(results)
        if not cumulative_accuracy_df.empty:
            all_accuracy_dfs.append(cumulative_accuracy_df)
            max_sample_index = max(max_sample_index, cumulative_accuracy_df['Sample Index'].max())
            accuracy_by_perturb[perturb_level] = cumulative_accuracy_df[f'Perturbation {perturb_level}'].values.tolist()
            
    if accuracy_by_perturb:
        max_samples = max(len(acc) for acc in accuracy_by_perturb.values())
        combined_accuracy_df = pd.DataFrame({'Size': list(accuracy_by_perturb.keys())})
        for i in range(max_samples):
            column_data = []
            for perturb_level in accuracy_by_perturb:
                acc_list = accuracy_by_perturb[perturb_level]
                value = acc_list[i] if i < len(acc_list) else np.nan
                column_data.append(value)
            combined_accuracy_df[f'{i+1}'] = column_data
        
        os.makedirs('Results', exist_ok=True)
        combined_accuracy_df.to_csv('Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv', index=False)
        print("Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'")
        
    if all_results:
        results_df = pd.DataFrame(all_results)
        os.makedirs('Results', exist_ok=True)
        results_df.to_csv('Results/AMCAL_20_cumulative_accuracy.csv', index=False)
        print("\nCombined Results Table:")
        print(results_df.to_string(index=False))
        print("\nCombined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.")
        
    if accuracy_by_perturb:
        plt.figure(figsize=(12, 8))
        for perturb_level in test_perturb_levels:
            if perturb_level in accuracy_by_perturb:
                plt.plot(range(1, len(accuracy_by_perturb[perturb_level]) + 1), 
                         accuracy_by_perturb[perturb_level], 
                         label=f'Perturbation {perturb_level}', marker='o', markersize=4, linewidth=1.5)
        plt.xlabel('Sample Index')
        plt.ylabel('Cumulative Accuracy')
        plt.title('Cumulative Accuracy per Sample Across Perturbation Levels')
        plt.legend()
        plt.grid(True, linestyle='--', alpha=0.7)
        os.makedirs('Results', exist_ok=True)
        plt.savefig('Results/AMCAL_20_cumulative_accuracy.png', dpi=300)
        plt.show()
        print("Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'")

# %% [markdown]
# # FGSM Adversarial Attack

# %%
import warnings
warnings.filterwarnings('ignore', category=pd.errors.PerformanceWarning)

if __name__ == "__main__":
    fine_tune_lr = 0.0005
    test_perturb_levels = [0.01, 0.05, 0.1, 0.2, 0.5]
    attack_type = "FGSM" # or "PGD" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 285
    threshold = 0.0005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST\Dataset
# Available files in data directory:
# Dataset\IUST_MSCN_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.01
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.01:
#   Test Accuracy: 0.8866
#   Precision (weighted): 0.8891
#   Recall (weighted): 0.8866
#   F1 Score (weighted): 0.8871
#   Context Updates Used: 70/285
#   DQN Updates Used: 70/285
#   Average DQN Loss: 0.2956
#   Average Reward: -0.5000
#   Action Distribution: [711 717]
#
# ==================================================
# Starting processing for perturbation level 0.05
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.05:
#   Test Accuracy: 0.8676
#   Precision (weighted): 0.8714
#   Recall (weighted): 0.8676
#   F1 Score (weighted): 0.8686
#   Context Updates Used: 62/285
#   DQN Updates Used: 62/285
#   Average DQN Loss: 0.3105
#   Average Reward: -0.3871
#   Action Distribution: [726 702]
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.8480
#   Precision (weighted): 0.8552
#   Recall (weighted): 0.8480
#   F1 Score (weighted): 0.8493
#   Context Updates Used: 101/285
#   DQN Updates Used: 101/285
#   Average DQN Loss: 0.3910
#   Average Reward: 0.1485
#   Action Distribution: [702 726]
#
# ==================================================
# Starting processing for perturbation level 0.2
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.2:
#   Test Accuracy: 0.8389
#   Precision (weighted): 0.8564
#   Recall (weighted): 0.8389
#   F1 Score (weighted): 0.8412
#   Context Updates Used: 150/285
#   DQN Updates Used: 150/285
#   Average DQN Loss: 0.5138
#   Average Reward: 0.8000
#   Action Distribution: [704 724]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.8032
#   Precision (weighted): 0.8303
#   Recall (weighted): 0.8032
#   F1 Score (weighted): 0.8061
#   Context Updates Used: 285/285
#   DQN Updates Used: 285/285
#   Average DQN Loss: 0.6557
#   Average Reward: 1.4596
#   Action Distribution: [728 700]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision   Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                0.01       0.886555   0.889075 0.886555  0.887101                    70                70  0.295598
#                0.05       0.867647   0.871355 0.867647  0.868579                    62                62  0.310513
#                0.10       0.848039   0.855195 0.848039  0.849350                   101               101  0.391034
#                0.20       0.838936   0.856362 0.838936  0.841164                   150               150  0.513845
#                0.50       0.803221   0.830296 0.803221  0.806054                   285               285  0.655743
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %% [markdown]
# ## PGD Adversarial Attack

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0005
    test_perturb_levels = [0.01, 0.05, 0.1, 0.2, 0.5]
    attack_type = "PGD" # or "FGSM" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 576
    threshold = 0.0005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST\Dataset
# Available files in data directory:
# Dataset\IUST_MSCN_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.01
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.01:
#   Test Accuracy: 0.8543
#   Precision (weighted): 0.8602
#   Recall (weighted): 0.8543
#   F1 Score (weighted): 0.8557
#   Context Updates Used: 88/576
#   DQN Updates Used: 88/576
#   Average DQN Loss: 0.3283
#   Average Reward: -0.9091
#   Action Distribution: [745 683]
#
# ==================================================
# Starting processing for perturbation level 0.05
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.05:
#   Test Accuracy: 0.8634
#   Precision (weighted): 0.8652
#   Recall (weighted): 0.8634
#   F1 Score (weighted): 0.8641
#   Context Updates Used: 111/576
#   DQN Updates Used: 111/576
#   Average DQN Loss: 0.4047
#   Average Reward: -0.3604
#   Action Distribution: [713 715]
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.8270
#   Precision (weighted): 0.8298
#   Recall (weighted): 0.8270
#   F1 Score (weighted): 0.8267
#   Context Updates Used: 144/576
#   DQN Updates Used: 144/576
#   Average DQN Loss: 0.4814
#   Average Reward: 0.4375
#   Action Distribution: [687 741]
#
# ==================================================
# Starting processing for perturbation level 0.2
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.2:
#   Test Accuracy: 0.8746
#   Precision (weighted): 0.8922
#   Recall (weighted): 0.8746
#   F1 Score (weighted): 0.8765
#   Context Updates Used: 217/576
#   DQN Updates Used: 217/576
#   Average DQN Loss: 0.5776
#   Average Reward: 1.3134
#   Action Distribution: [734 694]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.8824
#   Precision (weighted): 0.8854
#   Recall (weighted): 0.8824
#   F1 Score (weighted): 0.8829
#   Context Updates Used: 400/576
#   DQN Updates Used: 400/576
#   Average DQN Loss: 0.6486
#   Average Reward: 1.6550
#   Action Distribution: [732 696]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision   Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                0.01       0.854342   0.860226 0.854342  0.855657                    88                88  0.328344
#                0.05       0.863445   0.865219 0.863445  0.864083                   111               111  0.404691
#                0.10       0.827031   0.829769 0.827031  0.826664                   144               144  0.481433
#                0.20       0.874650   0.892158 0.874650  0.876532                   217               217  0.577596
#                0.50       0.882353   0.885353 0.882353  0.882910                   400               400  0.648643
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0005
    test_perturb_levels = [0.1, 0.5, 1.0, 2.0, 5.0]
    attack_type = "CW" # or "FGSM" or "CW" or "DeepFool" or "RANDOM"
    context_budget_test = 576
    threshold = 0.0005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST\Dataset
# Available files in data directory:
# Dataset\IUST_MSCN_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.8901
#   Precision (weighted): 0.8967
#   Recall (weighted): 0.8901
#   F1 Score (weighted): 0.8912
#   Context Updates Used: 59/576
#   DQN Updates Used: 59/576
#   Average DQN Loss: 0.3307
#   Average Reward: -1.1186
#   Action Distribution: [684 744]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.8326
#   Precision (weighted): 0.8460
#   Recall (weighted): 0.8326
#   F1 Score (weighted): 0.8346
#   Context Updates Used: 98/576
#   DQN Updates Used: 98/576
#   Average DQN Loss: 0.3695
#   Average Reward: -0.4898
#   Action Distribution: [704 724]
#
# ==================================================
# Starting processing for perturbation level 1.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 1.0:
#   Test Accuracy: 0.8361
#   Precision (weighted): 0.8359
#   Recall (weighted): 0.8361
#   F1 Score (weighted): 0.8359
#   Context Updates Used: 131/576
#   DQN Updates Used: 131/576
#   Average DQN Loss: 0.4396
#   Average Reward: -0.0076
#   Action Distribution: [728 700]
#
# ==================================================
# Starting processing for perturbation level 2.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 2.0:
#   Test Accuracy: 0.7920
#   Precision (weighted): 0.7905
#   Recall (weighted): 0.7920
#   F1 Score (weighted): 0.7904
#   Context Updates Used: 150/576
#   DQN Updates Used: 150/576
#   Average DQN Loss: 0.5029
#   Average Reward: -0.2267
#   Action Distribution: [715 713]
#
# ==================================================
# Starting processing for perturbation level 5.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 5.0:
#   Test Accuracy: 0.8186
#   Precision (weighted): 0.8324
#   Recall (weighted): 0.8186
#   F1 Score (weighted): 0.8218
#   Context Updates Used: 131/576
#   DQN Updates Used: 131/576
#   Average DQN Loss: 0.4480
#   Average Reward: 0.1832
#   Action Distribution: [701 727]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision   Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                 0.1       0.890056   0.896711 0.890056  0.891217                    59                59  0.330670
#                 0.5       0.832633   0.845986 0.832633  0.834603                    98                98  0.369531
#                 1.0       0.836134   0.835857 0.836134  0.835883                   131               131  0.439550
#                 2.0       0.792017   0.790535 0.792017  0.790442                   150               150  0.502900
#                 5.0       0.818627   0.832395 0.818627  0.821841                   131               131  0.448006
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'

# %%
if __name__ == "__main__":
    fine_tune_lr = 0.0005
    test_perturb_levels = [0.1, 0.5, 1.0, 2.0, 5.0]
    attack_type = "DeepFool" # or "FGSM" or "CW" or "DeepFool" 
    context_budget_test = 576
    threshold = 0.0005
    main(attack_type, fine_tune_lr, test_perturb_levels, context_budget_test,threshold)
# Out:
# Current working directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST
# Expected data directory: d:\Paper_Implementation\TNSM_Paper-Active\Active_Learning_Paper\IUST_MSCN_TEST\Dataset
# Available files in data directory:
# Dataset\IUST_MSCN_original.csv
#
# ==================================================
# Starting processing for perturbation level 0.1
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.1:
#   Test Accuracy: 0.8754
#   Precision (weighted): 0.8769
#   Recall (weighted): 0.8754
#   F1 Score (weighted): 0.8760
#   Context Updates Used: 67/576
#   DQN Updates Used: 67/576
#   Average DQN Loss: 0.2793
#   Average Reward: -0.6716
#   Action Distribution: [713 715]
#
# ==================================================
# Starting processing for perturbation level 0.5
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 0.5:
#   Test Accuracy: 0.8529
#   Precision (weighted): 0.8568
#   Recall (weighted): 0.8529
#   F1 Score (weighted): 0.8541
#   Context Updates Used: 96/576
#   DQN Updates Used: 96/576
#   Average DQN Loss: 0.3772
#   Average Reward: -0.7083
#   Action Distribution: [729 699]
#
# ==================================================
# Starting processing for perturbation level 1.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 1.0:
#   Test Accuracy: 0.8424
#   Precision (weighted): 0.8500
#   Recall (weighted): 0.8424
#   F1 Score (weighted): 0.8440
#   Context Updates Used: 170/576
#   DQN Updates Used: 170/576
#   Average DQN Loss: 0.4909
#   Average Reward: 0.3529
#   Action Distribution: [702 726]
#
# ==================================================
# Starting processing for perturbation level 2.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 2.0:
#   Test Accuracy: 0.7892
#   Precision (weighted): 0.7999
#   Recall (weighted): 0.7892
#   F1 Score (weighted): 0.7914
#   Context Updates Used: 194/576
#   DQN Updates Used: 194/576
#   Average DQN Loss: 0.5344
#   Average Reward: 0.6340
#   Action Distribution: [717 711]
#
# ==================================================
# Starting processing for perturbation level 5.0
# ==================================================
# Loaded data for perturbation level 0 with 7136 samples.
# Detected 5 classes for perturbation level 0.
# Input length: 36
# Successfully loaded CNN model from Models/initial_cnn_model.pth
# Selected num_heads=4 for input_size=36
# Successfully loaded Context model from Models/adversarial_best_context.pth
# Loaded replay buffer with 1000 experiences
# Successfully loaded DQN model from Models/adversarial_best_dqn.pth
# Test - Using DQN threshold: 0.0005
#
# Results for Perturbation Level 5.0:
#   Test Accuracy: 0.7955
#   Precision (weighted): 0.8060
#   Recall (weighted): 0.7955
#   F1 Score (weighted): 0.7979
#   Context Updates Used: 290/576
#   DQN Updates Used: 290/576
#   Average DQN Loss: 0.6984
#   Average Reward: 0.6172
#   Action Distribution: [697 731]
# Combined cumulative accuracy saved to 'Results/Micfoal_Conf_cumulative_accuracy_all_perturbations_transposed.csv'
#
# Combined Results Table:
#  Perturbation Level  Test Accuracy  Precision   Recall  F1 Score  Context Updates Used  DQN Updates Used  DQN Loss
#                 0.1       0.875350   0.876899 0.875350  0.875964                    67                67  0.279293
#                 0.5       0.852941   0.856794 0.852941  0.854131                    96                96  0.377195
#                 1.0       0.842437   0.849973 0.842437  0.844026                   170               170  0.490886
#                 2.0       0.789216   0.799924 0.789216  0.791425                   194               194  0.534362
#                 5.0       0.795518   0.806028 0.795518  0.797877                   290               290  0.698435
#
# Combined results saved to 'Results/AMCAL_20_cumulative_accuracy.csv'.
# Plot saved to 'Results/AMCAL_20_cumulative_accuracy.png'
